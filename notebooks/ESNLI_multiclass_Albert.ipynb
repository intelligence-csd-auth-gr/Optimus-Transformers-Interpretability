# %% [markdown]
# ## ESNLI alBERT multiclass
# In this notebook we examine the performance of interpretability techniques in the ESNLI dataset using alBERT on token level

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score, average_precision_score
from dataset import Dataset
from myModel import MyModel, MyDataset
from myExplainers import MyExplainer
from myEvaluation import MyEvaluation
from sklearn.preprocessing import maxabs_scale
import pickle
from tqdm import tqdm
import datetime
import csv
import warnings
import torch
import tensorflow as tf
from scipy.special import softmax
from helper import print_results, print_results_ap

# %% [markdown]
# Loading model and dataset, defining transformer model, and if rationales are available in the dataset

# %%
data_path = '../datasets/esnli_multiclass.pickle'
model_path = 'Trained Models/'
save_path = 'Results/esnli_multiclass/'

# %%
model_name = 'albert'
dataset_name='esnli_albert_multiclass'
existing_rationales = True

# %% [markdown]
# Load MyModel, and the subsequent tokenizer

# %%
task = 'single_label'
sentence_level = False
labels = 3

model = MyModel(model_path, dataset_name, model_name, task, labels, cased=False, attention=True)
model_no_attention = MyModel(model_path, dataset_name, model_name, task, labels, cased=False, attention=False)
max_sequence_len = model.tokenizer.max_len_single_sentence
tokenizer = model.tokenizer

import torch
print(torch.cuda.is_available())
model.trainer.model.to('cuda')
# Out:
# True
# AlbertForSequenceClassification(
#   (albert): AlbertModel(
#     (embeddings): AlbertEmbeddings(
#       (word_embeddings): Embedding(30000, 128, padding_idx=0)
#       (position_embeddings): Embedding(512, 128)
#       (token_type_embeddings): Embedding(2, 128)
#       (LayerNorm): LayerNorm((128,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0, inplace=False)
#     )
#     (encoder): AlbertTransformer(
#       (embedding_hidden_mapping_in): Linear(in_features=128, out_features=768, bias=True)
#       (albert_layer_groups): ModuleList(
#         (0): AlbertLayerGroup(
#           (albert_layers): ModuleList(
#             (0): AlbertLayer(
#               (full_layer_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (attention): AlbertAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (attention_dropout): Dropout(p=0, inplace=False)
#                 (output_dropout): Dropout(p=0, inplace=False)
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               )
#               (ffn): Linear(in_features=768, out_features=3072, bias=True)
#               (ffn_output): Linear(in_features=3072, out_features=768, bias=True)
#               (dropout): Dropout(p=0, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (pooler): Linear(in_features=768, out_features=768, bias=True)
#     (pooler_activation): Tanh()
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
esnli = Dataset(path = data_path)
dataset, label_names = esnli.load_esnli_multiclass()

# %%
train_texts, test_texts, test_rationales, validation_texts, train_labels, test_labels, validation_labels = dataset

# %%
for i in range(len(test_rationales)):
    if (test_rationales[i][0] == []) & ((test_rationales[i][1] == [])):
        test_rationales[i][0] = [0] * len(test_rationales[i][2])
        test_rationales[i][1] = [0] * len(test_rationales[i][2])
        test_rationales[i][2] = list(test_rationales[i][2])
    
    elif (test_rationales[i][0] == []) & (test_rationales[i][2] == []):
        test_rationales[i][0] = [0] * len(test_rationales[i][1])
        test_rationales[i][1] = list(test_rationales[i][1])
        test_rationales[i][2] = [0] * len(test_rationales[i][1])
    else:
        test_rationales[i][0] = list(test_rationales[i][0])
        test_rationales[i][1] = [0] * len(test_rationales[i][0])
        test_rationales[i][2] = [0] * len(test_rationales[i][0])
# Out:
# C:\Users\chris\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#
# C:\Users\chris\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:7: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   import sys

# %%
test_test_rationales = test_rationales

# %%
new_rationale = []
len_test = len(test_labels) # 2000
num_labels = len(np.unique(test_labels)) #3

for i in range(len_test):
    rationale = []
    test_t = test_texts[i].split(' ')
    for j in range(num_labels):
        label_rational = []
        for k in range(len(test_t)):
            for r in tokenizer.tokenize(test_t[k]):
                #if r == '.':
                #    print(r)
                #print(r)
                rationall = 1 if test_test_rationales[i][j][k] > 0 else 0
                label_rational.append(rationall)
        rationale.append(label_rational)
    new_rationale.append(rationale)

# %% [markdown]
# Then, we measure the performance of the model using f1 score (both macro)

# %%
predictions = []
for test_text in test_texts:
    outputs = model.my_predict(test_text)
    predictions.append(outputs[0])

pred_labels = []
for prediction in predictions:
    pred_labels.append(np.argmax(softmax(prediction)))

accuracy_score(test_labels, pred_labels), f1_score(test_labels, pred_labels, average='macro'), f1_score(test_labels, pred_labels, average='micro')
# Out:
# 2000it [02:27, 13.77it/s]
# (0.7915, 0.7922547738739563, 0.7915)
# 2000it [02:40, 13.77it/s]

# %%
my_explainers = MyExplainer(label_names, model_no_attention) #model 2

my_evaluators = MyEvaluation(label_names, model_no_attention.my_predict, sentence_level = False, task = 'multi-class', evaluation_level_all = True, tokenizer=tokenizer) #model 2
my_evaluatorsP = MyEvaluation(label_names, model_no_attention.my_predict, sentence_level = False, task = 'multi-class', evaluation_level_all = False, tokenizer=tokenizer) #model 2
evaluation =  {'F':my_evaluators.faithfulness, 'FTP': my_evaluators.faithful_truthfulness_penalty, 
          'NZW': my_evaluators.nzw, 'AUPRC': my_evaluators.auprc}
evaluationP = {'F':my_evaluatorsP.faithfulness, 'FTP': my_evaluatorsP.faithful_truthfulness_penalty, 
          'NZW': my_evaluatorsP.nzw, 'AUPRC': my_evaluators.auprc}

# %%
import time
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    
    now = datetime.datetime.now()
    file_name = save_path + 'ESNLI_ALBERT_IG_'+str(now.day) + '_' + str(now.month) + '_' + str(now.year)
    metrics = {'F':[], 'FTP':[], 'NZW':[], 'AUPRC' : []}
    metricsP = {'F':[], 'FTP':[], 'NZW':[], 'AUPRC' : []}
    time_r = []
    my_explainers.neighbours = 2000
    techniques = [my_explainers.ig] #my_explainers.lime 
    for ind in tqdm(range(len(test_texts))):
        torch.cuda.empty_cache() 
        test_rational = new_rationale[ind]
        instance = test_texts[ind]
        my_evaluators.clear_states()
        my_evaluatorsP.clear_states()
        prediction, _, _ = model_no_attention.my_predict(instance)
        enc = model.tokenizer([instance,instance], truncation=True, padding=True)[0]
        mask = enc.attention_mask
        tokens = enc.tokens
    
        interpretations = []
        kk = 0
        for technique in techniques:
            ts = time.time()
            temp = technique(instance, prediction, tokens, mask, _, _)
            interpretations.append([np.array(i)/np.max(abs(np.array(i))) for i in temp])
            time_r.append(time.time()-ts)
            kk = kk + 1
        for metric in metrics.keys():
            evaluated = []
            for interpretation in interpretations:
                evaluated.append(evaluation[metric](interpretation, _, instance, prediction, tokens, _, _, test_rational))
            metrics[metric].append(evaluated)
        my_evaluatorsP.saved_state = my_evaluators.saved_state.copy()
        my_evaluators.clear_states()
        for metric in metrics.keys():
            evaluatedP = []
            for interpretation in interpretations:
                evaluatedP.append(evaluationP[metric](interpretation, _, instance, prediction, tokens, _, _, test_rational))
            metricsP[metric].append(evaluatedP)
with open(file_name+'(A).pickle', 'wb') as handle:
    pickle.dump(metrics, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(file_name+'(P).pickle', 'wb') as handle:
    pickle.dump(metricsP, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(file_name+'_TIME.pickle', 'wb') as handle:
    pickle.dump(time_r, handle, protocol=pickle.HIGHEST_PROTOCOL)
time_r = np.array(time_r)
# time_r.mean()
# time_r.mean(axis=1)
# Out:
# 100%|██████████| 2000/2000 [53:14<00:00,  1.60s/it]

# %% [markdown]
# We present the results for IG

# %%
# Can be fixed
print(time_r)
# Out:
# [1.08529377 0.92850542 0.93050051 ... 0.7705605  0.7933774  0.76258564]

# %%
print_results(file_name+'(A)', [' IG '], metrics, label_names) #[' LIME', ' IG  ']
# Out:
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# F
#  IG   0.035590000450611115 | 0.05574 0.11505 -0.06403
# FTP
#  IG   0.14647 | 0.16321 0.15109 0.12512
# NZW
#  IG   1.0 | 1.0 1.0 1.0
# AUPRC
#  IG   0.33724 | 0.40574 0.27728 0.32871

# %%
print_results(file_name+'(P)', [' IG '], metricsP, label_names) #[' LIME', ' IG  ']
# Out:
# F
#  IG   0.21689 | 0.2714 0.33006 0.04923
# FTP
#  IG   0.25859 | 0.33529 0.3828 0.05769
# NZW
#  IG   1.0 | 1.0 1.0 1.0
# AUPRC
#  IG   0.33724 | 0.40574 0.27728 0.32871

# %% [markdown]
# Then, we perform the experiments for the different attention setups!

# %%
conf = []
for ci in ['Mean', 'Multi'] + list(range(12)):
    for ce in ['Mean'] + list(range(12)):
        for cp in ['From', 'To', 'MeanColumns', 'MaxColumns']: # Matrix: From, To, MeanColumns, MeanRows, MaxColumns, MaxRows
            for cl in [False]: # Selection: True: select layers per head, False: do not
                conf.append([ci, ce, cp, cl])
len(conf)
# Out:
# 728

# %%
import time 
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    
    now = datetime.datetime.now()
    
    file_name = save_path + 'ESNLI_ALBERT_ATTENTION_'+str(now.day) + '_' + str(now.month) + '_' + str(now.year)
    metrics = {'FTP':[], 'F':[], 'NZW':[], 'AUPRC' : []}
    metricsP = {'FTP':[], 'F':[], 'NZW':[], 'AUPRC' : []}
    time_r = []
    time_b = []
    time_b2 = []
    for con in conf:
        time_r.append([])
    for ind in tqdm(range(len(test_texts))):
        torch.cuda.empty_cache() 
        test_rational = new_rationale[ind]
        instance = test_texts[ind]
        my_evaluators.clear_states()
        my_evaluatorsP.clear_states()
        my_explainers.save_states = {}
        prediction, attention, _ = model.my_predict(instance)
        enc = model.tokenizer([instance,instance], truncation=True, padding=True)[0]
        mask = enc.attention_mask
        tokens = enc.tokens
        
        interpretations = []
        kk = 0
        for con in conf:
            ts = time.time()
            my_explainers.config = con
            temp = my_explainers.my_attention(instance, prediction, tokens, mask, attention, _)
            interpretations.append([maxabs_scale(i) for i in temp])
            time_r[kk].append(time.time()-ts)
            kk = kk + 1
        for metric in metrics.keys():
            evaluated = []
            k = 0
            for interpretation in interpretations:
                tt = time.time()
                evaluated.append(evaluation[metric](interpretation, _, instance, prediction, tokens, _, _, test_rational))
                k = k + (time.time()-tt)
            if metric == 'FTP':
                time_b.append(k)
            metrics[metric].append(evaluated)
        my_evaluatorsP.saved_state = my_evaluators.saved_state.copy()
        for metric in metrics.keys():
            evaluated = []
            k = 0
            for interpretation in interpretations:
                tt = time.time()
                evaluated.append(evaluationP[metric](interpretation, _, instance, prediction, tokens, _, _, test_rational))
                k = k + (time.time()-tt)
            if metric == 'FTP':
                time_b2.append(k)
            metricsP[metric].append(evaluated)
with open(file_name+' (A).pickle', 'wb') as handle:
    pickle.dump(metrics, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(file_name+' (P).pickle', 'wb') as handle:
    pickle.dump(metricsP, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(file_name+'_TIME.pickle', 'wb') as handle:
    pickle.dump(time_r, handle, protocol=pickle.HIGHEST_PROTOCOL)
time_r = np.array(time_r)
time_r.mean(axis=1).min(),time_r.mean(axis=1).max(), time_r.mean(axis=1).mean(), time_r.sum(axis=1).mean(), np.mean(time_b), np.mean(time_b2)
# Out:
# 100%|██████████| 2000/2000 [3:03:27<00:00,  5.50s/it]

# %% [markdown]
# We present the results of the different attention setups

# %%
print_results(file_name+' (A)', conf, metrics, label_names)
# Out:
# FTP
# ['Mean', 'Mean', 'From', False]  -0.0 | 0.00752 0.38622 -0.39374
# ['Mean', 'Mean', 'To', False]  -0.0 | -0.0859 0.45486 -0.36897
# ['Mean', 'Mean', 'MeanColumns', False]  -0.0 | -0.00342 0.27532 -0.2719
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['Mean', 'Mean', 'MaxColumns', False]  -0.0 | -0.0741 0.26272 -0.18862
# ['Mean', 0, 'From', False]  -0.0 | 0.00487 0.38923 -0.3941
# ['Mean', 0, 'To', False]  -0.0 | -0.07279 0.44507 -0.37228
# ['Mean', 0, 'MeanColumns', False]  -0.0 | 0.00025 0.2827 -0.28295
# ['Mean', 0, 'MaxColumns', False]  -0.0 | -0.01209 0.29677 -0.28467
# ['Mean', 1, 'From', False]  -0.0 | -0.01339 0.34741 -0.33402
# ['Mean', 1, 'To', False]  -0.0 | -0.08235 0.47149 -0.38915
# ['Mean', 1, 'MeanColumns', False]  -0.0 | -0.02953 0.29809 -0.26856
# ['Mean', 1, 'MaxColumns', False]  -0.0 | -0.03337 0.35032 -0.31695
# ['Mean', 2, 'From', False]  -0.0 | -0.01813 0.452 -0.43387
# ['Mean', 2, 'To', False]  -0.0 | -0.12118 0.30957 -0.18839
# ['Mean', 2, 'MeanColumns', False]  -0.0 | 0.00474 0.3034 -0.30814
# ['Mean', 2, 'MaxColumns', False]  -0.0 | -0.0356 0.32019 -0.28459
# ['Mean', 3, 'From', False]  -0.0 | -0.06908 0.4045 -0.33542
# ['Mean', 3, 'To', False]  -0.0 | -0.05691 0.30327 -0.24636
# ['Mean', 3, 'MeanColumns', False]  -0.0 | -0.08019 0.27851 -0.19832
# ['Mean', 3, 'MaxColumns', False]  -0.0 | -0.09235 0.3053 -0.21295
# ['Mean', 4, 'From', False]  -0.0 | 0.02312 0.25835 -0.28147
# ['Mean', 4, 'To', False]  -0.0 | -0.07797 0.42326 -0.34529
# ['Mean', 4, 'MeanColumns', False]  -0.0 | -0.03487 0.24744 -0.21257
# ['Mean', 4, 'MaxColumns', False]  -0.0 | -0.06593 0.26953 -0.20361
# ['Mean', 5, 'From', False]  -0.0 | -0.06156 0.29513 -0.23358
# ['Mean', 5, 'To', False]  -0.0 | -0.09524 0.45797 -0.36273
# ['Mean', 5, 'MeanColumns', False]  -0.0 | -0.06717 0.28012 -0.21295
# ['Mean', 5, 'MaxColumns', False]  -0.0 | -0.0805 0.29153 -0.21104
# ['Mean', 6, 'From', False]  -0.0 | -0.02217 0.40923 -0.38706
# ['Mean', 6, 'To', False]  -0.0 | -0.06835 0.38883 -0.32047
# ['Mean', 6, 'MeanColumns', False]  -0.0 | -0.01211 0.28755 -0.27544
# ['Mean', 6, 'MaxColumns', False]  -0.0 | -0.04913 0.27293 -0.2238
# ['Mean', 7, 'From', False]  -0.0 | -0.04134 0.23793 -0.19658
# ['Mean', 7, 'To', False]  -0.0 | -0.06707 0.4475 -0.38043
# ['Mean', 7, 'MeanColumns', False]  -0.0 | -0.14214 0.3247 -0.18256
# ['Mean', 7, 'MaxColumns', False]  -0.0 | -0.06987 0.20803 -0.13816
# ['Mean', 8, 'From', False]  -0.0 | -0.05681 0.45907 -0.40227
# ['Mean', 8, 'To', False]  -0.0 | -0.08127 0.36056 -0.27929
# ['Mean', 8, 'MeanColumns', False]  -0.0 | -0.05718 0.30894 -0.25175
# ['Mean', 8, 'MaxColumns', False]  -0.0 | -0.08063 0.33838 -0.25775
# ['Mean', 9, 'From', False]  -0.0 | -0.06676 0.31166 -0.2449
# ['Mean', 9, 'To', False]  -0.0 | -0.08705 0.41859 -0.33154
# ['Mean', 9, 'MeanColumns', False]  -0.0 | -0.07427 0.30245 -0.22818
# ['Mean', 9, 'MaxColumns', False]  -0.0 | -0.09421 0.30373 -0.20952
# ['Mean', 10, 'From', False]  -0.0 | -0.02086 0.29301 -0.27215
# ['Mean', 10, 'To', False]  -0.0 | -0.02624 0.34061 -0.31437
# ['Mean', 10, 'MeanColumns', False]  -0.0 | -0.02341 0.2646 -0.24118
# ['Mean', 10, 'MaxColumns', False]  -0.0 | -0.07902 0.27796 -0.19894
# ['Mean', 11, 'From', False]  -0.0 | -0.04054 0.39659 -0.35605
# ['Mean', 11, 'To', False]  -0.0 | -0.07081 0.29341 -0.2226
# ['Mean', 11, 'MeanColumns', False]  -0.0 | -0.02608 0.2431 -0.21702
# ['Mean', 11, 'MaxColumns', False]  -0.0 | -0.0299 0.30044 -0.27054
# ['Multi', 'Mean', 'From', False]  -0.0 | -0.0584 0.22229 -0.16389
# ['Multi', 'Mean', 'To', False]  -0.0 | -0.06629 0.44306 -0.37677
# ['Multi', 'Mean', 'MeanColumns', False]  -0.0 | -0.05844 0.2223 -0.16387
# ['Multi', 'Mean', 'MaxColumns', False]  -0.0 | -0.05844 0.22229 -0.16386
# ['Multi', 0, 'From', False]  -0.0 | -0.05769 0.23594 -0.17825
# ['Multi', 0, 'To', False]  -0.0 | -0.0446 0.29867 -0.25407
# ['Multi', 0, 'MeanColumns', False]  -0.0 | -0.05777 0.23595 -0.17818
# ['Multi', 0, 'MaxColumns', False]  -0.0 | -0.05782 0.23595 -0.17813
# ['Multi', 1, 'From', False]  -0.0 | -0.05803 0.19932 -0.14129
# ['Multi', 1, 'To', False]  -0.0 | -0.05961 0.20789 -0.14828
# ['Multi', 1, 'MeanColumns', False]  -0.0 | -0.05792 0.19952 -0.14161
# ['Multi', 1, 'MaxColumns', False]  -0.0 | -0.05785 0.19986 -0.14201
# ['Multi', 2, 'From', False]  -0.0 | -0.0585 0.25341 -0.1949
# ['Multi', 2, 'To', False]  -0.0 | -0.05362 0.22811 -0.17449
# ['Multi', 2, 'MeanColumns', False]  -0.0 | -0.05846 0.2534 -0.19493
# ['Multi', 2, 'MaxColumns', False]  -0.0 | -0.05847 0.2534 -0.19494
# ['Multi', 3, 'From', False]  -0.0 | -0.0631 0.2419 -0.17881
# ['Multi', 3, 'To', False]  -0.0 | -0.06493 0.29568 -0.23075
# ['Multi', 3, 'MeanColumns', False]  -0.0 | -0.06308 0.24131 -0.17822
# ['Multi', 3, 'MaxColumns', False]  -0.0 | -0.06254 0.23919 -0.17665
# ['Multi', 4, 'From', False]  -0.0 | -0.0641 0.23343 -0.16933
# ['Multi', 4, 'To', False]  -0.0 | -0.0381 0.3395 -0.30139
# ['Multi', 4, 'MeanColumns', False]  -0.0 | -0.0642 0.23339 -0.16919
# ['Multi', 4, 'MaxColumns', False]  -0.0 | -0.06444 0.2333 -0.16886
# ['Multi', 5, 'From', False]  -0.0 | -0.04395 0.23914 -0.19519
# ['Multi', 5, 'To', False]  -0.0 | -0.07218 0.25384 -0.18166
# ['Multi', 5, 'MeanColumns', False]  -0.0 | -0.04395 0.23913 -0.19518
# ['Multi', 5, 'MaxColumns', False]  -0.0 | -0.04396 0.23914 -0.19518
# ['Multi', 6, 'From', False]  -0.0 | -0.05355 0.25628 -0.20273
# ['Multi', 6, 'To', False]  -0.0 | -0.05951 0.27879 -0.21928
# ['Multi', 6, 'MeanColumns', False]  -0.0 | -0.05357 0.25628 -0.20271
# ['Multi', 6, 'MaxColumns', False]  -0.0 | -0.05357 0.25628 -0.20272
# ['Multi', 7, 'From', False]  -0.0 | -0.08311 0.27469 -0.19158
# ['Multi', 7, 'To', False]  -0.0 | -0.09257 0.33702 -0.24445
# ['Multi', 7, 'MeanColumns', False]  -0.0 | -0.08394 0.27527 -0.19132
# ['Multi', 7, 'MaxColumns', False]  -0.0 | -0.09166 0.28412 -0.19246
# ['Multi', 8, 'From', False]  -0.0 | -0.07402 0.35346 -0.27944
# ['Multi', 8, 'To', False]  -0.0 | -0.08945 0.28246 -0.19301
# ['Multi', 8, 'MeanColumns', False]  -0.0 | -0.07471 0.35275 -0.27805
# ['Multi', 8, 'MaxColumns', False]  -0.0 | -0.0745 0.353 -0.2785
# ['Multi', 9, 'From', False]  -0.0 | -0.07715 0.29627 -0.21911
# ['Multi', 9, 'To', False]  -0.0 | -0.04294 0.20361 -0.16068
# ['Multi', 9, 'MeanColumns', False]  -0.0 | -0.07715 0.29625 -0.21909
# ['Multi', 9, 'MaxColumns', False]  -0.0 | -0.07714 0.29635 -0.2192
# ['Multi', 10, 'From', False]  -0.0 | -0.05424 0.23898 -0.18473
# ['Multi', 10, 'To', False]  -0.0 | -0.04831 0.18776 -0.13945
# ['Multi', 10, 'MeanColumns', False]  -0.0 | -0.05424 0.23898 -0.18473
# ['Multi', 10, 'MaxColumns', False]  -0.0 | -0.05424 0.23898 -0.18473
# ['Multi', 11, 'From', False]  -0.0 | -0.05615 0.17971 -0.12355
# ['Multi', 11, 'To', False]  -0.0 | -0.09571 0.37339 -0.27768
# ['Multi', 11, 'MeanColumns', False]  -0.0 | -0.05613 0.17971 -0.12358
# ['Multi', 11, 'MaxColumns', False]  -0.0 | -0.05615 0.17971 -0.12356
# [0, 'Mean', 'From', False]  -0.0 | -0.07214 0.33147 -0.25933
# [0, 'Mean', 'To', False]  -0.0 | -0.07839 0.44901 -0.37062
# [0, 'Mean', 'MeanColumns', False]  -0.0 | -0.07352 0.29199 -0.21847
# [0, 'Mean', 'MaxColumns', False]  -0.0 | -0.06349 0.28497 -0.22148
# [0, 0, 'From', False]  -0.0 | -0.05973 0.26005 -0.20033
# [0, 0, 'To', False]  -0.0 | -0.06474 0.43139 -0.36666
# [0, 0, 'MeanColumns', False]  -0.0 | -0.07278 0.29256 -0.21978
# [0, 0, 'MaxColumns', False]  -0.0 | -0.06201 0.26701 -0.205
# [0, 1, 'From', False]  -0.0 | -0.06797 0.31576 -0.2478
# [0, 1, 'To', False]  -0.0 | -0.08072 0.46913 -0.3884
# [0, 1, 'MeanColumns', False]  -0.0 | -0.06808 0.28073 -0.21265
# [0, 1, 'MaxColumns', False]  -0.0 | -0.06706 0.28065 -0.21359
# [0, 2, 'From', False]  -0.0 | -0.07921 0.43443 -0.35522
# [0, 2, 'To', False]  -0.0 | -0.07604 0.42576 -0.34972
# [0, 2, 'MeanColumns', False]  -0.0 | -0.07831 0.26966 -0.19134
# [0, 2, 'MaxColumns', False]  -0.0 | -0.08652 0.31322 -0.22671
# [0, 3, 'From', False]  -0.0 | -0.08894 0.37835 -0.28941
# [0, 3, 'To', False]  -0.0 | -0.07941 0.27843 -0.19902
# [0, 3, 'MeanColumns', False]  -0.0 | -0.06125 0.26621 -0.20495
# [0, 3, 'MaxColumns', False]  -0.0 | -0.06029 0.27113 -0.21083
# [0, 4, 'From', False]  -0.0 | -0.07082 0.25124 -0.18042
# [0, 4, 'To', False]  -0.0 | -0.08754 0.40674 -0.3192
# [0, 4, 'MeanColumns', False]  -0.0 | -0.07508 0.32428 -0.2492
# [0, 4, 'MaxColumns', False]  -0.0 | -0.07787 0.33032 -0.25246
# [0, 5, 'From', False]  -0.0 | -0.05407 0.21965 -0.16558
# [0, 5, 'To', False]  -0.0 | -0.05785 0.24336 -0.18551
# [0, 5, 'MeanColumns', False]  -0.0 | -0.05411 0.26737 -0.21326
# [0, 5, 'MaxColumns', False]  -0.0 | -0.06025 0.30234 -0.24209
# [0, 6, 'From', False]  -0.0 | -0.07112 0.33093 -0.2598
# [0, 6, 'To', False]  -0.0 | -0.0794 0.44838 -0.36899
# [0, 6, 'MeanColumns', False]  -0.0 | -0.06467 0.31629 -0.25162
# [0, 6, 'MaxColumns', False]  -0.0 | -0.05498 0.28889 -0.23391
# [0, 7, 'From', False]  -0.0 | -0.04864 0.23046 -0.18182
# [0, 7, 'To', False]  -0.0 | -0.05033 0.23856 -0.18823
# [0, 7, 'MeanColumns', False]  -0.0 | -0.08352 0.30811 -0.22459
# [0, 7, 'MaxColumns', False]  -0.0 | -0.05176 0.24073 -0.18897
# [0, 8, 'From', False]  -0.0 | -0.0718 0.32117 -0.24937
# [0, 8, 'To', False]  -0.0 | -0.07179 0.45188 -0.38008
# [0, 8, 'MeanColumns', False]  -0.0 | -0.0739 0.28903 -0.21512
# [0, 8, 'MaxColumns', False]  -0.0 | -0.0618 0.29006 -0.22826
# [0, 9, 'From', False]  -0.0 | -0.06645 0.276 -0.20955
# [0, 9, 'To', False]  -0.0 | -0.0678 0.31776 -0.24996
# [0, 9, 'MeanColumns', False]  -0.0 | -0.0663 0.28779 -0.22149
# [0, 9, 'MaxColumns', False]  -0.0 | -0.06225 0.30257 -0.24032
# [0, 10, 'From', False]  -0.0 | -0.05272 0.24877 -0.19604
# [0, 10, 'To', False]  -0.0 | -0.05844 0.272 -0.21356
# [0, 10, 'MeanColumns', False]  -0.0 | -0.05951 0.27162 -0.21211
# [0, 10, 'MaxColumns', False]  -0.0 | -0.05439 0.27438 -0.21999
# [0, 11, 'From', False]  -0.0 | -0.078 0.41585 -0.33785
# [0, 11, 'To', False]  -0.0 | -0.07429 0.45273 -0.37843
# [0, 11, 'MeanColumns', False]  -0.0 | -0.06095 0.21901 -0.15806
# [0, 11, 'MaxColumns', False]  -0.0 | -0.05881 0.30638 -0.24757
# [1, 'Mean', 'From', False]  -0.0 | -0.07113 0.38214 -0.311
# [1, 'Mean', 'To', False]  -0.0 | -0.06315 0.291 -0.22785
# [1, 'Mean', 'MeanColumns', False]  -0.0 | -0.06253 0.33516 -0.27263
# [1, 'Mean', 'MaxColumns', False]  -0.0 | -0.05359 0.33582 -0.28223
# [1, 0, 'From', False]  -0.0 | -0.06888 0.40983 -0.34095
# [1, 0, 'To', False]  -0.0 | -0.09071 0.44808 -0.35737
# [1, 0, 'MeanColumns', False]  -0.0 | -0.05232 0.35602 -0.30369
# [1, 0, 'MaxColumns', False]  -0.0 | -0.05417 0.36868 -0.31451
# [1, 1, 'From', False]  -0.0 | -0.07203 0.38983 -0.3178
# [1, 1, 'To', False]  -0.0 | -0.07976 0.47312 -0.39336
# [1, 1, 'MeanColumns', False]  -0.0 | -0.07991 0.3454 -0.26548
# [1, 1, 'MaxColumns', False]  -0.0 | -0.06948 0.38534 -0.31586
# [1, 2, 'From', False]  -0.0 | -0.07454 0.46708 -0.39255
# [1, 2, 'To', False]  -0.0 | -0.06343 0.37911 -0.31568
# [1, 2, 'MeanColumns', False]  -0.0 | -0.07799 0.32472 -0.24673
# [1, 2, 'MaxColumns', False]  -0.0 | -0.0702 0.33967 -0.26947
# [1, 3, 'From', False]  -0.0 | -0.0781 0.45535 -0.37725
# [1, 3, 'To', False]  -0.0 | -0.06498 0.29438 -0.2294
# [1, 3, 'MeanColumns', False]  -0.0 | -0.07952 0.29923 -0.21971
# [1, 3, 'MaxColumns', False]  -0.0 | -0.07023 0.32113 -0.25091
# [1, 4, 'From', False]  -0.0 | -0.0578 0.33639 -0.27859
# [1, 4, 'To', False]  -0.0 | -0.08069 0.43612 -0.35543
# [1, 4, 'MeanColumns', False]  -0.0 | -0.07204 0.29098 -0.21893
# [1, 4, 'MaxColumns', False]  -0.0 | -0.06902 0.32024 -0.25122
# [1, 5, 'From', False]  -0.0 | -0.05137 0.33674 -0.28537
# [1, 5, 'To', False]  -0.0 | -0.06716 0.31464 -0.24748
# [1, 5, 'MeanColumns', False]  -0.0 | -0.06093 0.33382 -0.27289
# [1, 5, 'MaxColumns', False]  -0.0 | -0.06236 0.34393 -0.28157
# [1, 6, 'From', False]  -0.0 | -0.0582 0.39069 -0.33249
# [1, 6, 'To', False]  -0.0 | -0.07947 0.46173 -0.38225
# [1, 6, 'MeanColumns', False]  -0.0 | -0.04468 0.29241 -0.24773
# [1, 6, 'MaxColumns', False]  -0.0 | -0.04373 0.29827 -0.25455
# [1, 7, 'From', False]  -0.0 | -0.08024 0.23832 -0.15808
# [1, 7, 'To', False]  -0.0 | -0.05002 0.20735 -0.15734
# [1, 7, 'MeanColumns', False]  -0.0 | -0.09823 0.30601 -0.20778
# [1, 7, 'MaxColumns', False]  -0.0 | -0.0644 0.25583 -0.19143
# [1, 8, 'From', False]  -0.0 | -0.07077 0.41627 -0.3455
# [1, 8, 'To', False]  -0.0 | -0.08014 0.41816 -0.33802
# [1, 8, 'MeanColumns', False]  -0.0 | -0.07386 0.33557 -0.26171
# [1, 8, 'MaxColumns', False]  -0.0 | -0.06259 0.33071 -0.26811
# [1, 9, 'From', False]  -0.0 | -0.07724 0.33491 -0.25767
# [1, 9, 'To', False]  -0.0 | -0.07145 0.37129 -0.29984
# [1, 9, 'MeanColumns', False]  -0.0 | -0.07653 0.35296 -0.27643
# [1, 9, 'MaxColumns', False]  -0.0 | -0.06699 0.3283 -0.2613
# [1, 10, 'From', False]  -0.0 | -0.09875 0.31366 -0.21491
# [1, 10, 'To', False]  -0.0 | -0.07616 0.242 -0.16583
# [1, 10, 'MeanColumns', False]  -0.0 | -0.06797 0.28806 -0.2201
# [1, 10, 'MaxColumns', False]  -0.0 | -0.07081 0.2799 -0.20909
# [1, 11, 'From', False]  -0.0 | -0.07194 0.45813 -0.38619
# [1, 11, 'To', False]  -0.0 | -0.05571 0.26828 -0.21257
# [1, 11, 'MeanColumns', False]  -0.0 | -0.05431 0.29101 -0.2367
# [1, 11, 'MaxColumns', False]  -0.0 | -0.03723 0.34685 -0.30962
# [2, 'Mean', 'From', False]  -0.0 | -0.06887 0.32063 -0.25176
# [2, 'Mean', 'To', False]  -0.0 | -0.06653 0.2949 -0.22837
# [2, 'Mean', 'MeanColumns', False]  -0.0 | -0.07878 0.30752 -0.22874
# [2, 'Mean', 'MaxColumns', False]  -0.0 | -0.05374 0.30011 -0.24637
# [2, 0, 'From', False]  -0.0 | -0.06792 0.36005 -0.29213
# [2, 0, 'To', False]  -0.0 | -0.08921 0.43006 -0.34085
# [2, 0, 'MeanColumns', False]  -0.0 | -0.07253 0.31338 -0.24086
# [2, 0, 'MaxColumns', False]  -0.0 | -0.06481 0.3299 -0.26509
# [2, 1, 'From', False]  -0.0 | -0.08074 0.30569 -0.22495
# [2, 1, 'To', False]  -0.0 | -0.083 0.45939 -0.37639
# [2, 1, 'MeanColumns', False]  -0.0 | -0.07169 0.30745 -0.23576
# [2, 1, 'MaxColumns', False]  -0.0 | -0.06416 0.3401 -0.27594
# [2, 2, 'From', False]  -0.0 | -0.07526 0.4052 -0.32995
# [2, 2, 'To', False]  -0.0 | -0.06046 0.26281 -0.20235
# [2, 2, 'MeanColumns', False]  -0.0 | -0.06309 0.34002 -0.27693
# [2, 2, 'MaxColumns', False]  -0.0 | -0.06089 0.34755 -0.28667
# [2, 3, 'From', False]  -0.0 | -0.0702 0.37777 -0.30757
# [2, 3, 'To', False]  -0.0 | -0.06123 0.23994 -0.17871
# [2, 3, 'MeanColumns', False]  -0.0 | -0.0804 0.31831 -0.2379
# [2, 3, 'MaxColumns', False]  -0.0 | -0.07225 0.32604 -0.25379
# [2, 4, 'From', False]  -0.0 | -0.07066 0.25311 -0.18245
# [2, 4, 'To', False]  -0.0 | -0.08289 0.42914 -0.34625
# [2, 4, 'MeanColumns', False]  -0.0 | -0.06581 0.29105 -0.22523
# [2, 4, 'MaxColumns', False]  -0.0 | -0.0599 0.29336 -0.23346
# [2, 5, 'From', False]  -0.0 | -0.0686 0.31129 -0.24268
# [2, 5, 'To', False]  -0.0 | -0.07217 0.31413 -0.24196
# [2, 5, 'MeanColumns', False]  -0.0 | -0.08137 0.30456 -0.22319
# [2, 5, 'MaxColumns', False]  -0.0 | -0.07677 0.29771 -0.22094
# [2, 6, 'From', False]  -0.0 | -0.0576 0.28895 -0.23136
# [2, 6, 'To', False]  -0.0 | -0.08353 0.38588 -0.30235
# [2, 6, 'MeanColumns', False]  -0.0 | -0.05518 0.28488 -0.22971
# [2, 6, 'MaxColumns', False]  -0.0 | -0.04848 0.29341 -0.24493
# [2, 7, 'From', False]  -0.0 | -0.07394 0.30736 -0.23342
# [2, 7, 'To', False]  -0.0 | -0.0527 0.23198 -0.17928
# [2, 7, 'MeanColumns', False]  -0.0 | -0.11495 0.34673 -0.23178
# [2, 7, 'MaxColumns', False]  -0.0 | -0.05829 0.26982 -0.21153
# [2, 8, 'From', False]  -0.0 | -0.07224 0.33209 -0.25985
# [2, 8, 'To', False]  -0.0 | -0.06581 0.31994 -0.25413
# [2, 8, 'MeanColumns', False]  -0.0 | -0.07735 0.30572 -0.22836
# [2, 8, 'MaxColumns', False]  -0.0 | -0.07227 0.34009 -0.26781
# [2, 9, 'From', False]  -0.0 | -0.0726 0.30759 -0.23499
# [2, 9, 'To', False]  -0.0 | -0.07283 0.3252 -0.25237
# [2, 9, 'MeanColumns', False]  -0.0 | -0.09097 0.29764 -0.20668
# [2, 9, 'MaxColumns', False]  -0.0 | -0.07062 0.26633 -0.1957
# [2, 10, 'From', False]  -0.0 | -0.09531 0.31802 -0.22271
# [2, 10, 'To', False]  -0.0 | -0.07648 0.31116 -0.23468
# [2, 10, 'MeanColumns', False]  -0.0 | -0.08145 0.26358 -0.18212
# [2, 10, 'MaxColumns', False]  -0.0 | -0.06951 0.25 -0.18049
# [2, 11, 'From', False]  -0.0 | -0.083 0.398 -0.31501
# [2, 11, 'To', False]  -0.0 | -0.05949 0.23475 -0.17526
# [2, 11, 'MeanColumns', False]  -0.0 | -0.066 0.26002 -0.19402
# [2, 11, 'MaxColumns', False]  -0.0 | -0.06244 0.33404 -0.2716
# [3, 'Mean', 'From', False]  -0.0 | -0.05897 0.31089 -0.25192
# [3, 'Mean', 'To', False]  -0.0 | -0.06565 0.30512 -0.23947
# [3, 'Mean', 'MeanColumns', False]  -0.0 | -0.08761 0.31683 -0.22922
# [3, 'Mean', 'MaxColumns', False]  -0.0 | -0.06504 0.27576 -0.21072
# [3, 0, 'From', False]  -0.0 | -0.06799 0.37274 -0.30476
# [3, 0, 'To', False]  -0.0 | -0.09393 0.44631 -0.35238
# [3, 0, 'MeanColumns', False]  -0.0 | -0.06873 0.34063 -0.27191
# [3, 0, 'MaxColumns', False]  -0.0 | -0.05603 0.34826 -0.29223
# [3, 1, 'From', False]  -0.0 | -0.08789 0.31971 -0.23182
# [3, 1, 'To', False]  -0.0 | -0.07611 0.46958 -0.39347
# [3, 1, 'MeanColumns', False]  -0.0 | -0.06041 0.34145 -0.28104
# [3, 1, 'MaxColumns', False]  -0.0 | -0.04971 0.37385 -0.32414
# [3, 2, 'From', False]  -0.0 | -0.07148 0.43289 -0.36141
# [3, 2, 'To', False]  -0.0 | -0.05679 0.2578 -0.20102
# [3, 2, 'MeanColumns', False]  -0.0 | -0.05777 0.34048 -0.28271
# [3, 2, 'MaxColumns', False]  -0.0 | -0.05519 0.34946 -0.29428
# [3, 3, 'From', False]  -0.0 | -0.05529 0.36669 -0.3114
# [3, 3, 'To', False]  -0.0 | -0.06607 0.25433 -0.18825
# [3, 3, 'MeanColumns', False]  -0.0 | -0.07861 0.30668 -0.22807
# [3, 3, 'MaxColumns', False]  -0.0 | -0.08096 0.30999 -0.22904
# [3, 4, 'From', False]  -0.0 | -0.05619 0.24435 -0.18816
# [3, 4, 'To', False]  -0.0 | -0.08094 0.418 -0.33706
# [3, 4, 'MeanColumns', False]  -0.0 | -0.07448 0.37103 -0.29655
# [3, 4, 'MaxColumns', False]  -0.0 | -0.07131 0.3613 -0.29
# [3, 5, 'From', False]  -0.0 | -0.06586 0.30903 -0.24316
# [3, 5, 'To', False]  -0.0 | -0.07309 0.3299 -0.25681
# [3, 5, 'MeanColumns', False]  -0.0 | -0.08968 0.2934 -0.20372
# [3, 5, 'MaxColumns', False]  -0.0 | -0.0867 0.29157 -0.20488
# [3, 6, 'From', False]  -0.0 | -0.06036 0.2949 -0.23454
# [3, 6, 'To', False]  -0.0 | -0.0732 0.33519 -0.262
# [3, 6, 'MeanColumns', False]  -0.0 | -0.06003 0.2564 -0.19637
# [3, 6, 'MaxColumns', False]  -0.0 | -0.05643 0.265 -0.20856
# [3, 7, 'From', False]  -0.0 | -0.07084 0.27239 -0.20156
# [3, 7, 'To', False]  -0.0 | -0.05659 0.24751 -0.19092
# [3, 7, 'MeanColumns', False]  -0.0 | -0.14032 0.32043 -0.18011
# [3, 7, 'MaxColumns', False]  -0.0 | -0.09532 0.26273 -0.16741
# [3, 8, 'From', False]  -0.0 | -0.06626 0.32672 -0.26046
# [3, 8, 'To', False]  -0.0 | -0.05884 0.31684 -0.258
# [3, 8, 'MeanColumns', False]  -0.0 | -0.08088 0.2922 -0.21133
# [3, 8, 'MaxColumns', False]  -0.0 | -0.07459 0.31508 -0.24049
# [3, 9, 'From', False]  -0.0 | -0.07104 0.31011 -0.23907
# [3, 9, 'To', False]  -0.0 | -0.0703 0.32001 -0.24971
# [3, 9, 'MeanColumns', False]  -0.0 | -0.09913 0.28125 -0.18212
# [3, 9, 'MaxColumns', False]  -0.0 | -0.08348 0.26337 -0.17989
# [3, 10, 'From', False]  -0.0 | -0.07522 0.2998 -0.22459
# [3, 10, 'To', False]  -0.0 | -0.08983 0.34051 -0.25068
# [3, 10, 'MeanColumns', False]  -0.0 | -0.07664 0.28029 -0.20365
# [3, 10, 'MaxColumns', False]  -0.0 | -0.07104 0.27381 -0.20277
# [3, 11, 'From', False]  -0.0 | -0.07893 0.41018 -0.33124
# [3, 11, 'To', False]  -0.0 | -0.05645 0.25746 -0.201
# [3, 11, 'MeanColumns', False]  -0.0 | -0.06851 0.28816 -0.21965
# [3, 11, 'MaxColumns', False]  -0.0 | -0.06843 0.32594 -0.25752
# [4, 'Mean', 'From', False]  -0.0 | -0.01487 0.31194 -0.29707
# [4, 'Mean', 'To', False]  -0.0 | -0.07647 0.32469 -0.24822
# [4, 'Mean', 'MeanColumns', False]  -0.0 | -0.0449 0.30132 -0.25642
# [4, 'Mean', 'MaxColumns', False]  -0.0 | -0.03941 0.27943 -0.24003
# [4, 0, 'From', False]  -0.0 | -0.02439 0.37473 -0.35034
# [4, 0, 'To', False]  -0.0 | -0.09908 0.40444 -0.30536
# [4, 0, 'MeanColumns', False]  -0.0 | -0.0343 0.33746 -0.30316
# [4, 0, 'MaxColumns', False]  -0.0 | -0.03059 0.35483 -0.32424
# [4, 1, 'From', False]  -0.0 | -0.05568 0.33619 -0.2805
# [4, 1, 'To', False]  -0.0 | -0.08122 0.44931 -0.36809
# [4, 1, 'MeanColumns', False]  -0.0 | -0.05945 0.33848 -0.27903
# [4, 1, 'MaxColumns', False]  -0.0 | -0.03736 0.34598 -0.30862
# [4, 2, 'From', False]  -0.0 | -0.05181 0.42815 -0.37633
# [4, 2, 'To', False]  -0.0 | -0.10819 0.38551 -0.27732
# [4, 2, 'MeanColumns', False]  -0.0 | -0.04118 0.31338 -0.2722
# [4, 2, 'MaxColumns', False]  -0.0 | -0.04589 0.33849 -0.2926
# [4, 3, 'From', False]  -0.0 | -0.01406 0.30121 -0.28714
# [4, 3, 'To', False]  -0.0 | -0.07031 0.28382 -0.2135
# [4, 3, 'MeanColumns', False]  -0.0 | -0.06918 0.28448 -0.2153
# [4, 3, 'MaxColumns', False]  -0.0 | -0.07197 0.28869 -0.21672
# [4, 4, 'From', False]  -0.0 | -0.05013 0.27859 -0.22846
# [4, 4, 'To', False]  -0.0 | -0.0731 0.41191 -0.33881
# [4, 4, 'MeanColumns', False]  -0.0 | -0.06861 0.28288 -0.21427
# [4, 4, 'MaxColumns', False]  -0.0 | -0.0639 0.2808 -0.2169
# [4, 5, 'From', False]  -0.0 | -0.03128 0.27908 -0.2478
# [4, 5, 'To', False]  -0.0 | -0.07301 0.3146 -0.24159
# [4, 5, 'MeanColumns', False]  -0.0 | -0.04961 0.3129 -0.26329
# [4, 5, 'MaxColumns', False]  -0.0 | -0.06061 0.31989 -0.25927
# [4, 6, 'From', False]  -0.0 | -0.03266 0.33585 -0.30319
# [4, 6, 'To', False]  -0.0 | -0.07651 0.39776 -0.32125
# [4, 6, 'MeanColumns', False]  -0.0 | -0.05868 0.27122 -0.21254
# [4, 6, 'MaxColumns', False]  -0.0 | -0.05513 0.26968 -0.21455
# [4, 7, 'From', False]  -0.0 | -0.07254 0.26507 -0.19253
# [4, 7, 'To', False]  -0.0 | -0.06083 0.28952 -0.22869
# [4, 7, 'MeanColumns', False]  -0.0 | -0.13793 0.35284 -0.21491
# [4, 7, 'MaxColumns', False]  -0.0 | -0.09384 0.28033 -0.18649
# [4, 8, 'From', False]  -0.0 | -0.06767 0.35171 -0.28404
# [4, 8, 'To', False]  -0.0 | -0.0592 0.28965 -0.23045
# [4, 8, 'MeanColumns', False]  -0.0 | -0.06767 0.28316 -0.2155
# [4, 8, 'MaxColumns', False]  -0.0 | -0.08129 0.34316 -0.26187
# [4, 9, 'From', False]  -0.0 | -0.04045 0.29477 -0.25432
# [4, 9, 'To', False]  -0.0 | -0.07903 0.3092 -0.23017
# [4, 9, 'MeanColumns', False]  -0.0 | -0.06986 0.28549 -0.21562
# [4, 9, 'MaxColumns', False]  -0.0 | -0.07339 0.29217 -0.21879
# [4, 10, 'From', False]  -0.0 | -0.05267 0.26754 -0.21487
# [4, 10, 'To', False]  -0.0 | -0.09612 0.32317 -0.22705
# [4, 10, 'MeanColumns', False]  -0.0 | -0.08123 0.33503 -0.25379
# [4, 10, 'MaxColumns', False]  -0.0 | -0.08284 0.33255 -0.24971
# [4, 11, 'From', False]  -0.0 | -0.05484 0.31754 -0.2627
# [4, 11, 'To', False]  -0.0 | -0.0655 0.26139 -0.19589
# [4, 11, 'MeanColumns', False]  -0.0 | -0.02824 0.25988 -0.23164
# [4, 11, 'MaxColumns', False]  -0.0 | -0.02726 0.33405 -0.3068
# [5, 'Mean', 'From', False]  -0.0 | 0.00832 0.30251 -0.31083
# [5, 'Mean', 'To', False]  -0.0 | -0.06871 0.34401 -0.2753
# [5, 'Mean', 'MeanColumns', False]  -0.0 | -0.00764 0.28129 -0.27365
# [5, 'Mean', 'MaxColumns', False]  -0.0 | -0.04191 0.27701 -0.2351
# [5, 0, 'From', False]  -0.0 | 0.00911 0.32876 -0.33787
# [5, 0, 'To', False]  -0.0 | -0.08826 0.4453 -0.35704
# [5, 0, 'MeanColumns', False]  -0.0 | -0.00214 0.26295 -0.26081
# [5, 0, 'MaxColumns', False]  -0.0 | -0.00439 0.28622 -0.28183
# [5, 1, 'From', False]  -0.0 | -0.04153 0.32692 -0.2854
# [5, 1, 'To', False]  -0.0 | -0.08392 0.43882 -0.3549
# [5, 1, 'MeanColumns', False]  -0.0 | -0.04235 0.31974 -0.27739
# [5, 1, 'MaxColumns', False]  -0.0 | -0.03235 0.35929 -0.32694
# [5, 2, 'From', False]  -0.0 | -0.03766 0.41245 -0.37479
# [5, 2, 'To', False]  -0.0 | -0.12402 0.3436 -0.21957
# [5, 2, 'MeanColumns', False]  -0.0 | -0.00863 0.33224 -0.32362
# [5, 2, 'MaxColumns', False]  -0.0 | -0.01713 0.34529 -0.32816
# [5, 3, 'From', False]  -0.0 | 0.0146 0.26069 -0.27529
# [5, 3, 'To', False]  -0.0 | -0.06679 0.29322 -0.22643
# [5, 3, 'MeanColumns', False]  -0.0 | -0.07638 0.27922 -0.20284
# [5, 3, 'MaxColumns', False]  -0.0 | -0.07833 0.30048 -0.22215
# [5, 4, 'From', False]  -0.0 | -0.03989 0.27545 -0.23556
# [5, 4, 'To', False]  -0.0 | -0.07274 0.40289 -0.33015
# [5, 4, 'MeanColumns', False]  -0.0 | -0.0599 0.23622 -0.17632
# [5, 4, 'MaxColumns', False]  -0.0 | -0.05879 0.25377 -0.19499
# [5, 5, 'From', False]  -0.0 | -0.01903 0.25683 -0.2378
# [5, 5, 'To', False]  -0.0 | -0.07428 0.35884 -0.28456
# [5, 5, 'MeanColumns', False]  -0.0 | -0.03751 0.30917 -0.27166
# [5, 5, 'MaxColumns', False]  -0.0 | -0.05533 0.3295 -0.27417
# [5, 6, 'From', False]  -0.0 | -0.02767 0.36159 -0.33392
# [5, 6, 'To', False]  -0.0 | -0.06902 0.31655 -0.24753
# [5, 6, 'MeanColumns', False]  -0.0 | -0.04084 0.31827 -0.27742
# [5, 6, 'MaxColumns', False]  -0.0 | -0.04743 0.32465 -0.27722
# [5, 7, 'From', False]  -0.0 | -0.06194 0.23384 -0.17189
# [5, 7, 'To', False]  -0.0 | -0.0431 0.29455 -0.25145
# [5, 7, 'MeanColumns', False]  -0.0 | -0.12758 0.35468 -0.2271
# [5, 7, 'MaxColumns', False]  -0.0 | -0.09583 0.28857 -0.19274
# [5, 8, 'From', False]  -0.0 | -0.06532 0.35467 -0.28935
# [5, 8, 'To', False]  -0.0 | -0.08047 0.26865 -0.18818
# [5, 8, 'MeanColumns', False]  -0.0 | -0.05704 0.29178 -0.23474
# [5, 8, 'MaxColumns', False]  -0.0 | -0.07443 0.36683 -0.2924
# [5, 9, 'From', False]  -0.0 | 0.00098 0.25145 -0.25243
# [5, 9, 'To', False]  -0.0 | -0.0844 0.33501 -0.25061
# [5, 9, 'MeanColumns', False]  -0.0 | -0.05618 0.28578 -0.2296
# [5, 9, 'MaxColumns', False]  -0.0 | -0.07085 0.30047 -0.22963
# [5, 10, 'From', False]  -0.0 | -0.03404 0.21364 -0.1796
# [5, 10, 'To', False]  -0.0 | -0.06859 0.30249 -0.2339
# [5, 10, 'MeanColumns', False]  -0.0 | -0.08087 0.28033 -0.19946
# [5, 10, 'MaxColumns', False]  -0.0 | -0.08306 0.27482 -0.19176
# [5, 11, 'From', False]  -0.0 | -0.04389 0.29416 -0.25027
# [5, 11, 'To', False]  -0.0 | -0.05992 0.20938 -0.14947
# [5, 11, 'MeanColumns', False]  -0.0 | -0.02556 0.26982 -0.24426
# [5, 11, 'MaxColumns', False]  -0.0 | -0.0239 0.31188 -0.28797
# F
# ['Mean', 'Mean', 'From', False]  0.0 | 0.06797 0.11704 -0.18501
# ['Mean', 'Mean', 'To', False]  0.0 | -0.04052 0.17036 -0.12984
# ['Mean', 'Mean', 'MeanColumns', False]  -0.0 | 0.04947 0.06644 -0.11591
# ['Mean', 'Mean', 'MaxColumns', False]  0.0 | -0.02129 0.05838 -0.03709
# ['Mean', 0, 'From', False]  0.0 | 0.06831 0.1127 -0.18101
# ['Mean', 0, 'To', False]  -0.0 | -0.01384 0.14703 -0.1332
# ['Mean', 0, 'MeanColumns', False]  0.0 | 0.07172 0.0487 -0.12042
# ['Mean', 0, 'MaxColumns', False]  0.0 | 0.06059 0.04984 -0.11043
# ['Mean', 1, 'From', False]  0.0 | 0.03614 0.10056 -0.1367
# ['Mean', 1, 'To', False]  -0.0 | -0.03506 0.17585 -0.14079
# ['Mean', 1, 'MeanColumns', False]  0.0 | 0.00878 0.09982 -0.1086
# ['Mean', 1, 'MaxColumns', False]  0.0 | 0.01825 0.10765 -0.1259
# ['Mean', 2, 'From', False]  -0.0 | 0.02889 0.1673 -0.19619
# ['Mean', 2, 'To', False]  -0.0 | -0.06371 0.10729 -0.04358
# ['Mean', 2, 'MeanColumns', False]  0.0 | 0.07178 0.05344 -0.12522
# ['Mean', 2, 'MaxColumns', False]  0.0 | 0.02028 0.06774 -0.08802
# ['Mean', 3, 'From', False]  0.0 | -0.0198 0.16296 -0.14315
# ['Mean', 3, 'To', False]  -0.0 | -0.00961 0.02283 -0.01322
# ['Mean', 3, 'MeanColumns', False]  -0.0 | -0.02052 0.06195 -0.04143
# ['Mean', 3, 'MaxColumns', False]  0.0 | -0.03053 0.07765 -0.04712
# ['Mean', 4, 'From', False]  -0.0 | 0.07812 0.00276 -0.08088
# ['Mean', 4, 'To', False]  0.0 | -0.03832 0.17817 -0.13985
# ['Mean', 4, 'MeanColumns', False]  0.0 | 0.00558 0.04472 -0.0503
# ['Mean', 4, 'MaxColumns', False]  0.0 | -0.01735 0.06232 -0.04497
# ['Mean', 5, 'From', False]  0.0 | -0.02664 0.09269 -0.06605
# ['Mean', 5, 'To', False]  0.0 | -0.03537 0.17613 -0.14076
# ['Mean', 5, 'MeanColumns', False]  0.0 | -0.02678 0.06085 -0.03407
# ['Mean', 5, 'MaxColumns', False]  -0.0 | -0.03002 0.06933 -0.03931
# ['Mean', 6, 'From', False]  -0.0 | 0.01733 0.13359 -0.15092
# ['Mean', 6, 'To', False]  0.0 | -0.02332 0.13372 -0.1104
# ['Mean', 6, 'MeanColumns', False]  0.0 | 0.02161 0.06703 -0.08864
# ['Mean', 6, 'MaxColumns', False]  -0.0 | -0.0106 0.06128 -0.05068
# ['Mean', 7, 'From', False]  -0.0 | -0.01404 0.05325 -0.03921
# ['Mean', 7, 'To', False]  0.0 | -0.02795 0.17849 -0.15054
# ['Mean', 7, 'MeanColumns', False]  0.0 | -0.08716 0.13307 -0.0459
# ['Mean', 7, 'MaxColumns', False]  -0.0 | -0.01331 0.03442 -0.02111
# ['Mean', 8, 'From', False]  0.0 | -0.00587 0.17334 -0.16747
# ['Mean', 8, 'To', False]  -0.0 | -0.01904 0.11427 -0.09523
# ['Mean', 8, 'MeanColumns', False]  -0.0 | -0.01233 0.05134 -0.03901
# ['Mean', 8, 'MaxColumns', False]  0.0 | -0.03124 0.12043 -0.08918
# ['Mean', 9, 'From', False]  0.0 | -0.02927 0.12442 -0.09514
# ['Mean', 9, 'To', False]  -0.0 | -0.0339 0.15485 -0.12095
# ['Mean', 9, 'MeanColumns', False]  -0.0 | -0.02506 0.10146 -0.0764
# ['Mean', 9, 'MaxColumns', False]  0.0 | -0.03177 0.09749 -0.06571
# ['Mean', 10, 'From', False]  -0.0 | 0.0287 0.07538 -0.10408
# ['Mean', 10, 'To', False]  0.0 | 0.01728 0.11368 -0.13096
# ['Mean', 10, 'MeanColumns', False]  -0.0 | 0.01141 0.08108 -0.09249
# ['Mean', 10, 'MaxColumns', False]  0.0 | -0.02579 0.0964 -0.07062
# ['Mean', 11, 'From', False]  0.0 | 0.00826 0.13003 -0.13829
# ['Mean', 11, 'To', False]  -0.0 | -0.01449 0.04129 -0.0268
# ['Mean', 11, 'MeanColumns', False]  -0.0 | -0.0071 0.0549 -0.0478
# ['Mean', 11, 'MaxColumns', False]  0.0 | -0.00439 0.10189 -0.09751
# ['Multi', 'Mean', 'From', False]  -0.0 | -0.00959 0.02406 -0.01447
# ['Multi', 'Mean', 'To', False]  0.0 | -0.0056 0.16292 -0.15732
# ['Multi', 'Mean', 'MeanColumns', False]  -0.0 | -0.00959 0.02406 -0.01447
# ['Multi', 'Mean', 'MaxColumns', False]  -0.0 | -0.00959 0.02406 -0.01447
# ['Multi', 0, 'From', False]  -0.0 | -0.00992 0.02463 -0.01471
# ['Multi', 0, 'To', False]  0.0 | 0.00056 0.10441 -0.10497
# ['Multi', 0, 'MeanColumns', False]  -0.0 | -0.00992 0.02463 -0.01471
# ['Multi', 0, 'MaxColumns', False]  -0.0 | -0.00992 0.02463 -0.01471
# ['Multi', 1, 'From', False]  -0.0 | -0.00906 0.0198 -0.01074
# ['Multi', 1, 'To', False]  -0.0 | -0.00516 0.02714 -0.02198
# ['Multi', 1, 'MeanColumns', False]  -0.0 | -0.00906 0.0198 -0.01074
# ['Multi', 1, 'MaxColumns', False]  -0.0 | -0.00906 0.0198 -0.01074
# ['Multi', 2, 'From', False]  -0.0 | -0.00953 0.02209 -0.01256
# ['Multi', 2, 'To', False]  -0.0 | -0.00948 0.05699 -0.04751
# ['Multi', 2, 'MeanColumns', False]  -0.0 | -0.00952 0.02209 -0.01257
# ['Multi', 2, 'MaxColumns', False]  -0.0 | -0.00953 0.02209 -0.01256
# ['Multi', 3, 'From', False]  -0.0 | -0.0181 0.05525 -0.03715
# ['Multi', 3, 'To', False]  -0.0 | -0.01468 0.07575 -0.06107
# ['Multi', 3, 'MeanColumns', False]  0.0 | -0.01818 0.05485 -0.03667
# ['Multi', 3, 'MaxColumns', False]  -0.0 | -0.01679 0.05329 -0.0365
# ['Multi', 4, 'From', False]  -0.0 | -0.01237 0.02404 -0.01168
# ['Multi', 4, 'To', False]  0.0 | 0.00293 0.09724 -0.10017
# ['Multi', 4, 'MeanColumns', False]  -0.0 | -0.01237 0.02404 -0.01168
# ['Multi', 4, 'MaxColumns', False]  -0.0 | -0.01237 0.02404 -0.01168
# ['Multi', 5, 'From', False]  0.0 | -0.00573 0.04279 -0.03706
# ['Multi', 5, 'To', False]  0.0 | -0.03019 0.09416 -0.06397
# ['Multi', 5, 'MeanColumns', False]  0.0 | -0.00573 0.04279 -0.03706
# ['Multi', 5, 'MaxColumns', False]  0.0 | -0.00573 0.04279 -0.03706
# ['Multi', 6, 'From', False]  -0.0 | -0.00953 0.02327 -0.01374
# ['Multi', 6, 'To', False]  0.0 | -0.01619 0.0954 -0.07921
# ['Multi', 6, 'MeanColumns', False]  -0.0 | -0.00953 0.02327 -0.01374
# ['Multi', 6, 'MaxColumns', False]  -0.0 | -0.00953 0.02327 -0.01374
# ['Multi', 7, 'From', False]  0.0 | -0.02584 0.06501 -0.03917
# ['Multi', 7, 'To', False]  0.0 | -0.04491 0.10547 -0.06056
# ['Multi', 7, 'MeanColumns', False]  0.0 | -0.02677 0.06474 -0.03797
# ['Multi', 7, 'MaxColumns', False]  0.0 | -0.03144 0.07113 -0.03969
# ['Multi', 8, 'From', False]  0.0 | -0.02517 0.11508 -0.08991
# ['Multi', 8, 'To', False]  0.0 | -0.02793 0.07842 -0.0505
# ['Multi', 8, 'MeanColumns', False]  0.0 | -0.02569 0.11522 -0.08953
# ['Multi', 8, 'MaxColumns', False]  0.0 | -0.02546 0.1152 -0.08974
# ['Multi', 9, 'From', False]  0.0 | -0.02255 0.07058 -0.04804
# ['Multi', 9, 'To', False]  -0.0 | 0.00162 0.04073 -0.04236
# ['Multi', 9, 'MeanColumns', False]  0.0 | -0.02255 0.07058 -0.04804
# ['Multi', 9, 'MaxColumns', False]  -0.0 | -0.02249 0.07059 -0.0481
# ['Multi', 10, 'From', False]  -0.0 | -0.01193 0.03681 -0.02488
# ['Multi', 10, 'To', False]  0.0 | -0.02433 0.09813 -0.0738
# ['Multi', 10, 'MeanColumns', False]  -0.0 | -0.01193 0.03681 -0.02488
# ['Multi', 10, 'MaxColumns', False]  -0.0 | -0.01193 0.03681 -0.02488
# ['Multi', 11, 'From', False]  -0.0 | -0.00872 0.02092 -0.0122
# ['Multi', 11, 'To', False]  0.0 | -0.0327 0.13125 -0.09855
# ['Multi', 11, 'MeanColumns', False]  -0.0 | -0.00872 0.02092 -0.0122
# ['Multi', 11, 'MaxColumns', False]  -0.0 | -0.00872 0.02092 -0.0122
# [0, 'Mean', 'From', False]  -0.0 | -0.02615 0.109 -0.08285
# [0, 'Mean', 'To', False]  -0.0 | -0.03787 0.1777 -0.13983
# [0, 'Mean', 'MeanColumns', False]  0.0 | -0.02874 0.1103 -0.08155
# [0, 'Mean', 'MaxColumns', False]  0.0 | -0.01643 0.07566 -0.05922
# [0, 0, 'From', False]  0.0 | -0.01572 0.05219 -0.03647
# [0, 0, 'To', False]  -0.0 | -0.01337 0.15288 -0.13951
# [0, 0, 'MeanColumns', False]  -0.0 | -0.02436 0.08147 -0.05711
# [0, 0, 'MaxColumns', False]  -0.0 | -0.0097 0.0249 -0.0152
# [0, 1, 'From', False]  -0.0 | -0.02551 0.10477 -0.07925
# [0, 1, 'To', False]  0.0 | -0.03599 0.17376 -0.13778
# [0, 1, 'MeanColumns', False]  0.0 | -0.02904 0.11761 -0.08857
# [0, 1, 'MaxColumns', False]  0.0 | -0.02805 0.11327 -0.08522
# [0, 2, 'From', False]  0.0 | -0.03126 0.17472 -0.14346
# [0, 2, 'To', False]  0.0 | -0.02457 0.15692 -0.13234
# [0, 2, 'MeanColumns', False]  -0.0 | -0.02355 0.05813 -0.03458
# [0, 2, 'MaxColumns', False]  0.0 | -0.03055 0.08754 -0.05699
# [0, 3, 'From', False]  -0.0 | -0.03784 0.17763 -0.13979
# [0, 3, 'To', False]  -0.0 | -0.02454 0.06081 -0.03627
# [0, 3, 'MeanColumns', False]  -0.0 | -0.01584 0.06865 -0.0528
# [0, 3, 'MaxColumns', False]  -0.0 | -0.01506 0.07593 -0.06087
# [0, 4, 'From', False]  0.0 | -0.01426 0.04381 -0.02955
# [0, 4, 'To', False]  -0.0 | -0.03836 0.1782 -0.13984
# [0, 4, 'MeanColumns', False]  -0.0 | -0.02004 0.09544 -0.0754
# [0, 4, 'MaxColumns', False]  0.0 | -0.02369 0.10808 -0.08439
# [0, 5, 'From', False]  0.0 | -0.0104 0.0407 -0.0303
# [0, 5, 'To', False]  -0.0 | -0.01209 0.03954 -0.02745
# [0, 5, 'MeanColumns', False]  0.0 | -0.0096 0.05252 -0.04292
# [0, 5, 'MaxColumns', False]  0.0 | -0.01073 0.08004 -0.06931
# [0, 6, 'From', False]  0.0 | -0.02664 0.11343 -0.08679
# [0, 6, 'To', False]  -0.0 | -0.03371 0.17589 -0.14218
# [0, 6, 'MeanColumns', False]  -0.0 | -0.02558 0.11833 -0.09275
# [0, 6, 'MaxColumns', False]  0.0 | -0.00842 0.07739 -0.06896
# [0, 7, 'From', False]  -0.0 | -0.00737 0.03996 -0.03259
# [0, 7, 'To', False]  -0.0 | -0.00571 0.04212 -0.03641
# [0, 7, 'MeanColumns', False]  0.0 | -0.02693 0.09129 -0.06436
# [0, 7, 'MaxColumns', False]  -0.0 | -0.00524 0.04073 -0.03549
# [0, 8, 'From', False]  0.0 | -0.02307 0.09547 -0.0724
# [0, 8, 'To', False]  -0.0 | -0.01951 0.16668 -0.14717
# [0, 8, 'MeanColumns', False]  -0.0 | -0.02631 0.09457 -0.06827
# [0, 8, 'MaxColumns', False]  0.0 | -0.01752 0.08152 -0.064
# [0, 9, 'From', False]  -0.0 | -0.01274 0.05908 -0.04635
# [0, 9, 'To', False]  -0.0 | -0.00792 0.08634 -0.07842
# [0, 9, 'MeanColumns', False]  -0.0 | -0.01652 0.06705 -0.05053
# [0, 9, 'MaxColumns', False]  0.0 | -0.01158 0.08274 -0.07116
# [0, 10, 'From', False]  -0.0 | -0.00963 0.04583 -0.03619
# [0, 10, 'To', False]  0.0 | -0.00786 0.05996 -0.05211
# [0, 10, 'MeanColumns', False]  -0.0 | -0.01417 0.06507 -0.0509
# [0, 10, 'MaxColumns', False]  0.0 | -0.01075 0.07054 -0.0598
# [0, 11, 'From', False]  0.0 | -0.0288 0.15554 -0.12673
# [0, 11, 'To', False]  0.0 | -0.02618 0.1608 -0.13462
# [0, 11, 'MeanColumns', False]  -0.0 | -0.01588 0.0423 -0.02643
# [0, 11, 'MaxColumns', False]  0.0 | -0.01494 0.10962 -0.09468
# [1, 'Mean', 'From', False]  0.0 | -0.00596 0.1319 -0.12594
# [1, 'Mean', 'To', False]  0.0 | -0.01041 0.02715 -0.01673
# [1, 'Mean', 'MeanColumns', False]  0.0 | 0.00083 0.0959 -0.09673
# [1, 'Mean', 'MaxColumns', False]  0.0 | 0.00691 0.0928 -0.09971
# [1, 0, 'From', False]  -0.0 | -0.00616 0.13923 -0.13307
# [1, 0, 'To', False]  0.0 | -0.03165 0.17033 -0.13868
# [1, 0, 'MeanColumns', False]  0.0 | 0.01567 0.10234 -0.118
# [1, 0, 'MaxColumns', False]  0.0 | 0.00941 0.11707 -0.12648
# [1, 1, 'From', False]  -0.0 | -0.01166 0.13213 -0.12047
# [1, 1, 'To', False]  -0.0 | -0.03378 0.17935 -0.14556
# [1, 1, 'MeanColumns', False]  0.0 | -0.02802 0.11577 -0.08774
# [1, 1, 'MaxColumns', False]  0.0 | -0.01241 0.13241 -0.12
# [1, 2, 'From', False]  0.0 | -0.02248 0.16719 -0.14471
# [1, 2, 'To', False]  0.0 | -0.01432 0.11718 -0.10286
# [1, 2, 'MeanColumns', False]  0.0 | -0.01689 0.09065 -0.07376
# [1, 2, 'MaxColumns', False]  -0.0 | -0.00627 0.09869 -0.09242
# [1, 3, 'From', False]  0.0 | -0.02736 0.17112 -0.14375
# [1, 3, 'To', False]  -0.0 | -0.00983 0.02311 -0.01328
# [1, 3, 'MeanColumns', False]  -0.0 | -0.02674 0.08259 -0.05585
# [1, 3, 'MaxColumns', False]  -0.0 | -0.01662 0.09417 -0.07754
# [1, 4, 'From', False]  -0.0 | -0.00338 0.08065 -0.07726
# [1, 4, 'To', False]  -0.0 | -0.03836 0.1782 -0.13984
# [1, 4, 'MeanColumns', False]  -0.0 | -0.0189 0.06889 -0.04999
# [1, 4, 'MaxColumns', False]  0.0 | -0.01646 0.09421 -0.07775
# [1, 5, 'From', False]  0.0 | 0.00442 0.09309 -0.09751
# [1, 5, 'To', False]  0.0 | -0.02248 0.11369 -0.09121
# [1, 5, 'MeanColumns', False]  0.0 | -0.0023 0.08624 -0.08393
# [1, 5, 'MaxColumns', False]  0.0 | -0.0034 0.10204 -0.09865
# [1, 6, 'From', False]  0.0 | -8e-05 0.13543 -0.13534
# [1, 6, 'To', False]  0.0 | -0.02677 0.17709 -0.15032
# [1, 6, 'MeanColumns', False]  0.0 | -0.00011 0.07122 -0.07111
# [1, 6, 'MaxColumns', False]  0.0 | -0.00284 0.08467 -0.08183
# [1, 7, 'From', False]  0.0 | -0.02695 0.04694 -0.01999
# [1, 7, 'To', False]  0.0 | -0.00744 0.02156 -0.01412
# [1, 7, 'MeanColumns', False]  -0.0 | -0.03645 0.09434 -0.05789
# [1, 7, 'MaxColumns', False]  -0.0 | -0.01157 0.05394 -0.04237
# [1, 8, 'From', False]  0.0 | -0.01741 0.14792 -0.13051
# [1, 8, 'To', False]  -0.0 | -0.03221 0.16193 -0.12972
# [1, 8, 'MeanColumns', False]  0.0 | -0.01493 0.10138 -0.08645
# [1, 8, 'MaxColumns', False]  -0.0 | -0.01535 0.09739 -0.08204
# [1, 9, 'From', False]  0.0 | -0.02348 0.11458 -0.0911
# [1, 9, 'To', False]  -0.0 | -0.02567 0.14958 -0.12391
# [1, 9, 'MeanColumns', False]  -0.0 | -0.011 0.11229 -0.10129
# [1, 9, 'MaxColumns', False]  0.0 | -0.00659 0.08764 -0.08105
# [1, 10, 'From', False]  0.0 | -0.04261 0.09208 -0.04948
# [1, 10, 'To', False]  0.0 | -0.02226 0.05014 -0.02788
# [1, 10, 'MeanColumns', False]  -0.0 | -0.01404 0.06854 -0.0545
# [1, 10, 'MaxColumns', False]  0.0 | -0.01838 0.06491 -0.04654
# [1, 11, 'From', False]  -0.0 | -0.01715 0.15537 -0.13822
# [1, 11, 'To', False]  -0.0 | -0.01234 0.04104 -0.0287
# [1, 11, 'MeanColumns', False]  -0.0 | -0.00277 0.07962 -0.07685
# [1, 11, 'MaxColumns', False]  0.0 | 0.01822 0.1131 -0.13133
# [2, 'Mean', 'From', False]  0.0 | -0.0178 0.10315 -0.08535
# [2, 'Mean', 'To', False]  -0.0 | -0.00991 0.02525 -0.01534
# [2, 'Mean', 'MeanColumns', False]  -0.0 | -0.0263 0.08923 -0.06293
# [2, 'Mean', 'MaxColumns', False]  -0.0 | -0.00118 0.06944 -0.06826
# [2, 0, 'From', False]  -0.0 | -0.01339 0.12027 -0.10688
# [2, 0, 'To', False]  -0.0 | -0.03032 0.16299 -0.13267
# [2, 0, 'MeanColumns', False]  0.0 | -0.01514 0.0797 -0.06456
# [2, 0, 'MaxColumns', False]  0.0 | -0.00677 0.08602 -0.07925
# [2, 1, 'From', False]  0.0 | -0.02287 0.07856 -0.05569
# [2, 1, 'To', False]  0.0 | -0.0341 0.17527 -0.14116
# [2, 1, 'MeanColumns', False]  0.0 | -0.0226 0.09805 -0.07545
# [2, 1, 'MaxColumns', False]  0.0 | -0.01438 0.1111 -0.09672
# [2, 2, 'From', False]  0.0 | -0.02294 0.13884 -0.1159
# [2, 2, 'To', False]  -0.0 | -0.00915 0.02441 -0.01526
# [2, 2, 'MeanColumns', False]  0.0 | -0.00298 0.09468 -0.09171
# [2, 2, 'MaxColumns', False]  0.0 | 0.00078 0.10269 -0.10347
# [2, 3, 'From', False]  0.0 | -0.01361 0.13492 -0.12131
# [2, 3, 'To', False]  -0.0 | -0.0093 0.02293 -0.01364
# [2, 3, 'MeanColumns', False]  0.0 | -0.0258 0.087 -0.0612
# [2, 3, 'MaxColumns', False]  -0.0 | -0.01742 0.09434 -0.07691
# [2, 4, 'From', False]  -0.0 | -0.01028 0.02383 -0.01355
# [2, 4, 'To', False]  0.0 | -0.03828 0.17811 -0.13983
# [2, 4, 'MeanColumns', False]  0.0 | -0.01706 0.08013 -0.06308
# [2, 4, 'MaxColumns', False]  0.0 | -0.00826 0.07946 -0.0712
# [2, 5, 'From', False]  -0.0 | -0.02143 0.10588 -0.08445
# [2, 5, 'To', False]  -0.0 | -0.02001 0.09701 -0.07699
# [2, 5, 'MeanColumns', False]  0.0 | -0.02855 0.0968 -0.06824
# [2, 5, 'MaxColumns', False]  -0.0 | -0.02308 0.08738 -0.0643
# [2, 6, 'From', False]  0.0 | -0.00348 0.03207 -0.02858
# [2, 6, 'To', False]  -0.0 | -0.02776 0.12855 -0.10079
# [2, 6, 'MeanColumns', False]  0.0 | -0.01177 0.07449 -0.06272
# [2, 6, 'MaxColumns', False]  0.0 | -0.00282 0.078 -0.07518
# [2, 7, 'From', False]  -0.0 | -0.02389 0.10994 -0.08605
# [2, 7, 'To', False]  -0.0 | -0.00857 0.03569 -0.02712
# [2, 7, 'MeanColumns', False]  0.0 | -0.05755 0.11696 -0.05942
# [2, 7, 'MaxColumns', False]  0.0 | -0.00699 0.05683 -0.04984
# [2, 8, 'From', False]  -0.0 | -0.01734 0.06756 -0.05023
# [2, 8, 'To', False]  -0.0 | -0.01671 0.06634 -0.04963
# [2, 8, 'MeanColumns', False]  0.0 | -0.02501 0.08741 -0.0624
# [2, 8, 'MaxColumns', False]  0.0 | -0.02268 0.10875 -0.08607
# [2, 9, 'From', False]  0.0 | -0.02853 0.12249 -0.09396
# [2, 9, 'To', False]  0.0 | -0.02668 0.11532 -0.08864
# [2, 9, 'MeanColumns', False]  0.0 | -0.03827 0.10224 -0.06397
# [2, 9, 'MaxColumns', False]  -0.0 | -0.02324 0.06892 -0.04568
# [2, 10, 'From', False]  -0.0 | -0.0379 0.09682 -0.05892
# [2, 10, 'To', False]  0.0 | -0.02088 0.08926 -0.06838
# [2, 10, 'MeanColumns', False]  -0.0 | -0.02639 0.06263 -0.03624
# [2, 10, 'MaxColumns', False]  0.0 | -0.0172 0.05379 -0.03659
# [2, 11, 'From', False]  0.0 | -0.0265 0.13764 -0.11114
# [2, 11, 'To', False]  -0.0 | -0.00984 0.02677 -0.01693
# [2, 11, 'MeanColumns', False]  -0.0 | -0.01394 0.04748 -0.03354
# [2, 11, 'MaxColumns', False]  0.0 | -0.00922 0.1054 -0.09617
# [3, 'Mean', 'From', False]  0.0 | -0.00771 0.09539 -0.08768
# [3, 'Mean', 'To', False]  -0.0 | -0.00951 0.02484 -0.01533
# [3, 'Mean', 'MeanColumns', False]  0.0 | -0.0328 0.09898 -0.06619
# [3, 'Mean', 'MaxColumns', False]  0.0 | -0.01333 0.0621 -0.04876
# [3, 0, 'From', False]  -0.0 | -0.01437 0.12737 -0.11299
# [3, 0, 'To', False]  0.0 | -0.04012 0.163 -0.12288
# [3, 0, 'MeanColumns', False]  0.0 | -0.00892 0.10221 -0.09329
# [3, 0, 'MaxColumns', False]  0.0 | 0.00832 0.10122 -0.10953
# [3, 1, 'From', False]  -0.0 | -0.02782 0.08984 -0.06202
# [3, 1, 'To', False]  0.0 | -0.02775 0.18275 -0.155
# [3, 1, 'MeanColumns', False]  -0.0 | -0.00849 0.10985 -0.10137
# [3, 1, 'MaxColumns', False]  0.0 | 0.00589 0.12836 -0.13425
# [3, 2, 'From', False]  0.0 | -0.01576 0.15687 -0.14111
# [3, 2, 'To', False]  -0.0 | -0.01046 0.03183 -0.02137
# [3, 2, 'MeanColumns', False]  0.0 | 0.00557 0.09552 -0.10108
# [3, 2, 'MaxColumns', False]  0.0 | 0.00306 0.10337 -0.10642
# [3, 3, 'From', False]  0.0 | 0.00803 0.11617 -0.1242
# [3, 3, 'To', False]  -0.0 | -0.00972 0.02343 -0.01371
# [3, 3, 'MeanColumns', False]  0.0 | -0.02568 0.09464 -0.06896
# [3, 3, 'MaxColumns', False]  -0.0 | -0.02609 0.0966 -0.07051
# [3, 4, 'From', False]  -0.0 | -0.00935 0.02302 -0.01367
# [3, 4, 'To', False]  0.0 | -0.03846 0.1775 -0.13904
# [3, 4, 'MeanColumns', False]  -0.0 | -0.02081 0.1272 -0.10639
# [3, 4, 'MaxColumns', False]  -0.0 | -0.01736 0.11783 -0.10047
# [3, 5, 'From', False]  -0.0 | -0.02207 0.10834 -0.08626
# [3, 5, 'To', False]  0.0 | -0.02298 0.10389 -0.08091
# [3, 5, 'MeanColumns', False]  -0.0 | -0.03624 0.08552 -0.04928
# [3, 5, 'MaxColumns', False]  0.0 | -0.03124 0.07725 -0.04601
# [3, 6, 'From', False]  -0.0 | -0.00649 0.02434 -0.01785
# [3, 6, 'To', False]  0.0 | -0.02256 0.09707 -0.07451
# [3, 6, 'MeanColumns', False]  -0.0 | -0.01487 0.05549 -0.04062
# [3, 6, 'MaxColumns', False]  -0.0 | -0.01291 0.06183 -0.04892
# [3, 7, 'From', False]  0.0 | -0.02626 0.09616 -0.06991
# [3, 7, 'To', False]  0.0 | -0.01255 0.05166 -0.03911
# [3, 7, 'MeanColumns', False]  0.0 | -0.08514 0.12836 -0.04322
# [3, 7, 'MaxColumns', False]  0.0 | -0.0411 0.0724 -0.0313
# [3, 8, 'From', False]  0.0 | -0.00939 0.04085 -0.03146
# [3, 8, 'To', False]  0.0 | -0.01376 0.07972 -0.06596
# [3, 8, 'MeanColumns', False]  0.0 | -0.02435 0.07974 -0.05539
# [3, 8, 'MaxColumns', False]  0.0 | -0.02061 0.08987 -0.06927
# [3, 9, 'From', False]  0.0 | -0.02502 0.12222 -0.09719
# [3, 9, 'To', False]  0.0 | -0.02586 0.12228 -0.09642
# [3, 9, 'MeanColumns', False]  0.0 | -0.0499 0.09086 -0.04096
# [3, 9, 'MaxColumns', False]  -0.0 | -0.03782 0.07503 -0.03722
# [3, 10, 'From', False]  -0.0 | -0.02166 0.08769 -0.06604
# [3, 10, 'To', False]  0.0 | -0.0352 0.11321 -0.07801
# [3, 10, 'MeanColumns', False]  0.0 | -0.02414 0.07547 -0.05133
# [3, 10, 'MaxColumns', False]  -0.0 | -0.02098 0.07274 -0.05176
# [3, 11, 'From', False]  0.0 | -0.02233 0.14095 -0.11862
# [3, 11, 'To', False]  -0.0 | -0.01821 0.06849 -0.05028
# [3, 11, 'MeanColumns', False]  0.0 | -0.0181 0.08188 -0.06378
# [3, 11, 'MaxColumns', False]  0.0 | -0.01482 0.09929 -0.08447
# [4, 'Mean', 'From', False]  0.0 | 0.03334 0.09603 -0.12937
# [4, 'Mean', 'To', False]  -0.0 | -0.01803 0.05846 -0.04043
# [4, 'Mean', 'MeanColumns', False]  0.0 | 0.00757 0.08149 -0.08905
# [4, 'Mean', 'MaxColumns', False]  0.0 | 0.00889 0.06353 -0.07243
# [4, 0, 'From', False]  0.0 | 0.03784 0.11755 -0.15539
# [4, 0, 'To', False]  -0.0 | -0.04209 0.14417 -0.10208
# [4, 0, 'MeanColumns', False]  0.0 | 0.02977 0.09598 -0.12575
# [4, 0, 'MaxColumns', False]  0.0 | 0.03753 0.10144 -0.13897
# [4, 1, 'From', False]  0.0 | 0.0015 0.09924 -0.10074
# [4, 1, 'To', False]  0.0 | -0.02549 0.16587 -0.14039
# [4, 1, 'MeanColumns', False]  0.0 | -0.00969 0.1081 -0.09841
# [4, 1, 'MaxColumns', False]  0.0 | 0.01497 0.10831 -0.12328
# [4, 2, 'From', False]  0.0 | -0.00515 0.16389 -0.15874
# [4, 2, 'To', False]  0.0 | -0.03883 0.12954 -0.09071
# [4, 2, 'MeanColumns', False]  -0.0 | 0.01714 0.07379 -0.09094
# [4, 2, 'MaxColumns', False]  -0.0 | 0.0106 0.09143 -0.10203
# [4, 3, 'From', False]  0.0 | 0.06376 0.02993 -0.09369
# [4, 3, 'To', False]  -0.0 | -0.00994 0.02366 -0.01372
# [4, 3, 'MeanColumns', False]  0.0 | -0.01909 0.07092 -0.05183
# [4, 3, 'MaxColumns', False]  -0.0 | -0.02224 0.07311 -0.05087
# [4, 4, 'From', False]  -0.0 | -0.00359 0.02221 -0.01862
# [4, 4, 'To', False]  0.0 | -0.0245 0.16763 -0.14313
# [4, 4, 'MeanColumns', False]  -0.0 | -0.02449 0.07855 -0.05406
# [4, 4, 'MaxColumns', False]  0.0 | -0.01929 0.07443 -0.05514
# [4, 5, 'From', False]  0.0 | 0.00531 0.06674 -0.07205
# [4, 5, 'To', False]  0.0 | -0.01922 0.08397 -0.06474
# [4, 5, 'MeanColumns', False]  0.0 | 0.00231 0.08535 -0.08766
# [4, 5, 'MaxColumns', False]  0.0 | -0.00825 0.08439 -0.07614
# [4, 6, 'From', False]  0.0 | 0.01898 0.06811 -0.08709
# [4, 6, 'To', False]  0.0 | -0.02328 0.1403 -0.11702
# [4, 6, 'MeanColumns', False]  0.0 | -0.01343 0.06685 -0.05342
# [4, 6, 'MaxColumns', False]  0.0 | -0.00958 0.06461 -0.05503
# [4, 7, 'From', False]  -0.0 | -0.02781 0.09095 -0.06314
# [4, 7, 'To', False]  0.0 | -0.01959 0.08849 -0.0689
# [4, 7, 'MeanColumns', False]  -0.0 | -0.08388 0.14611 -0.06222
# [4, 7, 'MaxColumns', False]  -0.0 | -0.0393 0.07988 -0.04058
# [4, 8, 'From', False]  -0.0 | -0.01213 0.06175 -0.04962
# [4, 8, 'To', False]  0.0 | -0.00982 0.07471 -0.06489
# [4, 8, 'MeanColumns', False]  0.0 | -0.01109 0.03843 -0.02734
# [4, 8, 'MaxColumns', False]  0.0 | -0.02782 0.11964 -0.09182
# [4, 9, 'From', False]  0.0 | 0.00212 0.10029 -0.10241
# [4, 9, 'To', False]  0.0 | -0.02737 0.10444 -0.07706
# [4, 9, 'MeanColumns', False]  0.0 | -0.01851 0.06248 -0.04397
# [4, 9, 'MaxColumns', False]  -0.0 | -0.02391 0.08319 -0.05929
# [4, 10, 'From', False]  0.0 | -0.01106 0.07666 -0.0656
# [4, 10, 'To', False]  -0.0 | -0.04251 0.10232 -0.05981
# [4, 10, 'MeanColumns', False]  0.0 | -0.02955 0.10589 -0.07634
# [4, 10, 'MaxColumns', False]  0.0 | -0.02783 0.10348 -0.07564
# [4, 11, 'From', False]  -0.0 | -0.00678 0.06375 -0.05697
# [4, 11, 'To', False]  -0.0 | -0.02118 0.06936 -0.04818
# [4, 11, 'MeanColumns', False]  -0.0 | 0.00667 0.0372 -0.04386
# [4, 11, 'MaxColumns', False]  0.0 | 0.02208 0.09873 -0.12082
# [5, 'Mean', 'From', False]  -0.0 | 0.04971 0.09181 -0.14153
# [5, 'Mean', 'To', False]  -0.0 | -0.0135 0.09576 -0.08227
# [5, 'Mean', 'MeanColumns', False]  0.0 | 0.04844 0.06508 -0.11351
# [5, 'Mean', 'MaxColumns', False]  -0.0 | 0.00214 0.06757 -0.06971
# [5, 0, 'From', False]  0.0 | 0.06988 0.09048 -0.16037
# [5, 0, 'To', False]  0.0 | -0.02748 0.16634 -0.13886
# [5, 0, 'MeanColumns', False]  0.0 | 0.05368 0.04443 -0.09811
# [5, 0, 'MaxColumns', False]  0.0 | 0.05726 0.05494 -0.11221
# [5, 1, 'From', False]  -0.0 | 0.00101 0.1183 -0.11931
# [5, 1, 'To', False]  -0.0 | -0.03033 0.17188 -0.14155
# [5, 1, 'MeanColumns', False]  -0.0 | 0.00322 0.09994 -0.10316
# [5, 1, 'MaxColumns', False]  -0.0 | 0.0233 0.11439 -0.13769
# [5, 2, 'From', False]  0.0 | 0.00489 0.15037 -0.15526
# ...
# [0, 10, 'To', False]  0.25307 | 0.27221 0.23499 0.25201
# [0, 10, 'MeanColumns', False]  0.20885 | 0.19454 0.14583 0.28618
# [0, 10, 'MaxColumns', False]  0.23256 | 0.2157 0.17894 0.30304
# [0, 11, 'From', False]  0.30051 | 0.30377 0.19739 0.40038
# [0, 11, 'To', False]  0.43638 | 0.42211 0.3513 0.53572
# [0, 11, 'MeanColumns', False]  0.20364 | 0.19889 0.16039 0.25163
# [0, 11, 'MaxColumns', False]  0.25898 | 0.26614 0.18325 0.32755
# [1, 'Mean', 'From', False]  0.37789 | 0.41077 0.30375 0.41917
# [1, 'Mean', 'To', False]  0.18299 | 0.18337 0.11143 0.25416
# [1, 'Mean', 'MeanColumns', False]  0.3268 | 0.37504 0.27796 0.3274
# [1, 'Mean', 'MaxColumns', False]  0.33438 | 0.38171 0.2743 0.34714
# [1, 0, 'From', False]  0.38339 | 0.41338 0.28355 0.45323
# [1, 0, 'To', False]  0.31924 | 0.30802 0.19207 0.45763
# [1, 0, 'MeanColumns', False]  0.36388 | 0.40263 0.33137 0.35766
# [1, 0, 'MaxColumns', False]  0.36052 | 0.39592 0.30546 0.38018
# [1, 1, 'From', False]  0.37044 | 0.39809 0.29986 0.41337
# [1, 1, 'To', False]  0.34517 | 0.35114 0.21821 0.46615
# [1, 1, 'MeanColumns', False]  0.32316 | 0.34233 0.26814 0.359
# [1, 1, 'MaxColumns', False]  0.34958 | 0.3625 0.28347 0.40277
# [1, 2, 'From', False]  0.39205 | 0.4156 0.25536 0.50518
# [1, 2, 'To', False]  0.28665 | 0.3006 0.18195 0.37741
# [1, 2, 'MeanColumns', False]  0.27514 | 0.28831 0.2401 0.297
# [1, 2, 'MaxColumns', False]  0.30917 | 0.33265 0.26295 0.33192
# [1, 3, 'From', False]  0.35145 | 0.37853 0.22579 0.45004
# [1, 3, 'To', False]  0.23145 | 0.21995 0.18317 0.29123
# [1, 3, 'MeanColumns', False]  0.24185 | 0.25136 0.20091 0.27329
# [1, 3, 'MaxColumns', False]  0.28866 | 0.30752 0.24591 0.31254
# [1, 4, 'From', False]  0.34037 | 0.34082 0.31866 0.36164
# [1, 4, 'To', False]  0.27787 | 0.27999 0.16885 0.38477
# [1, 4, 'MeanColumns', False]  0.27997 | 0.27866 0.25158 0.30968
# [1, 4, 'MaxColumns', False]  0.31789 | 0.31552 0.2759 0.36225
# [1, 5, 'From', False]  0.42898 | 0.42326 0.44063 0.42306
# [1, 5, 'To', False]  0.18114 | 0.1873 0.11281 0.24331
# [1, 5, 'MeanColumns', False]  0.34427 | 0.36827 0.28052 0.38402
# [1, 5, 'MaxColumns', False]  0.35448 | 0.37503 0.28847 0.39995
# [1, 6, 'From', False]  0.36171 | 0.3902 0.28155 0.41337
# [1, 6, 'To', False]  0.38127 | 0.38678 0.26933 0.48772
# [1, 6, 'MeanColumns', False]  0.2944 | 0.32993 0.23639 0.3169
# [1, 6, 'MaxColumns', False]  0.27733 | 0.30444 0.21752 0.31003
# [1, 7, 'From', False]  0.18377 | 0.19164 0.15556 0.20411
# [1, 7, 'To', False]  0.16324 | 0.17233 0.09963 0.21776
# [1, 7, 'MeanColumns', False]  0.20197 | 0.20629 0.12993 0.26968
# [1, 7, 'MaxColumns', False]  0.20051 | 0.20342 0.1313 0.2668
# [1, 8, 'From', False]  0.43501 | 0.44816 0.34341 0.51346
# [1, 8, 'To', False]  0.28969 | 0.28708 0.20528 0.37671
# [1, 8, 'MeanColumns', False]  0.32642 | 0.32073 0.28824 0.37028
# [1, 8, 'MaxColumns', False]  0.28557 | 0.28119 0.21703 0.35849
# [1, 9, 'From', False]  0.31646 | 0.33322 0.26359 0.35256
# [1, 9, 'To', False]  0.24913 | 0.24362 0.17952 0.32425
# [1, 9, 'MeanColumns', False]  0.31285 | 0.35998 0.22597 0.35259
# [1, 9, 'MaxColumns', False]  0.28838 | 0.33387 0.20294 0.32832
# [1, 10, 'From', False]  0.24157 | 0.25828 0.21424 0.2522
# [1, 10, 'To', False]  0.17874 | 0.17918 0.12673 0.23033
# [1, 10, 'MeanColumns', False]  0.26381 | 0.27802 0.223 0.29041
# [1, 10, 'MaxColumns', False]  0.25201 | 0.26873 0.2039 0.28338
# [1, 11, 'From', False]  0.43345 | 0.4567 0.2933 0.55036
# [1, 11, 'To', False]  0.19461 | 0.20661 0.12823 0.24899
# [1, 11, 'MeanColumns', False]  0.24892 | 0.27803 0.2037 0.26502
# [1, 11, 'MaxColumns', False]  0.33656 | 0.38511 0.26551 0.35906
# [2, 'Mean', 'From', False]  0.34885 | 0.34473 0.33878 0.36304
# [2, 'Mean', 'To', False]  0.20148 | 0.19968 0.13132 0.27345
# [2, 'Mean', 'MeanColumns', False]  0.28638 | 0.29821 0.26273 0.29818
# [2, 'Mean', 'MaxColumns', False]  0.30925 | 0.33782 0.28245 0.30748
# [2, 0, 'From', False]  0.33521 | 0.34525 0.26826 0.39212
# [2, 0, 'To', False]  0.29653 | 0.27747 0.17783 0.4343
# [2, 0, 'MeanColumns', False]  0.27529 | 0.28734 0.2579 0.28062
# [2, 0, 'MaxColumns', False]  0.29652 | 0.31659 0.26819 0.30477
# [2, 1, 'From', False]  0.3008 | 0.28388 0.30084 0.3177
# [2, 1, 'To', False]  0.34278 | 0.34365 0.21244 0.47226
# [2, 1, 'MeanColumns', False]  0.29879 | 0.29779 0.25162 0.34695
# [2, 1, 'MaxColumns', False]  0.34617 | 0.34058 0.31193 0.38601
# [2, 2, 'From', False]  0.35537 | 0.34255 0.2862 0.43736
# [2, 2, 'To', False]  0.20697 | 0.20447 0.14467 0.27176
# [2, 2, 'MeanColumns', False]  0.33282 | 0.34878 0.3154 0.33427
# [2, 2, 'MaxColumns', False]  0.35529 | 0.37155 0.33201 0.36232
# [2, 3, 'From', False]  0.31098 | 0.35264 0.20666 0.37365
# [2, 3, 'To', False]  0.19325 | 0.1917 0.14584 0.2422
# [2, 3, 'MeanColumns', False]  0.23771 | 0.25802 0.16834 0.28677
# [2, 3, 'MaxColumns', False]  0.27108 | 0.28781 0.20374 0.32168
# [2, 4, 'From', False]  0.19688 | 0.1971 0.16835 0.22518
# [2, 4, 'To', False]  0.27133 | 0.26831 0.16474 0.38094
# [2, 4, 'MeanColumns', False]  0.21877 | 0.22914 0.15206 0.2751
# [2, 4, 'MaxColumns', False]  0.23258 | 0.24295 0.16255 0.29224
# [2, 5, 'From', False]  0.33937 | 0.31926 0.34042 0.35843
# [2, 5, 'To', False]  0.23398 | 0.22979 0.15457 0.31759
# [2, 5, 'MeanColumns', False]  0.28571 | 0.2798 0.26507 0.31226
# [2, 5, 'MaxColumns', False]  0.26888 | 0.28218 0.22641 0.29805
# [2, 6, 'From', False]  0.2537 | 0.27347 0.19394 0.29369
# [2, 6, 'To', False]  0.34755 | 0.32418 0.30209 0.41639
# [2, 6, 'MeanColumns', False]  0.27693 | 0.29416 0.22697 0.30966
# [2, 6, 'MaxColumns', False]  0.27461 | 0.28995 0.22497 0.30891
# [2, 7, 'From', False]  0.32736 | 0.32063 0.33379 0.32766
# [2, 7, 'To', False]  0.1906 | 0.19898 0.1197 0.25311
# [2, 7, 'MeanColumns', False]  0.25967 | 0.26169 0.22391 0.29339
# [2, 7, 'MaxColumns', False]  0.24916 | 0.2647 0.20218 0.28059
# [2, 8, 'From', False]  0.3237 | 0.31766 0.28226 0.37119
# [2, 8, 'To', False]  0.26934 | 0.26599 0.21765 0.32438
# [2, 8, 'MeanColumns', False]  0.26707 | 0.25768 0.23168 0.31186
# [2, 8, 'MaxColumns', False]  0.25142 | 0.24275 0.20593 0.30557
# [2, 9, 'From', False]  0.31946 | 0.31241 0.30002 0.34595
# [2, 9, 'To', False]  0.29981 | 0.28165 0.26588 0.35189
# [2, 9, 'MeanColumns', False]  0.2718 | 0.26615 0.26489 0.28437
# [2, 9, 'MaxColumns', False]  0.24841 | 0.26014 0.23142 0.25367
# [2, 10, 'From', False]  0.278 | 0.29831 0.27303 0.26265
# [2, 10, 'To', False]  0.21319 | 0.22555 0.13064 0.28338
# [2, 10, 'MeanColumns', False]  0.22444 | 0.23414 0.18308 0.25609
# [2, 10, 'MaxColumns', False]  0.22488 | 0.23365 0.17732 0.26368
# [2, 11, 'From', False]  0.39395 | 0.3862 0.33687 0.45878
# [2, 11, 'To', False]  0.19526 | 0.20136 0.14963 0.23478
# [2, 11, 'MeanColumns', False]  0.21312 | 0.22286 0.16683 0.24967
# [2, 11, 'MaxColumns', False]  0.28703 | 0.32124 0.20911 0.33076
# [3, 'Mean', 'From', False]  0.33834 | 0.35477 0.29641 0.36385
# [3, 'Mean', 'To', False]  0.22026 | 0.21849 0.15057 0.29172
# [3, 'Mean', 'MeanColumns', False]  0.28853 | 0.31066 0.2682 0.28673
# [3, 'Mean', 'MaxColumns', False]  0.28766 | 0.28957 0.28044 0.29297
# [3, 0, 'From', False]  0.35568 | 0.36079 0.28098 0.42528
# [3, 0, 'To', False]  0.34902 | 0.31185 0.22694 0.50827
# [3, 0, 'MeanColumns', False]  0.34176 | 0.37106 0.33443 0.31981
# [3, 0, 'MaxColumns', False]  0.34932 | 0.37645 0.32693 0.34457
# [3, 1, 'From', False]  0.30014 | 0.28876 0.2898 0.32188
# [3, 1, 'To', False]  0.32648 | 0.33954 0.19557 0.44432
# [3, 1, 'MeanColumns', False]  0.37477 | 0.3874 0.34306 0.39384
# [3, 1, 'MaxColumns', False]  0.4269 | 0.41592 0.42116 0.44362
# [3, 2, 'From', False]  0.35752 | 0.36599 0.24633 0.46024
# [3, 2, 'To', False]  0.19358 | 0.1993 0.13003 0.25142
# [3, 2, 'MeanColumns', False]  0.38868 | 0.39245 0.42161 0.35198
# [3, 2, 'MaxColumns', False]  0.38411 | 0.38358 0.40368 0.36506
# [3, 3, 'From', False]  0.3605 | 0.43537 0.26495 0.38118
# [3, 3, 'To', False]  0.19873 | 0.18873 0.15499 0.25246
# [3, 3, 'MeanColumns', False]  0.27683 | 0.26923 0.2505 0.31075
# [3, 3, 'MaxColumns', False]  0.27283 | 0.25349 0.24714 0.31786
# [3, 4, 'From', False]  0.21278 | 0.22032 0.18719 0.23084
# [3, 4, 'To', False]  0.26688 | 0.26544 0.1726 0.36259
# [3, 4, 'MeanColumns', False]  0.33088 | 0.30625 0.30403 0.38236
# [3, 4, 'MaxColumns', False]  0.31418 | 0.29402 0.25991 0.3886
# [3, 5, 'From', False]  0.3303 | 0.33545 0.29534 0.36009
# [3, 5, 'To', False]  0.28856 | 0.27728 0.23669 0.3517
# [3, 5, 'MeanColumns', False]  0.2169 | 0.23021 0.17459 0.2459
# [3, 5, 'MaxColumns', False]  0.21265 | 0.23131 0.15886 0.24777
# [3, 6, 'From', False]  0.26601 | 0.27876 0.22138 0.29788
# [3, 6, 'To', False]  0.28736 | 0.27899 0.23786 0.34524
# [3, 6, 'MeanColumns', False]  0.24713 | 0.25946 0.19649 0.28543
# [3, 6, 'MaxColumns', False]  0.245 | 0.25467 0.19596 0.28438
# [3, 7, 'From', False]  0.26916 | 0.2667 0.24818 0.2926
# [3, 7, 'To', False]  0.21069 | 0.21342 0.15239 0.26626
# [3, 7, 'MeanColumns', False]  0.16339 | 0.17 0.10502 0.21514
# [3, 7, 'MaxColumns', False]  0.16996 | 0.17985 0.11003 0.21998
# [3, 8, 'From', False]  0.32168 | 0.32346 0.2711 0.37049
# [3, 8, 'To', False]  0.2693 | 0.27834 0.21263 0.31694
# [3, 8, 'MeanColumns', False]  0.25343 | 0.24019 0.22196 0.29813
# [3, 8, 'MaxColumns', False]  0.28141 | 0.25394 0.25206 0.33823
# [3, 9, 'From', False]  0.32791 | 0.32652 0.30935 0.34785
# [3, 9, 'To', False]  0.31947 | 0.30925 0.29517 0.35398
# [3, 9, 'MeanColumns', False]  0.20969 | 0.2279 0.15391 0.24726
# [3, 9, 'MaxColumns', False]  0.20598 | 0.23407 0.14437 0.23949
# [3, 10, 'From', False]  0.29552 | 0.30855 0.32658 0.25142
# [3, 10, 'To', False]  0.24757 | 0.25281 0.16856 0.32135
# [3, 10, 'MeanColumns', False]  0.19965 | 0.21094 0.13428 0.25373
# [3, 10, 'MaxColumns', False]  0.19607 | 0.20461 0.12362 0.25997
# [3, 11, 'From', False]  0.42652 | 0.41042 0.39893 0.47022
# [3, 11, 'To', False]  0.25923 | 0.2767 0.22907 0.27191
# [3, 11, 'MeanColumns', False]  0.30734 | 0.30035 0.29735 0.32433
# [3, 11, 'MaxColumns', False]  0.35278 | 0.34552 0.33028 0.38255
# [4, 'Mean', 'From', False]  0.42221 | 0.47673 0.42045 0.36944
# [4, 'Mean', 'To', False]  0.27871 | 0.26479 0.23851 0.33282
# [4, 'Mean', 'MeanColumns', False]  0.30677 | 0.36609 0.25832 0.29591
# [4, 'Mean', 'MaxColumns', False]  0.30261 | 0.35529 0.26581 0.28674
# [4, 0, 'From', False]  0.50728 | 0.55957 0.51207 0.45021
# [4, 0, 'To', False]  0.32825 | 0.25278 0.26677 0.46521
# [4, 0, 'MeanColumns', False]  0.40223 | 0.45872 0.41858 0.32938
# [4, 0, 'MaxColumns', False]  0.40243 | 0.46477 0.39778 0.34475
# [4, 1, 'From', False]  0.38454 | 0.39901 0.38033 0.37427
# [4, 1, 'To', False]  0.32583 | 0.31802 0.2127 0.44678
# [4, 1, 'MeanColumns', False]  0.31311 | 0.33909 0.25568 0.34456
# [4, 1, 'MaxColumns', False]  0.35151 | 0.37426 0.31786 0.36242
# [4, 2, 'From', False]  0.34492 | 0.39176 0.22985 0.41314
# [4, 2, 'To', False]  0.27671 | 0.26643 0.2052 0.35852
# [4, 2, 'MeanColumns', False]  0.32767 | 0.37907 0.3172 0.28673
# [4, 2, 'MaxColumns', False]  0.33716 | 0.35465 0.34313 0.31371
# [4, 3, 'From', False]  0.37201 | 0.50519 0.30917 0.30168
# [4, 3, 'To', False]  0.21851 | 0.21472 0.16562 0.2752
# [4, 3, 'MeanColumns', False]  0.24996 | 0.26233 0.21097 0.27657
# [4, 3, 'MaxColumns', False]  0.25138 | 0.2551 0.20573 0.29332
# [4, 4, 'From', False]  0.26941 | 0.30196 0.23944 0.26682
# [4, 4, 'To', False]  0.28329 | 0.29059 0.18427 0.37501
# [4, 4, 'MeanColumns', False]  0.25215 | 0.25966 0.20652 0.29028
# [4, 4, 'MaxColumns', False]  0.2525 | 0.2586 0.19448 0.30443
# [4, 5, 'From', False]  0.39345 | 0.38294 0.41974 0.37768
# [4, 5, 'To', False]  0.30582 | 0.27576 0.28583 0.35586
# [4, 5, 'MeanColumns', False]  0.3008 | 0.34143 0.22996 0.331
# [4, 5, 'MaxColumns', False]  0.28286 | 0.32074 0.19621 0.33161
# [4, 6, 'From', False]  0.31985 | 0.38601 0.22417 0.34937
# [4, 6, 'To', False]  0.33783 | 0.33619 0.25818 0.41914
# [4, 6, 'MeanColumns', False]  0.21588 | 0.2301 0.14715 0.27039
# [4, 6, 'MaxColumns', False]  0.21174 | 0.22265 0.15065 0.26191
# [4, 7, 'From', False]  0.2524 | 0.24955 0.24868 0.25896
# [4, 7, 'To', False]  0.28568 | 0.27637 0.27004 0.31062
# [4, 7, 'MeanColumns', False]  0.18873 | 0.20595 0.11326 0.24698
# [4, 7, 'MaxColumns', False]  0.1846 | 0.20077 0.11072 0.24231
# [4, 8, 'From', False]  0.30469 | 0.31935 0.21529 0.37944
# [4, 8, 'To', False]  0.28584 | 0.32403 0.25664 0.27685
# [4, 8, 'MeanColumns', False]  0.1896 | 0.19126 0.12856 0.24898
# [4, 8, 'MaxColumns', False]  0.22594 | 0.21898 0.16271 0.29612
# [4, 9, 'From', False]  0.39263 | 0.42271 0.40766 0.34751
# [4, 9, 'To', False]  0.3208 | 0.27281 0.32718 0.3624
# [4, 9, 'MeanColumns', False]  0.2503 | 0.26848 0.19444 0.28796
# [4, 9, 'MaxColumns', False]  0.26363 | 0.302 0.1999 0.28899
# [4, 10, 'From', False]  0.32103 | 0.34457 0.37106 0.24746
# [4, 10, 'To', False]  0.21879 | 0.23724 0.14684 0.27228
# [4, 10, 'MeanColumns', False]  0.27097 | 0.27788 0.17901 0.35602
# [4, 10, 'MaxColumns', False]  0.258 | 0.2534 0.16025 0.36035
# [4, 11, 'From', False]  0.36359 | 0.37637 0.37039 0.344
# [4, 11, 'To', False]  0.26548 | 0.28082 0.24221 0.2734
# [4, 11, 'MeanColumns', False]  0.27258 | 0.30794 0.23004 0.27977
# [4, 11, 'MaxColumns', False]  0.34609 | 0.39896 0.28668 0.35263
# [5, 'Mean', 'From', False]  0.48168 | 0.52388 0.5209 0.40027
# [5, 'Mean', 'To', False]  0.32318 | 0.30765 0.27134 0.39054
# [5, 'Mean', 'MeanColumns', False]  0.36835 | 0.44415 0.32965 0.33125
# [5, 'Mean', 'MaxColumns', False]  0.3326 | 0.34234 0.34821 0.30723
# [5, 0, 'From', False]  0.55018 | 0.61942 0.59281 0.43831
# [5, 0, 'To', False]  0.3695 | 0.34217 0.28949 0.47682
# [5, 0, 'MeanColumns', False]  0.38504 | 0.43987 0.4305 0.28476
# [5, 0, 'MaxColumns', False]  0.39367 | 0.45417 0.42642 0.30043
# [5, 1, 'From', False]  0.39787 | 0.41186 0.38935 0.39241
# [5, 1, 'To', False]  0.3026 | 0.31353 0.16446 0.42982
# [5, 1, 'MeanColumns', False]  0.34971 | 0.36263 0.28641 0.4001
# [5, 1, 'MaxColumns', False]  0.42189 | 0.41751 0.40103 0.44712
# [5, 2, 'From', False]  0.35725 | 0.41283 0.23397 0.42494
# [5, 2, 'To', False]  0.22717 | 0.20535 0.17294 0.30321
# [5, 2, 'MeanColumns', False]  0.44234 | 0.49052 0.46764 0.36886
# [5, 2, 'MaxColumns', False]  0.45201 | 0.46663 0.48536 0.40404
# [5, 3, 'From', False]  0.38553 | 0.49704 0.35208 0.30747
# [5, 3, 'To', False]  0.29597 | 0.28012 0.26172 0.34607
# [5, 3, 'MeanColumns', False]  0.20254 | 0.20765 0.14962 0.25034
# [5, 3, 'MaxColumns', False]  0.23149 | 0.22299 0.17961 0.29188
# [5, 4, 'From', False]  0.29274 | 0.34116 0.2556 0.28146
# [5, 4, 'To', False]  0.31541 | 0.30467 0.22873 0.41283
# [5, 4, 'MeanColumns', False]  0.18199 | 0.19593 0.12063 0.22941
# [5, 4, 'MaxColumns', False]  0.19305 | 0.20332 0.12712 0.24871
# [5, 5, 'From', False]  0.4137 | 0.37355 0.49794 0.36962
# [5, 5, 'To', False]  0.30306 | 0.26665 0.25367 0.38888
# [5, 5, 'MeanColumns', False]  0.34191 | 0.39695 0.27711 0.35167
# [5, 5, 'MaxColumns', False]  0.31766 | 0.3598 0.2388 0.35436
# [5, 6, 'From', False]  0.35457 | 0.40577 0.25538 0.40255
# [5, 6, 'To', False]  0.24509 | 0.24603 0.16161 0.32762
# [5, 6, 'MeanColumns', False]  0.29777 | 0.3114 0.22231 0.3596
# [5, 6, 'MaxColumns', False]  0.29391 | 0.29875 0.231 0.35199
# [5, 7, 'From', False]  0.23 | 0.24291 0.22408 0.223
# [5, 7, 'To', False]  0.27209 | 0.28782 0.21413 0.31433
# [5, 7, 'MeanColumns', False]  0.23883 | 0.25129 0.16745 0.29776
# [5, 7, 'MaxColumns', False]  0.2083 | 0.20776 0.14294 0.27419
# [5, 8, 'From', False]  0.32054 | 0.32547 0.23496 0.40119
# [5, 8, 'To', False]  0.21525 | 0.23405 0.16059 0.2511
# [5, 8, 'MeanColumns', False]  0.22407 | 0.22021 0.1576 0.2944
# [5, 8, 'MaxColumns', False]  0.27726 | 0.24557 0.2122 0.37402
# [5, 9, 'From', False]  0.43569 | 0.48444 0.49513 0.32751
# [5, 9, 'To', False]  0.26748 | 0.21222 0.22635 0.36386
# [5, 9, 'MeanColumns', False]  0.32816 | 0.35981 0.2955 0.32919
# [5, 9, 'MaxColumns', False]  0.33713 | 0.3641 0.32669 0.32059
# [5, 10, 'From', False]  0.29507 | 0.3083 0.3535 0.22341
# [5, 10, 'To', False]  0.24225 | 0.25313 0.18867 0.28496
# [5, 10, 'MeanColumns', False]  0.22426 | 0.24066 0.15578 0.27634
# [5, 10, 'MaxColumns', False]  0.21378 | 0.2201 0.1426 0.27865
# [5, 11, 'From', False]  0.35339 | 0.34945 0.36415 0.34657
# [5, 11, 'To', False]  0.23062 | 0.22527 0.23309 0.23348
# [5, 11, 'MeanColumns', False]  0.30096 | 0.32213 0.27367 0.30708
# [5, 11, 'MaxColumns', False]  0.35872 | 0.38076 0.31888 0.37653

# %%
print_results(file_name+' (P)', conf, metricsP, label_names)
# Out:
# FTP
# ['Mean', 'Mean', 'From', False]  0.61184 | 0.48452 1.23549 0.11552
# ['Mean', 'Mean', 'To', False]  0.58342 | 0.25213 1.37984 0.11828
# ['Mean', 'Mean', 'MeanColumns', False]  0.48123 | 0.40943 0.89639 0.13786
# ['Mean', 'Mean', 'MaxColumns', False]  0.35433 | 0.14947 0.7954 0.11811
# ['Mean', 0, 'From', False]  0.62487 | 0.50023 1.25195 0.12242
# ['Mean', 0, 'To', False]  0.61307 | 0.3088 1.38414 0.14629
# ['Mean', 0, 'MeanColumns', False]  0.51373 | 0.47208 0.92844 0.14069
# ['Mean', 0, 'MaxColumns', False]  0.50891 | 0.4306 0.95975 0.13637
# ['Mean', 1, 'From', False]  0.5209 | 0.3888 1.07462 0.09927
# ['Mean', 1, 'To', False]  0.59609 | 0.2641 1.4189 0.10527
# ['Mean', 1, 'MeanColumns', False]  0.43376 | 0.28295 0.91764 0.1007
# ['Mean', 1, 'MaxColumns', False]  0.50954 | 0.31529 1.09809 0.11524
# ['Mean', 2, 'From', False]  0.62759 | 0.41837 1.38343 0.08098
# ['Mean', 2, 'To', False]  0.38655 | 0.12897 0.89142 0.13925
# ['Mean', 2, 'MeanColumns', False]  0.53346 | 0.47002 0.99128 0.13908
# ['Mean', 2, 'MaxColumns', False]  0.50814 | 0.36499 1.01621 0.14323
# ['Mean', 3, 'From', False]  0.54839 | 0.28175 1.24421 0.11921
# ['Mean', 3, 'To', False]  0.39327 | 0.18334 0.90829 0.08818
# ['Mean', 3, 'MeanColumns', False]  0.35962 | 0.14366 0.82519 0.11003
# ['Mean', 3, 'MaxColumns', False]  0.37821 | 0.12829 0.89623 0.11012
# ['Mean', 4, 'From', False]  0.45086 | 0.43127 0.82918 0.09212
# ['Mean', 4, 'To', False]  0.53783 | 0.23788 1.2733 0.10232
# ['Mean', 4, 'MeanColumns', False]  0.37659 | 0.25169 0.77021 0.10788
# ['Mean', 4, 'MaxColumns', False]  0.35135 | 0.14529 0.80944 0.09932
# ['Mean', 5, 'From', False]  0.39658 | 0.17165 0.90485 0.11324
# ['Mean', 5, 'To', False]  0.51986 | 0.14088 1.34384 0.07487
# ['Mean', 5, 'MeanColumns', False]  0.38444 | 0.19684 0.84325 0.11322
# ['Mean', 5, 'MaxColumns', False]  0.38626 | 0.17378 0.87205 0.11295
# ['Mean', 6, 'From', False]  0.57127 | 0.36777 1.25572 0.09031
# ['Mean', 6, 'To', False]  0.48675 | 0.2252 1.15334 0.08171
# ['Mean', 6, 'MeanColumns', False]  0.4405 | 0.32335 0.90143 0.09671
# ['Mean', 6, 'MaxColumns', False]  0.37253 | 0.18809 0.83257 0.09692
# ['Mean', 7, 'From', False]  0.34406 | 0.2215 0.71432 0.09635
# ['Mean', 7, 'To', False]  0.54551 | 0.23141 1.33236 0.07277
# ['Mean', 7, 'MeanColumns', False]  0.40945 | 0.12703 0.94147 0.15986
# ['Mean', 7, 'MaxColumns', False]  0.27778 | 0.10757 0.62242 0.10336
# ['Mean', 8, 'From', False]  0.61478 | 0.34203 1.39932 0.10299
# ['Mean', 8, 'To', False]  0.49679 | 0.26399 1.09634 0.13005
# ['Mean', 8, 'MeanColumns', False]  0.39533 | 0.1792 0.92085 0.08595
# ['Mean', 8, 'MaxColumns', False]  0.40045 | 0.12033 0.99582 0.0852
# ['Mean', 9, 'From', False]  0.40445 | 0.17638 0.93329 0.10367
# ['Mean', 9, 'To', False]  0.52425 | 0.20671 1.25468 0.11136
# ['Mean', 9, 'MeanColumns', False]  0.38096 | 0.15457 0.89289 0.09543
# ['Mean', 9, 'MaxColumns', False]  0.36931 | 0.11592 0.88635 0.10567
# ['Mean', 10, 'From', False]  0.49664 | 0.43737 0.92024 0.1323
# ['Mean', 10, 'To', False]  0.5022 | 0.35602 1.04926 0.10133
# ['Mean', 10, 'MeanColumns', False]  0.41693 | 0.30255 0.83921 0.10902
# ['Mean', 10, 'MaxColumns', False]  0.33692 | 0.09023 0.82804 0.09249
# ['Mean', 11, 'From', False]  0.54851 | 0.3376 1.2061 0.10184
# ['Mean', 11, 'To', False]  0.35805 | 0.11157 0.87344 0.08915
# ['Mean', 11, 'MeanColumns', False]  0.35542 | 0.23344 0.74525 0.08758
# ['Mean', 11, 'MaxColumns', False]  0.42786 | 0.25797 0.9284 0.0972
# ['Multi', 'Mean', 'From', False]  0.27718 | 0.09615 0.65545 0.07993
# ['Multi', 'Mean', 'To', False]  0.54877 | 0.25243 1.3166 0.07726
# ['Multi', 'Mean', 'MeanColumns', False]  0.27714 | 0.09603 0.65547 0.07993
# ['Multi', 'Mean', 'MaxColumns', False]  0.27713 | 0.09602 0.65545 0.07992
# ['Multi', 0, 'From', False]  0.29863 | 0.1158 0.6986 0.0815
# ['Multi', 0, 'To', False]  0.39436 | 0.21383 0.89007 0.07917
# ['Multi', 0, 'MeanColumns', False]  0.29855 | 0.11554 0.6986 0.0815
# ['Multi', 0, 'MaxColumns', False]  0.29849 | 0.11535 0.6986 0.08151
# ['Multi', 1, 'From', False]  0.25097 | 0.08368 0.58898 0.08026
# ['Multi', 1, 'To', False]  0.26898 | 0.10863 0.61079 0.08753
# ['Multi', 1, 'MeanColumns', False]  0.25137 | 0.08425 0.58962 0.08022
# ['Multi', 1, 'MaxColumns', False]  0.25197 | 0.08499 0.59059 0.08033
# ['Multi', 2, 'From', False]  0.31731 | 0.11994 0.75164 0.08034
# ['Multi', 2, 'To', False]  0.30211 | 0.13103 0.68557 0.08973
# ['Multi', 2, 'MeanColumns', False]  0.31734 | 0.12004 0.75163 0.08034
# ['Multi', 2, 'MaxColumns', False]  0.31735 | 0.12008 0.75163 0.08034
# ['Multi', 3, 'From', False]  0.30157 | 0.10681 0.71267 0.08522
# ['Multi', 3, 'To', False]  0.38063 | 0.15873 0.88953 0.09362
# ['Multi', 3, 'MeanColumns', False]  0.30086 | 0.10634 0.71105 0.0852
# ['Multi', 3, 'MaxColumns', False]  0.29766 | 0.10432 0.70513 0.08353
# ['Multi', 4, 'From', False]  0.30662 | 0.12992 0.69308 0.09687
# ['Multi', 4, 'To', False]  0.46059 | 0.2792 1.01965 0.08293
# ['Multi', 4, 'MeanColumns', False]  0.30645 | 0.12953 0.69294 0.09687
# ['Multi', 4, 'MaxColumns', False]  0.30586 | 0.12844 0.6924 0.09674
# ['Multi', 5, 'From', False]  0.32439 | 0.16574 0.72472 0.08273
# ['Multi', 5, 'To', False]  0.32252 | 0.11537 0.75966 0.09251
# ['Multi', 5, 'MeanColumns', False]  0.32439 | 0.16574 0.7247 0.08273
# ['Multi', 5, 'MaxColumns', False]  0.32438 | 0.16569 0.72472 0.08273
# ['Multi', 6, 'From', False]  0.31809 | 0.12079 0.75973 0.07376
# ['Multi', 6, 'To', False]  0.35829 | 0.1535 0.83374 0.08762
# ['Multi', 6, 'MeanColumns', False]  0.31807 | 0.12073 0.75973 0.07376
# ['Multi', 6, 'MaxColumns', False]  0.31807 | 0.12073 0.75973 0.07376
# ['Multi', 7, 'From', False]  0.33438 | 0.10079 0.80286 0.09949
# ['Multi', 7, 'To', False]  0.4309 | 0.17595 0.9996 0.11716
# ['Multi', 7, 'MeanColumns', False]  0.33607 | 0.10197 0.80493 0.10131
# ['Multi', 7, 'MaxColumns', False]  0.34606 | 0.10115 0.8284 0.10863
# ['Multi', 8, 'From', False]  0.43156 | 0.16135 1.04453 0.08881
# ['Multi', 8, 'To', False]  0.35414 | 0.11384 0.83468 0.1139
# ['Multi', 8, 'MeanColumns', False]  0.42983 | 0.15863 1.04213 0.08872
# ['Multi', 8, 'MaxColumns', False]  0.43018 | 0.15929 1.04271 0.08854
# ['Multi', 9, 'From', False]  0.36599 | 0.13334 0.87201 0.09261
# ['Multi', 9, 'To', False]  0.29117 | 0.16869 0.61072 0.09409
# ['Multi', 9, 'MeanColumns', False]  0.36603 | 0.13338 0.87201 0.0927
# ['Multi', 9, 'MaxColumns', False]  0.3661 | 0.13334 0.87228 0.09268
# ['Multi', 10, 'From', False]  0.30801 | 0.11951 0.71779 0.08674
# ['Multi', 10, 'To', False]  0.23817 | 0.08964 0.55749 0.06739
# ['Multi', 10, 'MeanColumns', False]  0.30801 | 0.11951 0.71779 0.08674
# ['Multi', 10, 'MaxColumns', False]  0.30801 | 0.11951 0.71779 0.08674
# ['Multi', 11, 'From', False]  0.23512 | 0.08487 0.53573 0.08477
# ['Multi', 11, 'To', False]  0.43999 | 0.09918 1.12032 0.10046
# ['Multi', 11, 'MeanColumns', False]  0.23515 | 0.08496 0.53573 0.08477
# ['Multi', 11, 'MaxColumns', False]  0.23513 | 0.0849 0.53573 0.08477
# [0, 'Mean', 'From', False]  0.38477 | 0.1139 0.96983 0.07059
# [0, 'Mean', 'To', False]  0.57093 | 0.25827 1.35188 0.10263
# [0, 'Mean', 'MeanColumns', False]  0.35016 | 0.1073 0.85805 0.08514
# [0, 'Mean', 'MaxColumns', False]  0.36154 | 0.14225 0.84893 0.09346
# [0, 0, 'From', False]  0.3103 | 0.09707 0.76539 0.06844
# [0, 0, 'To', False]  0.56918 | 0.2919 1.30836 0.10729
# [0, 0, 'MeanColumns', False]  0.37598 | 0.15163 0.87452 0.10178
# [0, 0, 'MaxColumns', False]  0.33835 | 0.13653 0.7916 0.08694
# [0, 1, 'From', False]  0.37322 | 0.12156 0.92492 0.07319
# [0, 1, 'To', False]  0.58975 | 0.25904 1.40935 0.10086
# [0, 1, 'MeanColumns', False]  0.33152 | 0.09584 0.82312 0.07559
# [0, 1, 'MaxColumns', False]  0.33271 | 0.09941 0.82217 0.07653
# [0, 2, 'From', False]  0.51547 | 0.18723 1.28285 0.07633
# [0, 2, 'To', False]  0.56613 | 0.28499 1.29121 0.12218
# [0, 2, 'MeanColumns', False]  0.34606 | 0.13426 0.79705 0.10686
# [0, 2, 'MaxColumns', False]  0.40345 | 0.16504 0.92867 0.11664
# [0, 3, 'From', False]  0.47425 | 0.18539 1.12993 0.10742
# [0, 3, 'To', False]  0.34013 | 0.112 0.81502 0.09336
# [0, 3, 'MeanColumns', False]  0.33422 | 0.12341 0.79248 0.08675
# [0, 3, 'MaxColumns', False]  0.33842 | 0.12819 0.80584 0.08123
# [0, 4, 'From', False]  0.3155 | 0.1087 0.74237 0.09543
# [0, 4, 'To', False]  0.51021 | 0.20669 1.21771 0.10622
# [0, 4, 'MeanColumns', False]  0.43184 | 0.20272 0.97487 0.11792
# [0, 4, 'MaxColumns', False]  0.42708 | 0.18131 0.98984 0.1101
# [0, 5, 'From', False]  0.2875 | 0.11405 0.66248 0.08597
# [0, 5, 'To', False]  0.29239 | 0.08998 0.71639 0.07079
# [0, 5, 'MeanColumns', False]  0.35995 | 0.17619 0.80868 0.09498
# [0, 5, 'MaxColumns', False]  0.42178 | 0.23517 0.91785 0.1123
# [0, 6, 'From', False]  0.38472 | 0.11543 0.96914 0.06958
# [0, 6, 'To', False]  0.54836 | 0.22196 1.33613 0.08698
# [0, 6, 'MeanColumns', False]  0.38288 | 0.13488 0.93701 0.07674
# [0, 6, 'MaxColumns', False]  0.3699 | 0.15953 0.8675 0.08266
# [0, 7, 'From', False]  0.29326 | 0.11478 0.69063 0.07436
# [0, 7, 'To', False]  0.34008 | 0.19175 0.72558 0.10291
# [0, 7, 'MeanColumns', False]  0.36606 | 0.10406 0.90409 0.09005
# [0, 7, 'MaxColumns', False]  0.32099 | 0.13922 0.73118 0.09256
# [0, 8, 'From', False]  0.38055 | 0.1206 0.94348 0.07756
# [0, 8, 'To', False]  0.58202 | 0.28575 1.36047 0.09983
# [0, 8, 'MeanColumns', False]  0.34911 | 0.11375 0.84869 0.0849
# [0, 8, 'MaxColumns', False]  0.37757 | 0.16451 0.87063 0.09755
# [0, 9, 'From', False]  0.35639 | 0.14931 0.82231 0.09755
# [0, 9, 'To', False]  0.4273 | 0.20974 0.95871 0.11345
# [0, 9, 'MeanColumns', False]  0.34295 | 0.1094 0.84514 0.0743
# [0, 9, 'MaxColumns', False]  0.37195 | 0.14254 0.89453 0.07878
# [0, 10, 'From', False]  0.32044 | 0.12856 0.74705 0.08572
# [0, 10, 'To', False]  0.38091 | 0.20816 0.82386 0.1107
# [0, 10, 'MeanColumns', False]  0.33895 | 0.12728 0.80861 0.08097
# [0, 10, 'MaxColumns', False]  0.34945 | 0.14796 0.82049 0.0799
# [0, 11, 'From', False]  0.49803 | 0.18528 1.22868 0.08013
# [0, 11, 'To', False]  0.5707 | 0.25954 1.356 0.09655
# [0, 11, 'MeanColumns', False]  0.2769 | 0.09136 0.65457 0.08477
# [0, 11, 'MaxColumns', False]  0.37618 | 0.14501 0.90757 0.07596
# [1, 'Mean', 'From', False]  0.53506 | 0.30396 1.16571 0.13552
# [1, 'Mean', 'To', False]  0.35487 | 0.1297 0.85986 0.07505
# [1, 'Mean', 'MeanColumns', False]  0.49107 | 0.3152 1.02286 0.13515
# [1, 'Mean', 'MaxColumns', False]  0.49415 | 0.32235 1.03215 0.12797
# [1, 0, 'From', False]  0.57367 | 0.32836 1.2578 0.13486
# [1, 0, 'To', False]  0.54529 | 0.2049 1.33121 0.09976
# [1, 0, 'MeanColumns', False]  0.53037 | 0.3516 1.10524 0.13427
# [1, 0, 'MaxColumns', False]  0.54207 | 0.35102 1.14131 0.13388
# [1, 1, 'From', False]  0.5353 | 0.28974 1.18678 0.12939
# [1, 1, 'To', False]  0.58243 | 0.24646 1.41111 0.08972
# [1, 1, 'MeanColumns', False]  0.44907 | 0.2013 1.03054 0.11539
# [1, 1, 'MaxColumns', False]  0.50974 | 0.25159 1.16447 0.11316
# [1, 2, 'From', False]  0.60076 | 0.29175 1.40711 0.10342
# [1, 2, 'To', False]  0.47942 | 0.22005 1.13257 0.08565
# [1, 2, 'MeanColumns', False]  0.45652 | 0.25492 0.98088 0.13376
# [1, 2, 'MaxColumns', False]  0.48198 | 0.28081 1.03414 0.131
# [1, 3, 'From', False]  0.59391 | 0.29143 1.37603 0.11426
# [1, 3, 'To', False]  0.35683 | 0.12661 0.86629 0.07759
# [1, 3, 'MeanColumns', False]  0.39874 | 0.18696 0.89184 0.11742
# [1, 3, 'MaxColumns', False]  0.44157 | 0.23409 0.97239 0.11823
# [1, 4, 'From', False]  0.46273 | 0.25483 1.02498 0.10838
# [1, 4, 'To', False]  0.54283 | 0.22755 1.30462 0.09632
# [1, 4, 'MeanColumns', False]  0.38926 | 0.18485 0.87202 0.11093
# [1, 4, 'MaxColumns', False]  0.42024 | 0.1966 0.96027 0.10386
# [1, 5, 'From', False]  0.47138 | 0.27046 1.02997 0.1137
# [1, 5, 'To', False]  0.37696 | 0.12716 0.92858 0.07515
# [1, 5, 'MeanColumns', False]  0.46317 | 0.26187 1.01434 0.1133
# [1, 5, 'MaxColumns', False]  0.47656 | 0.27019 1.04404 0.11543
# [1, 6, 'From', False]  0.52913 | 0.29324 1.18642 0.10773
# [1, 6, 'To', False]  0.57152 | 0.24124 1.38007 0.09327
# [1, 6, 'MeanColumns', False]  0.41815 | 0.25677 0.89559 0.10209
# [1, 6, 'MaxColumns', False]  0.42199 | 0.25123 0.91476 0.09996
# [1, 7, 'From', False]  0.30439 | 0.11163 0.69454 0.10701
# [1, 7, 'To', False]  0.26286 | 0.09333 0.61999 0.07527
# [1, 7, 'MeanColumns', False]  0.38357 | 0.13349 0.89987 0.11735
# [1, 7, 'MaxColumns', False]  0.33618 | 0.14087 0.76958 0.09808
# [1, 8, 'From', False]  0.5485 | 0.27846 1.25572 0.11132
# [1, 8, 'To', False]  0.50039 | 0.18345 1.23714 0.08058
# [1, 8, 'MeanColumns', False]  0.42592 | 0.18509 0.9984 0.09427
# [1, 8, 'MaxColumns', False]  0.42746 | 0.19523 0.99493 0.09223
# [1, 9, 'From', False]  0.42477 | 0.18489 0.98942 0.10001
# [1, 9, 'To', False]  0.44544 | 0.16492 1.09462 0.07678
# [1, 9, 'MeanColumns', False]  0.48351 | 0.26252 1.06163 0.12637
# [1, 9, 'MaxColumns', False]  0.46084 | 0.26099 0.99894 0.12257
# [1, 10, 'From', False]  0.42564 | 0.19609 0.93489 0.14594
# [1, 10, 'To', False]  0.31029 | 0.10815 0.71796 0.10476
# [1, 10, 'MeanColumns', False]  0.401 | 0.2077 0.87606 0.11922
# [1, 10, 'MaxColumns', False]  0.38462 | 0.19035 0.84624 0.11727
# [1, 11, 'From', False]  0.59743 | 0.29837 1.38402 0.1099
# [1, 11, 'To', False]  0.33663 | 0.13644 0.79894 0.0745
# [1, 11, 'MeanColumns', False]  0.41224 | 0.2487 0.88043 0.10758
# [1, 11, 'MaxColumns', False]  0.50162 | 0.32449 1.07157 0.10881
# [2, 'Mean', 'From', False]  0.40754 | 0.17335 0.95393 0.09534
# [2, 'Mean', 'To', False]  0.35807 | 0.12681 0.8692 0.07821
# [2, 'Mean', 'MeanColumns', False]  0.42453 | 0.22046 0.92238 0.13076
# [2, 'Mean', 'MaxColumns', False]  0.44391 | 0.27916 0.92625 0.12631
# [2, 0, 'From', False]  0.48613 | 0.25006 1.09102 0.11732
# [2, 0, 'To', False]  0.52685 | 0.2007 1.27814 0.10171
# [2, 0, 'MeanColumns', False]  0.45386 | 0.26478 0.95858 0.13822
# [2, 0, 'MaxColumns', False]  0.47804 | 0.292 1.00939 0.13272
# [2, 1, 'From', False]  0.39016 | 0.1501 0.91024 0.11014
# [2, 1, 'To', False]  0.56794 | 0.23777 1.37131 0.09473
# [2, 1, 'MeanColumns', False]  0.38474 | 0.1476 0.91022 0.09642
# [2, 1, 'MaxColumns', False]  0.44102 | 0.20198 1.01982 0.10125
# [2, 2, 'From', False]  0.50132 | 0.21164 1.20421 0.08812
# [2, 2, 'To', False]  0.32937 | 0.1269 0.77717 0.08406
# [2, 2, 'MeanColumns', False]  0.49434 | 0.30146 1.04579 0.13576
# [2, 2, 'MaxColumns', False]  0.50276 | 0.30421 1.0723 0.13177
# [2, 3, 'From', False]  0.51336 | 0.27361 1.14721 0.11928
# [2, 3, 'To', False]  0.29717 | 0.10237 0.70768 0.08145
# [2, 3, 'MeanColumns', False]  0.42068 | 0.20129 0.94701 0.11374
# [2, 3, 'MaxColumns', False]  0.43845 | 0.22324 0.97741 0.1147
# [2, 4, 'From', False]  0.33404 | 0.14485 0.7531 0.10417
# [2, 4, 'To', False]  0.53466 | 0.22083 1.28408 0.09908
# [2, 4, 'MeanColumns', False]  0.38759 | 0.1793 0.87761 0.10585
# [2, 4, 'MaxColumns', False]  0.39253 | 0.18881 0.88721 0.10157
# [2, 5, 'From', False]  0.39821 | 0.16274 0.93302 0.09886
# [2, 5, 'To', False]  0.37245 | 0.11941 0.92085 0.07708
# [2, 5, 'MeanColumns', False]  0.40194 | 0.18211 0.90583 0.1179
# [2, 5, 'MaxColumns', False]  0.40595 | 0.20638 0.89137 0.12009
# [2, 6, 'From', False]  0.37643 | 0.17877 0.86118 0.08934
# [2, 6, 'To', False]  0.4648 | 0.161 1.142 0.09139
# [2, 6, 'MeanColumns', False]  0.38341 | 0.18752 0.86218 0.10052
# [2, 6, 'MaxColumns', False]  0.39931 | 0.20752 0.89373 0.09669
# [2, 7, 'From', False]  0.39244 | 0.16565 0.91054 0.10112
# [2, 7, 'To', False]  0.29288 | 0.11006 0.69047 0.0781
# [2, 7, 'MeanColumns', False]  0.44743 | 0.17655 1.01968 0.14607
# [2, 7, 'MaxColumns', False]  0.38064 | 0.2061 0.82169 0.11413
# [2, 8, 'From', False]  0.41389 | 0.16619 0.9844 0.09107
# [2, 8, 'To', False]  0.38413 | 0.13453 0.94271 0.07514
# [2, 8, 'MeanColumns', False]  0.37217 | 0.12677 0.89759 0.09214
# [2, 8, 'MaxColumns', False]  0.42184 | 0.16255 1.01064 0.09232
# [2, 9, 'From', False]  0.37188 | 0.12924 0.90306 0.08334
# [2, 9, 'To', False]  0.38374 | 0.12375 0.9519 0.07558
# [2, 9, 'MeanColumns', False]  0.3715 | 0.13421 0.87187 0.10843
# [2, 9, 'MaxColumns', False]  0.36337 | 0.17797 0.7984 0.11375
# [2, 10, 'From', False]  0.44473 | 0.22658 0.95558 0.15202
# [2, 10, 'To', False]  0.39106 | 0.15206 0.92046 0.10066
# [2, 10, 'MeanColumns', False]  0.34589 | 0.14108 0.78168 0.11491
# [2, 10, 'MaxColumns', False]  0.32633 | 0.13343 0.74539 0.10018
# [2, 11, 'From', False]  0.50821 | 0.22642 1.1891 0.10912
# [2, 11, 'To', False]  0.29406 | 0.10827 0.69367 0.08026
# [2, 11, 'MeanColumns', False]  0.34722 | 0.15931 0.78011 0.10224
# [2, 11, 'MaxColumns', False]  0.45352 | 0.23785 1.01332 0.10939
# [3, 'Mean', 'From', False]  0.41129 | 0.20537 0.93151 0.09697
# [3, 'Mean', 'To', False]  0.36801 | 0.13034 0.89749 0.0762
# [3, 'Mean', 'MeanColumns', False]  0.45921 | 0.25759 0.96745 0.1526
# [3, 'Mean', 'MaxColumns', False]  0.40214 | 0.22929 0.84935 0.12776
# [3, 0, 'From', False]  0.50183 | 0.25772 1.12772 0.12004
# [3, 0, 'To', False]  0.54312 | 0.19648 1.32776 0.10512
# [3, 0, 'MeanColumns', False]  0.51388 | 0.33588 1.05341 0.15235
# [3, 0, 'MaxColumns', False]  0.52082 | 0.34781 1.07625 0.1384
# [3, 1, 'From', False]  0.41731 | 0.16991 0.9592 0.12281
# [3, 1, 'To', False]  0.58303 | 0.25536 1.40266 0.09108
# [3, 1, 'MeanColumns', False]  0.48417 | 0.27262 1.05416 0.12573
# [3, 1, 'MaxColumns', False]  0.53289 | 0.31592 1.16171 0.12103
# [3, 2, 'From', False]  0.54888 | 0.25867 1.29506 0.09291
# [3, 2, 'To', False]  0.32141 | 0.11917 0.76593 0.07913
# [3, 2, 'MeanColumns', False]  0.5056 | 0.32224 1.05534 0.13922
# [3, 2, 'MaxColumns', False]  0.51237 | 0.32007 1.08288 0.13415
# [3, 3, 'From', False]  0.53734 | 0.35201 1.12738 0.13263
# [3, 3, 'To', False]  0.3141 | 0.10557 0.75139 0.08535
# [3, 3, 'MeanColumns', False]  0.40434 | 0.18166 0.91748 0.1139
# [3, 3, 'MaxColumns', False]  0.40185 | 0.16897 0.92445 0.11214
# [3, 4, 'From', False]  0.3384 | 0.17684 0.73668 0.10168
# [3, 4, 'To', False]  0.53454 | 0.23572 1.25908 0.10883
# [3, 4, 'MeanColumns', False]  0.48738 | 0.22232 1.12368 0.11613
# [3, 4, 'MaxColumns', False]  0.4699 | 0.21053 1.092 0.10716
# [3, 5, 'From', False]  0.39555 | 0.17089 0.92136 0.09441
# [3, 5, 'To', False]  0.39017 | 0.1247 0.96628 0.07955
# [3, 5, 'MeanColumns', False]  0.39883 | 0.19347 0.8749 0.1281
# [3, 5, 'MaxColumns', False]  0.39794 | 0.19624 0.86996 0.12761
# [3, 6, 'From', False]  0.38717 | 0.18649 0.87889 0.09613
# [3, 6, 'To', False]  0.40209 | 0.13903 0.98791 0.07932
# [3, 6, 'MeanColumns', False]  0.34964 | 0.16626 0.77837 0.10428
# [3, 6, 'MaxColumns', False]  0.35778 | 0.17037 0.80476 0.09821
# [3, 7, 'From', False]  0.33524 | 0.11983 0.79819 0.08772
# [3, 7, 'To', False]  0.29976 | 0.10219 0.72667 0.0704
# [3, 7, 'MeanColumns', False]  0.39775 | 0.10552 0.92991 0.15782
# [3, 7, 'MaxColumns', False]  0.34256 | 0.12109 0.78154 0.12504
# [3, 8, 'From', False]  0.4198 | 0.18746 0.97788 0.09405
# [3, 8, 'To', False]  0.38675 | 0.15162 0.93685 0.07179
# [3, 8, 'MeanColumns', False]  0.35989 | 0.11886 0.86338 0.09743
# [3, 8, 'MaxColumns', False]  0.39469 | 0.14588 0.94117 0.09702
# [3, 9, 'From', False]  0.38226 | 0.14696 0.91202 0.0878
# [3, 9, 'To', False]  0.38078 | 0.12968 0.93631 0.07636
# [3, 9, 'MeanColumns', False]  0.36499 | 0.13637 0.82952 0.12908
# [3, 9, 'MaxColumns', False]  0.35821 | 0.16424 0.78811 0.12229
# [3, 10, 'From', False]  0.43134 | 0.24082 0.9136 0.1396
# [3, 10, 'To', False]  0.42709 | 0.16141 1.00724 0.11261
# [3, 10, 'MeanColumns', False]  0.36135 | 0.13861 0.84244 0.10299
# [3, 10, 'MaxColumns', False]  0.349 | 0.13137 0.82197 0.09367
# [3, 11, 'From', False]  0.52919 | 0.24447 1.23143 0.11168
# [3, 11, 'To', False]  0.31967 | 0.12527 0.75882 0.07491
# [3, 11, 'MeanColumns', False]  0.38805 | 0.18084 0.87141 0.11188
# [3, 11, 'MaxColumns', False]  0.44283 | 0.21837 0.99205 0.11807
# [4, 'Mean', 'From', False]  0.47577 | 0.34891 0.97379 0.10463
# [4, 'Mean', 'To', False]  0.39782 | 0.13669 0.9628 0.09396
# [4, 'Mean', 'MeanColumns', False]  0.45549 | 0.31527 0.92553 0.12566
# [4, 'Mean', 'MaxColumns', False]  0.42884 | 0.29768 0.86982 0.11904
# [4, 0, 'From', False]  0.55321 | 0.38611 1.16247 0.11104
# [4, 0, 'To', False]  0.4968 | 0.16548 1.20611 0.11882
# [4, 0, 'MeanColumns', False]  0.54301 | 0.41546 1.06825 0.14532
# [4, 0, 'MaxColumns', False]  0.56049 | 0.42565 1.11901 0.1368
# [4, 1, 'From', False]  0.47082 | 0.26516 1.0287 0.11861
# [4, 1, 'To', False]  0.55346 | 0.23039 1.3375 0.09251
# [4, 1, 'MeanColumns', False]  0.45654 | 0.24075 1.0224 0.10647
# [4, 1, 'MaxColumns', False]  0.49015 | 0.3026 1.06417 0.10368
# [4, 2, 'From', False]  0.55754 | 0.30161 1.28565 0.08536
# [4, 2, 'To', False]  0.46104 | 0.13432 1.13388 0.11493
# [4, 2, 'MeanColumns', False]  0.49322 | 0.36549 0.97711 0.13705
# [4, 2, 'MaxColumns', False]  0.50904 | 0.34573 1.05098 0.13042
# [4, 3, 'From', False]  0.49589 | 0.42457 0.94495 0.11815
# [4, 3, 'To', False]  0.34843 | 0.12365 0.83556 0.08608
# [4, 3, 'MeanColumns', False]  0.39754 | 0.21167 0.86277 0.11819
# [4, 3, 'MaxColumns', False]  0.39841 | 0.2005 0.87464 0.1201
# [4, 4, 'From', False]  0.39277 | 0.22612 0.84634 0.10584
# [4, 4, 'To', False]  0.53963 | 0.2614 1.24606 0.11142
# [4, 4, 'MeanColumns', False]  0.37986 | 0.18062 0.84711 0.11184
# [4, 4, 'MaxColumns', False]  0.371 | 0.171 0.83862 0.10338
# [4, 5, 'From', False]  0.41504 | 0.25335 0.87634 0.11544
# [4, 5, 'To', False]  0.388 | 0.13231 0.93397 0.09773
# [4, 5, 'MeanColumns', False]  0.4303 | 0.25324 0.94144 0.09623
# [4, 5, 'MaxColumns', False]  0.43401 | 0.23908 0.96088 0.10206
# [4, 6, 'From', False]  0.46802 | 0.30091 1.01648 0.08667
# [4, 6, 'To', False]  0.47834 | 0.18146 1.17202 0.08153
# [4, 6, 'MeanColumns', False]  0.36141 | 0.16898 0.81823 0.09702
# [4, 6, 'MaxColumns', False]  0.36236 | 0.173 0.81825 0.09582
# [4, 7, 'From', False]  0.34791 | 0.15554 0.78293 0.10524
# [4, 7, 'To', False]  0.35055 | 0.12031 0.85602 0.07532
# [4, 7, 'MeanColumns', False]  0.42987 | 0.12539 1.01924 0.14498
# [4, 7, 'MaxColumns', False]  0.35708 | 0.12705 0.83015 0.11404
# [4, 8, 'From', False]  0.45437 | 0.21095 1.05415 0.09801
# [4, 8, 'To', False]  0.40443 | 0.22017 0.87924 0.11388
# [4, 8, 'MeanColumns', False]  0.34806 | 0.12847 0.83137 0.08434
# [4, 8, 'MaxColumns', False]  0.41002 | 0.13574 1.00848 0.08585
# [4, 9, 'From', False]  0.42693 | 0.26319 0.90608 0.1115
# [4, 9, 'To', False]  0.38704 | 0.13547 0.91951 0.10614
# [4, 9, 'MeanColumns', False]  0.36275 | 0.15298 0.84266 0.0926
# [4, 9, 'MaxColumns', False]  0.38454 | 0.18063 0.86755 0.10544
# [4, 10, 'From', False]  0.403 | 0.24864 0.83026 0.1301
# [4, 10, 'To', False]  0.40663 | 0.14262 0.95698 0.12029
# [4, 10, 'MeanColumns', False]  0.42933 | 0.17822 0.99844 0.11132
# [4, 10, 'MaxColumns', False]  0.41107 | 0.14758 0.98456 0.10107
# [4, 11, 'From', False]  0.42416 | 0.21681 0.95727 0.09839
# [4, 11, 'To', False]  0.32801 | 0.11953 0.77569 0.08881
# [4, 11, 'MeanColumns', False]  0.38455 | 0.25479 0.79997 0.09891
# [4, 11, 'MaxColumns', False]  0.49138 | 0.32864 1.03563 0.10987
# [5, 'Mean', 'From', False]  0.50061 | 0.41867 0.97027 0.11289
# [5, 'Mean', 'To', False]  0.44314 | 0.19226 1.03823 0.09892
# [5, 'Mean', 'MeanColumns', False]  0.48001 | 0.40677 0.90243 0.13084
# [5, 'Mean', 'MaxColumns', False]  0.42558 | 0.28342 0.8709 0.12242
# [5, 0, 'From', False]  0.54212 | 0.46062 1.04929 0.11645
# [5, 0, 'To', False]  0.5635 | 0.23101 1.34357 0.11592
# [5, 0, 'MeanColumns', False]  0.47468 | 0.42584 0.86313 0.13507
# [5, 0, 'MaxColumns', False]  0.50127 | 0.43894 0.92955 0.13532
# [5, 1, 'From', False]  0.45391 | 0.27051 0.99259 0.09862
# [5, 1, 'To', False]  0.55611 | 0.24127 1.32107 0.10598
# [5, 1, 'MeanColumns', False]  0.44823 | 0.26237 0.97719 0.10512
# [5, 1, 'MaxColumns', False]  0.52718 | 0.34264 1.12044 0.11848
# [5, 2, 'From', False]  0.55126 | 0.32778 1.24417 0.08184
# [5, 2, 'To', False]  0.41012 | 0.10334 0.99872 0.12829
# [5, 2, 'MeanColumns', False]  0.55244 | 0.45119 1.06924 0.1369
# [5, 2, 'MaxColumns', False]  0.5534 | 0.42539 1.10114 0.13366
# [5, 3, 'From', False]  0.4418 | 0.40948 0.82472 0.09121
# [5, 3, 'To', False]  0.36722 | 0.14503 0.86836 0.08828
# [5, 3, 'MeanColumns', False]  0.37707 | 0.17473 0.83961 0.11688
# [5, 3, 'MaxColumns', False]  0.39982 | 0.1759 0.90526 0.1183
# [5, 4, 'From', False]  0.39283 | 0.24315 0.83772 0.09761
# [5, 4, 'To', False]  0.51714 | 0.23366 1.21619 0.10159
# [5, 4, 'MeanColumns', False]  0.32269 | 0.15211 0.71157 0.10439
# [5, 4, 'MaxColumns', False]  0.33846 | 0.15593 0.76406 0.09541
# [5, 5, 'From', False]  0.40948 | 0.28213 0.82548 0.12082
# [5, 5, 'To', False]  0.43264 | 0.1484 1.06206 0.08746
# [5, 5, 'MeanColumns', False]  0.46674 | 0.33009 0.95233 0.11779
# [5, 5, 'MaxColumns', False]  0.46534 | 0.28383 1.00076 0.11144
# [5, 6, 'From', False]  0.49889 | 0.32326 1.09229 0.08111
# [5, 6, 'To', False]  0.38631 | 0.14155 0.93597 0.08142
# [5, 6, 'MeanColumns', False]  0.43824 | 0.24137 0.97394 0.0994
# [5, 6, 'MaxColumns', False]  0.43508 | 0.21948 0.99025 0.0955
# [5, 7, 'From', False]  0.33704 | 0.1867 0.70432 0.12009
# [5, 7, 'To', False]  0.37892 | 0.18783 0.87732 0.07161
# [5, 7, 'MeanColumns', False]  0.45216 | 0.16249 1.04182 0.15216
# [5, 7, 'MaxColumns', False]  0.37113 | 0.13154 0.8607 0.12114
# [5, 8, 'From', False]  0.45933 | 0.21986 1.06279 0.09536
# [5, 8, 'To', False]  0.35096 | 0.1453 0.79727 0.11031
# [5, 8, 'MeanColumns', False]  0.37056 | 0.16469 0.86401 0.08298
# [5, 8, 'MaxColumns', False]  0.44706 | 0.17471 1.08242 0.08404
# [5, 9, 'From', False]  0.43952 | 0.37724 0.8167 0.12463
# [5, 9, 'To', False]  0.40415 | 0.11976 0.9942 0.0985
# [5, 9, 'MeanColumns', False]  0.38605 | 0.20028 0.8595 0.09837
# [5, 9, 'MaxColumns', False]  0.39256 | 0.18034 0.89849 0.09885
# [5, 10, 'From', False]  0.34202 | 0.23536 0.67379 0.11692
# [5, 10, 'To', False]  0.39494 | 0.17552 0.90518 0.10411
# [5, 10, 'MeanColumns', False]  0.36627 | 0.14586 0.83953 0.11344
# [5, 10, 'MaxColumns', False]  0.34647 | 0.11608 0.81751 0.1058
# [5, 11, 'From', False]  0.39897 | 0.21853 0.88863 0.08975
# [5, 11, 'To', False]  0.27463 | 0.10384 0.62656 0.0935
# [5, 11, 'MeanColumns', False]  0.39565 | 0.26111 0.83222 0.09362
# [5, 11, 'MaxColumns', False]  0.45772 | 0.30313 0.96809 0.10193
# F
# ['Mean', 'Mean', 'From', False]  0.29172 | 0.37137 0.44782 0.05598
# ['Mean', 'Mean', 'To', False]  0.21641 | 0.07673 0.52347 0.04903
# ['Mean', 'Mean', 'MeanColumns', False]  0.20972 | 0.28535 0.27998 0.06383
# ['Mean', 'Mean', 'MaxColumns', False]  0.0762 | 0.01962 0.17716 0.03182
# ['Mean', 0, 'From', False]  0.29985 | 0.38847 0.44855 0.06255
# ['Mean', 0, 'To', False]  0.24 | 0.14976 0.49601 0.07424
# ['Mean', 0, 'MeanColumns', False]  0.2253 | 0.37419 0.24449 0.05723
# ['Mean', 0, 'MaxColumns', False]  0.20404 | 0.32687 0.23273 0.05251
# ['Mean', 1, 'From', False]  0.19858 | 0.23819 0.3338 0.02375
# ['Mean', 1, 'To', False]  0.2133 | 0.08261 0.5257 0.03157
# ['Mean', 1, 'MeanColumns', False]  0.1557 | 0.12968 0.31402 0.02339
# ['Mean', 1, 'MaxColumns', False]  0.19788 | 0.18253 0.36909 0.04203
# ['Mean', 2, 'From', False]  0.26219 | 0.2487 0.52689 0.01097
# ['Mean', 2, 'To', False]  0.12555 | 0.02235 0.29269 0.06161
# ['Mean', 2, 'MeanColumns', False]  0.23213 | 0.364 0.2646 0.06779
# ['Mean', 2, 'MaxColumns', False]  0.18362 | 0.21653 0.26664 0.06769
# ['Mean', 3, 'From', False]  0.23262 | 0.13685 0.5179 0.04311
# ['Mean', 3, 'To', False]  0.02963 | 0.00606 0.06541 0.01741
# ['Mean', 3, 'MeanColumns', False]  0.08181 | 0.03744 0.17771 0.03027
# ['Mean', 3, 'MaxColumns', False]  0.09344 | 0.02861 0.21763 0.03407
# ['Mean', 4, 'From', False]  0.12445 | 0.29072 0.06628 0.01636
# ['Mean', 4, 'To', False]  0.21308 | 0.07619 0.53143 0.03161
# ['Mean', 4, 'MeanColumns', False]  0.09632 | 0.10239 0.15708 0.0295
# ['Mean', 4, 'MaxColumns', False]  0.08094 | 0.0297 0.18705 0.02608
# ['Mean', 5, 'From', False]  0.11737 | 0.01902 0.29227 0.04083
# ['Mean', 5, 'To', False]  0.18493 | 0.03121 0.51035 0.01322
# ['Mean', 5, 'MeanColumns', False]  0.08067 | 0.02478 0.17962 0.03762
# ['Mean', 5, 'MaxColumns', False]  0.09113 | 0.03155 0.20607 0.03577
# ['Mean', 6, 'From', False]  0.20923 | 0.18157 0.42402 0.02212
# ['Mean', 6, 'To', False]  0.16002 | 0.07306 0.38989 0.01711
# ['Mean', 6, 'MeanColumns', False]  0.14327 | 0.16699 0.23155 0.03128
# ['Mean', 6, 'MaxColumns', False]  0.09141 | 0.05373 0.19078 0.02972
# ['Mean', 7, 'From', False]  0.07024 | 0.03862 0.15077 0.02133
# ['Mean', 7, 'To', False]  0.20187 | 0.06805 0.52295 0.01461
# ['Mean', 7, 'MeanColumns', False]  0.15258 | 0.01633 0.36758 0.07383
# ['Mean', 7, 'MaxColumns', False]  0.05287 | 0.02786 0.1041 0.02664
# ['Mean', 8, 'From', False]  0.252 | 0.18247 0.54292 0.03061
# ['Mean', 8, 'To', False]  0.17573 | 0.12527 0.35833 0.0436
# ['Mean', 8, 'MeanColumns', False]  0.06389 | 0.02361 0.15085 0.01719
# ['Mean', 8, 'MaxColumns', False]  0.1266 | 0.0114 0.35061 0.0178
# ['Mean', 9, 'From', False]  0.12509 | 0.0074 0.35482 0.01305
# ['Mean', 9, 'To', False]  0.18965 | 0.07061 0.46224 0.03609
# ['Mean', 9, 'MeanColumns', False]  0.10263 | 0.00707 0.28943 0.01139
# ['Mean', 9, 'MaxColumns', False]  0.10513 | 0.01156 0.27761 0.02623
# ['Mean', 10, 'From', False]  0.20617 | 0.29201 0.27303 0.05348
# ['Mean', 10, 'To', False]  0.20083 | 0.20562 0.36822 0.02864
# ['Mean', 10, 'MeanColumns', False]  0.15284 | 0.14743 0.2769 0.03419
# ['Mean', 10, 'MaxColumns', False]  0.10711 | 0.00999 0.28882 0.02251
# ['Mean', 11, 'From', False]  0.20552 | 0.18196 0.40555 0.02907
# ['Mean', 11, 'To', False]  0.04774 | 0.00708 0.11671 0.01943
# ['Mean', 11, 'MeanColumns', False]  0.07203 | 0.03612 0.16481 0.01516
# ['Mean', 11, 'MaxColumns', False]  0.14328 | 0.08085 0.32122 0.02778
# ['Multi', 'Mean', 'From', False]  0.02885 | 0.00566 0.06646 0.01443
# ['Multi', 'Mean', 'To', False]  0.21634 | 0.14469 0.4897 0.01462
# ['Multi', 'Mean', 'MeanColumns', False]  0.02885 | 0.00566 0.06646 0.01443
# ['Multi', 'Mean', 'MaxColumns', False]  0.02885 | 0.00566 0.06646 0.01443
# ['Multi', 0, 'From', False]  0.02926 | 0.00548 0.06768 0.01464
# ['Multi', 0, 'To', False]  0.15237 | 0.11841 0.31981 0.01888
# ['Multi', 0, 'MeanColumns', False]  0.02926 | 0.00548 0.06768 0.01464
# ['Multi', 0, 'MaxColumns', False]  0.02926 | 0.00548 0.06768 0.01464
# ['Multi', 1, 'From', False]  0.02573 | 0.00567 0.05588 0.01562
# ['Multi', 1, 'To', False]  0.04278 | 0.03018 0.08101 0.01716
# ['Multi', 1, 'MeanColumns', False]  0.02573 | 0.00567 0.05588 0.01562
# ['Multi', 1, 'MaxColumns', False]  0.02573 | 0.00567 0.05588 0.01562
# ['Multi', 2, 'From', False]  0.02722 | 0.00584 0.06095 0.01486
# ['Multi', 2, 'To', False]  0.08212 | 0.04786 0.17442 0.0241
# ['Multi', 2, 'MeanColumns', False]  0.02722 | 0.00586 0.06095 0.01486
# ['Multi', 2, 'MaxColumns', False]  0.02722 | 0.00584 0.06095 0.01486
# ['Multi', 3, 'From', False]  0.06497 | 0.01567 0.15765 0.02158
# ['Multi', 3, 'To', False]  0.09837 | 0.0439 0.22767 0.02356
# ['Multi', 3, 'MeanColumns', False]  0.06473 | 0.01494 0.15714 0.02212
# ['Multi', 3, 'MaxColumns', False]  0.06236 | 0.01491 0.15291 0.01926
# ['Multi', 4, 'From', False]  0.03237 | 0.00894 0.06639 0.02177
# ['Multi', 4, 'To', False]  0.14417 | 0.12402 0.29381 0.01468
# ['Multi', 4, 'MeanColumns', False]  0.03237 | 0.00894 0.06639 0.02177
# ['Multi', 4, 'MaxColumns', False]  0.03237 | 0.00894 0.06639 0.02177
# ['Multi', 5, 'From', False]  0.07061 | 0.04948 0.1383 0.02406
# ['Multi', 5, 'To', False]  0.11064 | 0.02316 0.28226 0.0265
# ['Multi', 5, 'MeanColumns', False]  0.07061 | 0.04948 0.1383 0.02406
# ['Multi', 5, 'MaxColumns', False]  0.07061 | 0.04949 0.1383 0.02406
# ['Multi', 6, 'From', False]  0.02847 | 0.00532 0.06519 0.0149
# ['Multi', 6, 'To', False]  0.12506 | 0.06188 0.28648 0.02682
# ['Multi', 6, 'MeanColumns', False]  0.02847 | 0.00532 0.06519 0.0149
# ['Multi', 6, 'MaxColumns', False]  0.02847 | 0.00532 0.06519 0.0149
# ['Multi', 7, 'From', False]  0.07798 | 0.01727 0.18522 0.03144
# ['Multi', 7, 'To', False]  0.13999 | 0.06105 0.30787 0.05106
# ['Multi', 7, 'MeanColumns', False]  0.07947 | 0.0179 0.18612 0.0344
# ['Multi', 7, 'MaxColumns', False]  0.08814 | 0.0201 0.20322 0.04109
# ['Multi', 8, 'From', False]  0.11871 | 0.01638 0.32904 0.01071
# ['Multi', 8, 'To', False]  0.09899 | 0.03364 0.22876 0.03458
# ['Multi', 8, 'MeanColumns', False]  0.11851 | 0.01548 0.32938 0.01068
# ['Multi', 8, 'MaxColumns', False]  0.11878 | 0.01629 0.32938 0.01068
# ['Multi', 9, 'From', False]  0.08301 | 0.02257 0.20424 0.02222
# ['Multi', 9, 'To', False]  0.07488 | 0.07668 0.12396 0.02399
# ['Multi', 9, 'MeanColumns', False]  0.08301 | 0.02257 0.20424 0.02222
# ['Multi', 9, 'MaxColumns', False]  0.08298 | 0.02251 0.20423 0.02219
# ['Multi', 10, 'From', False]  0.05232 | 0.018 0.11223 0.02673
# ['Multi', 10, 'To', False]  0.11565 | 0.03157 0.28948 0.02589
# ['Multi', 10, 'MeanColumns', False]  0.05232 | 0.018 0.11223 0.02673
# ['Multi', 10, 'MaxColumns', False]  0.05232 | 0.018 0.11223 0.02673
# ['Multi', 11, 'From', False]  0.02736 | 0.00783 0.05881 0.01544
# ['Multi', 11, 'To', False]  0.15143 | 0.02549 0.39721 0.03158
# ['Multi', 11, 'MeanColumns', False]  0.02736 | 0.00783 0.05881 0.01544
# ['Multi', 11, 'MaxColumns', False]  0.02736 | 0.00783 0.05881 0.01544
# [0, 'Mean', 'From', False]  0.10865 | 0.00769 0.30722 0.01104
# [0, 'Mean', 'To', False]  0.21344 | 0.07777 0.53068 0.03186
# [0, 'Mean', 'MeanColumns', False]  0.1133 | 0.00836 0.31556 0.01599
# [0, 'Mean', 'MaxColumns', False]  0.09637 | 0.03501 0.22575 0.02836
# [0, 0, 'From', False]  0.05674 | 0.00615 0.14916 0.0149
# [0, 0, 'To', False]  0.21606 | 0.13705 0.47511 0.03603
# [0, 0, 'MeanColumns', False]  0.10117 | 0.02869 0.24542 0.0294
# [0, 0, 'MaxColumns', False]  0.03015 | 0.00611 0.06945 0.01489
# [0, 1, 'From', False]  0.10584 | 0.00849 0.29704 0.01199
# [0, 1, 'To', False]  0.20958 | 0.07685 0.52023 0.03165
# [0, 1, 'MeanColumns', False]  0.11768 | 0.00729 0.33316 0.0126
# [0, 1, 'MaxColumns', False]  0.11374 | 0.00758 0.32002 0.01361
# [0, 2, 'From', False]  0.19321 | 0.05529 0.5095 0.01485
# [0, 2, 'To', False]  0.2133 | 0.11568 0.4811 0.04314
# [0, 2, 'MeanColumns', False]  0.07653 | 0.02768 0.16809 0.03383
# [0, 2, 'MaxColumns', False]  0.11312 | 0.04438 0.25615 0.03883
# [0, 3, 'From', False]  0.21311 | 0.07743 0.52997 0.03193
# [0, 3, 'To', False]  0.06769 | 0.01069 0.1689 0.0235
# [0, 3, 'MeanColumns', False]  0.08253 | 0.02208 0.20345 0.02206
# [0, 3, 'MaxColumns', False]  0.08685 | 0.02361 0.22302 0.01391
# [0, 4, 'From', False]  0.05671 | 0.01598 0.13133 0.0228
# [0, 4, 'To', False]  0.21309 | 0.07619 0.53143 0.03164
# [0, 4, 'MeanColumns', False]  0.13561 | 0.07906 0.28848 0.0393
# [0, 4, 'MaxColumns', False]  0.14028 | 0.06398 0.3237 0.03314
# [0, 5, 'From', False]  0.05867 | 0.02676 0.12702 0.02223
# [0, 5, 'To', False]  0.04531 | 0.00843 0.11296 0.01453
# [0, 5, 'MeanColumns', False]  0.08078 | 0.04935 0.16603 0.02697
# [0, 5, 'MaxColumns', False]  0.13084 | 0.10186 0.25315 0.0375
# [0, 6, 'From', False]  0.1127 | 0.00673 0.32164 0.00974
# [0, 6, 'To', False]  0.20703 | 0.07491 0.5218 0.02439
# [0, 6, 'MeanColumns', False]  0.12433 | 0.01838 0.34122 0.01338
# [0, 6, 'MaxColumns', False]  0.10757 | 0.05943 0.24081 0.02248
# [0, 7, 'From', False]  0.05825 | 0.02843 0.12554 0.02076
# [0, 7, 'To', False]  0.08338 | 0.07779 0.1363 0.03605
# [0, 7, 'MeanColumns', False]  0.10301 | 0.02127 0.26428 0.02347
# [0, 7, 'MaxColumns', False]  0.06167 | 0.03367 0.12983 0.02149
# [0, 8, 'From', False]  0.09552 | 0.00591 0.27119 0.00945
# [0, 8, 'To', False]  0.22781 | 0.13501 0.51293 0.03549
# [0, 8, 'MeanColumns', False]  0.10202 | 0.01831 0.2702 0.01755
# [0, 8, 'MaxColumns', False]  0.10534 | 0.045 0.24495 0.02608
# [0, 9, 'From', False]  0.0827 | 0.04359 0.17746 0.02705
# [0, 9, 'To', False]  0.13008 | 0.0903 0.26842 0.03151
# [0, 9, 'MeanColumns', False]  0.07095 | 0.00937 0.19218 0.01131
# [0, 9, 'MaxColumns', False]  0.09583 | 0.03489 0.24145 0.01116
# [0, 10, 'From', False]  0.06328 | 0.02762 0.13882 0.02338
# [0, 10, 'To', False]  0.09966 | 0.08068 0.1861 0.03221
# [0, 10, 'MeanColumns', False]  0.08038 | 0.02887 0.19218 0.02009
# [0, 10, 'MaxColumns', False]  0.08783 | 0.04034 0.20911 0.01404
# [0, 11, 'From', False]  0.17189 | 0.04976 0.45174 0.01416
# [0, 11, 'To', False]  0.19762 | 0.08626 0.47982 0.02679
# [0, 11, 'MeanColumns', False]  0.05185 | 0.0068 0.12864 0.02012
# [0, 11, 'MaxColumns', False]  0.12611 | 0.04606 0.32008 0.0122
# [1, 'Mean', 'From', False]  0.21613 | 0.17318 0.42504 0.05017
# [1, 'Mean', 'To', False]  0.03327 | 0.00835 0.07624 0.01522
# [1, 'Mean', 'MeanColumns', False]  0.18068 | 0.18234 0.30998 0.04972
# [1, 'Mean', 'MaxColumns', False]  0.17859 | 0.18637 0.30462 0.04479
# [1, 0, 'From', False]  0.2234 | 0.17187 0.45055 0.04778
# [1, 0, 'To', False]  0.2031 | 0.07508 0.50556 0.02866
# [1, 0, 'MeanColumns', False]  0.2025 | 0.21206 0.35086 0.04457
# [1, 0, 'MaxColumns', False]  0.21503 | 0.20715 0.39072 0.04722
# [1, 1, 'From', False]  0.20286 | 0.14313 0.41806 0.04738
# [1, 1, 'To', False]  0.21108 | 0.07852 0.53016 0.02456
# [1, 1, 'MeanColumns', False]  0.14975 | 0.06894 0.34175 0.03856
# [1, 1, 'MaxColumns', False]  0.18794 | 0.11784 0.40969 0.03628
# [1, 2, 'From', False]  0.22284 | 0.12222 0.51124 0.03508
# [1, 2, 'To', False]  0.14162 | 0.06332 0.34693 0.0146
# [1, 2, 'MeanColumns', False]  0.14661 | 0.11656 0.2798 0.04346
# [1, 2, 'MaxColumns', False]  0.16701 | 0.14405 0.3162 0.04078
# [1, 3, 'From', False]  0.22461 | 0.11793 0.5191 0.03681
# [1, 3, 'To', False]  0.02916 | 0.0071 0.06383 0.01654
# [1, 3, 'MeanColumns', False]  0.11102 | 0.05445 0.24282 0.03579
# [1, 3, 'MaxColumns', False]  0.142 | 0.09577 0.29477 0.03546
# [1, 4, 'From', False]  0.13345 | 0.10858 0.25989 0.03187
# [1, 4, 'To', False]  0.21309 | 0.07619 0.53143 0.03164
# [1, 4, 'MeanColumns', False]  0.10269 | 0.06273 0.20814 0.0372
# [1, 4, 'MaxColumns', False]  0.12725 | 0.07003 0.28498 0.02674
# [1, 5, 'From', False]  0.15829 | 0.13496 0.30406 0.03585
# [1, 5, 'To', False]  0.13161 | 0.03911 0.33634 0.01939
# [1, 5, 'MeanColumns', False]  0.14479 | 0.12475 0.27678 0.03283
# [1, 5, 'MaxColumns', False]  0.1639 | 0.13642 0.32264 0.03265
# [1, 6, 'From', False]  0.20789 | 0.1674 0.42528 0.03098
# [1, 6, 'To', False]  0.20998 | 0.08378 0.52601 0.02014
# [1, 6, 'MeanColumns', False]  0.12426 | 0.11706 0.22746 0.02825
# [1, 6, 'MaxColumns', False]  0.13636 | 0.11061 0.26931 0.02917
# [1, 7, 'From', False]  0.05547 | 0.00831 0.1268 0.0313
# [1, 7, 'To', False]  0.03175 | 0.00952 0.06733 0.01839
# [1, 7, 'MeanColumns', False]  0.11474 | 0.033 0.27434 0.03689
# [1, 7, 'MaxColumns', False]  0.07396 | 0.03484 0.16459 0.02244
# [1, 8, 'From', False]  0.20546 | 0.1281 0.45176 0.03653
# [1, 8, 'To', False]  0.18526 | 0.05474 0.47883 0.0222
# [1, 8, 'MeanColumns', False]  0.12862 | 0.06707 0.30395 0.01484
# [1, 8, 'MaxColumns', False]  0.12877 | 0.06515 0.2974 0.02375
# [1, 9, 'From', False]  0.13519 | 0.05344 0.33063 0.02151
# [1, 9, 'To', False]  0.16921 | 0.05535 0.4367 0.01559
# [1, 9, 'MeanColumns', False]  0.17214 | 0.13264 0.34503 0.03874
# [1, 9, 'MaxColumns', False]  0.14778 | 0.12274 0.28203 0.03855
# [1, 10, 'From', False]  0.13089 | 0.05971 0.27123 0.06173
# [1, 10, 'To', False]  0.06727 | 0.01995 0.15073 0.03112
# [1, 10, 'MeanColumns', False]  0.11041 | 0.07488 0.21888 0.03746
# [1, 10, 'MaxColumns', False]  0.1017 | 0.06413 0.20231 0.03868
# [1, 11, 'From', False]  0.21982 | 0.13834 0.4815 0.03964
# [1, 11, 'To', False]  0.04961 | 0.0124 0.1203 0.01613
# [1, 11, 'MeanColumns', False]  0.13203 | 0.1215 0.24735 0.02725
# [1, 11, 'MaxColumns', False]  0.19867 | 0.19361 0.3723 0.0301
# [2, 'Mean', 'From', False]  0.11766 | 0.03932 0.29981 0.01385
# [2, 'Mean', 'To', False]  0.03158 | 0.00834 0.07113 0.01528
# [2, 'Mean', 'MeanColumns', False]  0.13569 | 0.08828 0.26736 0.05143
# [2, 'Mean', 'MaxColumns', False]  0.14341 | 0.14305 0.23755 0.04963
# [2, 0, 'From', False]  0.18003 | 0.12334 0.37662 0.04014
# [2, 0, 'To', False]  0.19588 | 0.07701 0.48327 0.02736
# [2, 0, 'MeanColumns', False]  0.14318 | 0.1182 0.25822 0.05314
# [2, 0, 'MaxColumns', False]  0.15721 | 0.14429 0.27873 0.04861
# [2, 1, 'From', False]  0.10108 | 0.03493 0.23515 0.03315
# [2, 1, 'To', False]  0.20952 | 0.08066 0.52055 0.02734
# [2, 1, 'MeanColumns', False]  0.10828 | 0.02512 0.27958 0.02014
# [2, 1, 'MaxColumns', False]  0.1409 | 0.06729 0.33067 0.02473
# [2, 2, 'From', False]  0.16272 | 0.06166 0.40816 0.01834
# [2, 2, 'To', False]  0.03033 | 0.00806 0.0679 0.01503
# [2, 2, 'MeanColumns', False]  0.17686 | 0.16108 0.31577 0.05374
# [2, 2, 'MaxColumns', False]  0.18869 | 0.17287 0.34413 0.04907
# [2, 3, 'From', False]  0.20078 | 0.13877 0.42311 0.04046
# [2, 3, 'To', False]  0.02874 | 0.0074 0.06365 0.01517
# [2, 3, 'MeanColumns', False]  0.11633 | 0.06234 0.25432 0.03233
# [2, 3, 'MaxColumns', False]  0.13404 | 0.08313 0.28324 0.03576
# [2, 4, 'From', False]  0.02986 | 0.0078 0.0657 0.01609
# [2, 4, 'To', False]  0.21298 | 0.0762 0.53118 0.03156
# [2, 4, 'MeanColumns', False]  0.1092 | 0.05513 0.24298 0.02949
# [2, 4, 'MaxColumns', False]  0.1144 | 0.07019 0.24593 0.0271
# [2, 5, 'From', False]  0.12817 | 0.04224 0.31812 0.02414
# [2, 5, 'To', False]  0.10957 | 0.03045 0.2819 0.01635
# [2, 5, 'MeanColumns', False]  0.12866 | 0.06031 0.28432 0.04135
# [2, 5, 'MaxColumns', False]  0.12973 | 0.08432 0.26363 0.04124
# [2, 6, 'From', False]  0.05131 | 0.04066 0.0963 0.01696
# [2, 6, 'To', False]  0.14459 | 0.03406 0.37684 0.02287
# [2, 6, 'MeanColumns', False]  0.11055 | 0.06957 0.22903 0.03305
# [2, 6, 'MaxColumns', False]  0.12066 | 0.08921 0.24496 0.02779
# [2, 7, 'From', False]  0.12596 | 0.03969 0.31914 0.01905
# [2, 7, 'To', False]  0.04599 | 0.01496 0.10617 0.01685
# [2, 7, 'MeanColumns', False]  0.14973 | 0.04989 0.33302 0.06629
# [2, 7, 'MaxColumns', False]  0.09396 | 0.07194 0.17773 0.03221
# [2, 8, 'From', False]  0.07646 | 0.01915 0.19462 0.01562
# [2, 8, 'To', False]  0.0719 | 0.01122 0.189 0.01549
# [2, 8, 'MeanColumns', False]  0.09638 | 0.02048 0.24804 0.02062
# [2, 8, 'MaxColumns', False]  0.13347 | 0.04959 0.32422 0.02659
# [2, 9, 'From', False]  0.1208 | 0.00835 0.34604 0.00801
# [2, 9, 'To', False]  0.11484 | 0.00926 0.32627 0.009
# [2, 9, 'MeanColumns', False]  0.11622 | 0.02703 0.29037 0.03127
# [2, 9, 'MaxColumns', False]  0.09971 | 0.05626 0.205 0.03788
# [2, 10, 'From', False]  0.15728 | 0.10328 0.29847 0.07009
# [2, 10, 'To', False]  0.11193 | 0.04568 0.2624 0.02771
# [2, 10, 'MeanColumns', False]  0.08446 | 0.03322 0.1839 0.03627
# [2, 10, 'MaxColumns', False]  0.07464 | 0.03379 0.16346 0.02667
# [2, 11, 'From', False]  0.1808 | 0.09235 0.41438 0.03568
# [2, 11, 'To', False]  0.03166 | 0.00595 0.07462 0.01439
# [2, 11, 'MeanColumns', False]  0.06881 | 0.03625 0.14469 0.02549
# [2, 11, 'MaxColumns', False]  0.15655 | 0.10761 0.3307 0.03132
# [3, 'Mean', 'From', False]  0.13071 | 0.08443 0.28881 0.01889
# [3, 'Mean', 'To', False]  0.03081 | 0.00792 0.06919 0.01533
# [3, 'Mean', 'MeanColumns', False]  0.16814 | 0.12803 0.31157 0.06483
# [3, 'Mean', 'MaxColumns', False]  0.11371 | 0.09608 0.20221 0.04282
# [3, 0, 'From', False]  0.18892 | 0.12623 0.39626 0.04426
# [3, 0, 'To', False]  0.19129 | 0.05489 0.48212 0.03687
# [3, 0, 'MeanColumns', False]  0.2022 | 0.20032 0.34164 0.06464
# [3, 0, 'MaxColumns', False]  0.20079 | 0.21571 0.33787 0.04879
# [3, 1, 'From', False]  0.12341 | 0.05113 0.2757 0.0434
# [3, 1, 'To', False]  0.21449 | 0.08505 0.53838 0.02004
# [3, 1, 'MeanColumns', False]  0.18091 | 0.13846 0.35794 0.04634
# [3, 1, 'MaxColumns', False]  0.22331 | 0.19002 0.43046 0.04946
# [3, 2, 'From', False]  0.20972 | 0.12528 0.47779 0.0261
# [3, 2, 'To', False]  0.039 | 0.01 0.09058 0.0164
# [3, 2, 'MeanColumns', False]  0.18783 | 0.18524 0.32556 0.0527
# [3, 2, 'MaxColumns', False]  0.19205 | 0.17293 0.35027 0.05297
# [3, 3, 'From', False]  0.21851 | 0.22345 0.38252 0.04957
# [3, 3, 'To', False]  0.02835 | 0.00651 0.06402 0.01453
# [3, 3, 'MeanColumns', False]  0.12783 | 0.06378 0.28251 0.03721
# [3, 3, 'MaxColumns', False]  0.12445 | 0.054 0.28673 0.03262
# [3, 4, 'From', False]  0.03083 | 0.01089 0.06489 0.0167
# [3, 4, 'To', False]  0.21323 | 0.07711 0.5294 0.03318
# [3, 4, 'MeanColumns', False]  0.1722 | 0.08852 0.38898 0.0391
# [3, 4, 'MaxColumns', False]  0.1555 | 0.07888 0.35857 0.02904
# [3, 5, 'From', False]  0.12978 | 0.05124 0.31786 0.02024
# [3, 5, 'To', False]  0.11278 | 0.0236 0.29787 0.01686
# [3, 5, 'MeanColumns', False]  0.12504 | 0.076 0.25036 0.04875
# [3, 5, 'MaxColumns', False]  0.11717 | 0.07283 0.22849 0.05019
# [3, 6, 'From', False]  0.03572 | 0.02131 0.06891 0.01692
# [3, 6, 'To', False]  0.10408 | 0.01935 0.27945 0.01344
# [3, 6, 'MeanColumns', False]  0.08408 | 0.0477 0.17415 0.0304
# [3, 6, 'MaxColumns', False]  0.0887 | 0.04735 0.19212 0.02663
# [3, 7, 'From', False]  0.09726 | 0.00833 0.26978 0.01368
# [3, 7, 'To', False]  0.05762 | 0.01277 0.1474 0.0127
# [3, 7, 'MeanColumns', False]  0.14904 | 0.00863 0.35558 0.0829
# [3, 7, 'MaxColumns', False]  0.09169 | 0.01834 0.21151 0.04523
# [3, 8, 'From', False]  0.05712 | 0.03014 0.1233 0.01791
# [3, 8, 'To', False]  0.08961 | 0.02843 0.22973 0.01068
# [3, 8, 'MeanColumns', False]  0.09402 | 0.02432 0.23365 0.02409
# [3, 8, 'MaxColumns', False]  0.11404 | 0.0436 0.2699 0.02863
# [3, 9, 'From', False]  0.12316 | 0.01555 0.34698 0.00694
# [3, 9, 'To', False]  0.12262 | 0.01286 0.34682 0.00819
# [3, 9, 'MeanColumns', False]  0.11417 | 0.02564 0.26027 0.0566
# [3, 9, 'MaxColumns', False]  0.10255 | 0.04217 0.21881 0.04668
# [3, 10, 'From', False]  0.14633 | 0.10353 0.28067 0.05479
# [3, 10, 'To', False]  0.14409 | 0.05453 0.33493 0.04283
# [3, 10, 'MeanColumns', False]  0.09479 | 0.02761 0.23005 0.0267
# [3, 10, 'MaxColumns', False]  0.09169 | 0.0301 0.22105 0.02393
# [3, 11, 'From', False]  0.18482 | 0.09276 0.42896 0.03275
# [3, 11, 'To', False]  0.07154 | 0.00963 0.19232 0.01268
# [3, 11, 'MeanColumns', False]  0.11335 | 0.05681 0.25085 0.03241
# [3, 11, 'MaxColumns', False]  0.14728 | 0.08948 0.31399 0.03837
# [4, 'Mean', 'From', False]  0.19045 | 0.21873 0.32529 0.02734
# [4, 'Mean', 'To', False]  0.06706 | 0.01281 0.16909 0.0193
# [4, 'Mean', 'MeanColumns', False]  0.16733 | 0.18953 0.2666 0.04584
# [4, 'Mean', 'MaxColumns', False]  0.14002 | 0.15984 0.21981 0.04042
# [4, 0, 'From', False]  0.22661 | 0.2555 0.39623 0.0281
# [4, 0, 'To', False]  0.16972 | 0.04285 0.42338 0.04292
# [4, 0, 'MeanColumns', False]  0.23975 | 0.29977 0.35519 0.06427
# [4, 0, 'MaxColumns', False]  0.24387 | 0.30903 0.37036 0.05224
# [4, 1, 'From', False]  0.16774 | 0.13672 0.32645 0.04006
# [4, 1, 'To', False]  0.19682 | 0.07833 0.49143 0.0207
# [4, 1, 'MeanColumns', False]  0.15469 | 0.10562 0.3281 0.03036
# [4, 1, 'MaxColumns', False]  0.18456 | 0.17599 0.34994 0.02776
# [4, 2, 'From', False]  0.21858 | 0.14455 0.49407 0.01712
# [4, 2, 'To', False]  0.1465 | 0.02807 0.37662 0.0348
# [4, 2, 'MeanColumns', False]  0.17801 | 0.2272 0.25583 0.051
# [4, 2, 'MaxColumns', False]  0.18526 | 0.19898 0.31028 0.04651
# [4, 3, 'From', False]  0.16281 | 0.31605 0.14333 0.02903
# [4, 3, 'To', False]  0.02859 | 0.00586 0.06476 0.01514
# [4, 3, 'MeanColumns', False]  0.11145 | 0.07671 0.2195 0.03814
# [4, 3, 'MaxColumns', False]  0.11345 | 0.06907 0.22706 0.04422
# [4, 4, 'From', False]  0.03673 | 0.02825 0.06529 0.01666
# [4, 4, 'To', False]  0.21794 | 0.10919 0.50984 0.0348
# [4, 4, 'MeanColumns', False]  0.10773 | 0.05102 0.234 0.03817
# [4, 4, 'MaxColumns', False]  0.10027 | 0.04907 0.21857 0.03318
# [4, 5, 'From', False]  0.13236 | 0.111 0.23617 0.04991
# [4, 5, 'To', False]  0.1033 | 0.03229 0.24856 0.02904
# [4, 5, 'MeanColumns', False]  0.13431 | 0.12282 0.26037 0.01974
# [4, 5, 'MaxColumns', False]  0.12498 | 0.09489 0.25495 0.02509
# [4, 6, 'From', False]  0.12861 | 0.14929 0.21931 0.01722
# [4, 6, 'To', False]  0.15782 | 0.05177 0.40708 0.01461
# [4, 6, 'MeanColumns', False]  0.09282 | 0.05098 0.20286 0.02462
# [4, 6, 'MaxColumns', False]  0.0959 | 0.05945 0.20196 0.02627
# [4, 7, 'From', False]  0.10972 | 0.04167 0.25852 0.02898
# [4, 7, 'To', False]  0.09531 | 0.0175 0.25445 0.01398
# [4, 7, 'MeanColumns', False]  0.16506 | 0.01875 0.40534 0.0711
# [4, 7, 'MaxColumns', False]  0.09901 | 0.02445 0.2331 0.03948
# [4, 8, 'From', False]  0.08276 | 0.04355 0.18542 0.0193
# [4, 8, 'To', False]  0.11946 | 0.08799 0.2327 0.03769
# [4, 8, 'MeanColumns', False]  0.04903 | 0.01927 0.10916 0.01867
# [4, 8, 'MaxColumns', False]  0.13478 | 0.03555 0.34952 0.01927
# [4, 9, 'From', False]  0.15293 | 0.117 0.31517 0.02663
# [4, 9, 'To', False]  0.12478 | 0.0334 0.30813 0.03281
# [4, 9, 'MeanColumns', False]  0.07179 | 0.0222 0.17709 0.01608
# [4, 9, 'MaxColumns', False]  0.11204 | 0.05876 0.24432 0.03304
# [4, 10, 'From', False]  0.14171 | 0.11246 0.25871 0.05395
# [4, 10, 'To', False]  0.12438 | 0.03232 0.2967 0.04414
# [4, 10, 'MeanColumns', False]  0.13149 | 0.04555 0.31366 0.03525
# [4, 10, 'MaxColumns', False]  0.12139 | 0.03435 0.30284 0.02699
# [4, 11, 'From', False]  0.08703 | 0.04973 0.19319 0.01819
# [4, 11, 'To', False]  0.07749 | 0.01256 0.19963 0.02029
# [4, 11, 'MeanColumns', False]  0.07698 | 0.08738 0.11954 0.02402
# [4, 11, 'MaxColumns', False]  0.18738 | 0.19784 0.32831 0.036
# [5, 'Mean', 'From', False]  0.22038 | 0.27722 0.34121 0.0427
# [5, 'Mean', 'To', False]  0.13404 | 0.07579 0.29667 0.02964
# ...
# [0, 10, 'To', False]  0.25307 | 0.27221 0.23499 0.25201
# [0, 10, 'MeanColumns', False]  0.20885 | 0.19454 0.14583 0.28618
# [0, 10, 'MaxColumns', False]  0.23256 | 0.2157 0.17894 0.30304
# [0, 11, 'From', False]  0.30051 | 0.30377 0.19739 0.40038
# [0, 11, 'To', False]  0.43638 | 0.42211 0.3513 0.53572
# [0, 11, 'MeanColumns', False]  0.20364 | 0.19889 0.16039 0.25163
# [0, 11, 'MaxColumns', False]  0.25898 | 0.26614 0.18325 0.32755
# [1, 'Mean', 'From', False]  0.37789 | 0.41077 0.30375 0.41917
# [1, 'Mean', 'To', False]  0.18299 | 0.18337 0.11143 0.25416
# [1, 'Mean', 'MeanColumns', False]  0.3268 | 0.37504 0.27796 0.3274
# [1, 'Mean', 'MaxColumns', False]  0.33438 | 0.38171 0.2743 0.34714
# [1, 0, 'From', False]  0.38339 | 0.41338 0.28355 0.45323
# [1, 0, 'To', False]  0.31924 | 0.30802 0.19207 0.45763
# [1, 0, 'MeanColumns', False]  0.36388 | 0.40263 0.33137 0.35766
# [1, 0, 'MaxColumns', False]  0.36052 | 0.39592 0.30546 0.38018
# [1, 1, 'From', False]  0.37044 | 0.39809 0.29986 0.41337
# [1, 1, 'To', False]  0.34517 | 0.35114 0.21821 0.46615
# [1, 1, 'MeanColumns', False]  0.32316 | 0.34233 0.26814 0.359
# [1, 1, 'MaxColumns', False]  0.34958 | 0.3625 0.28347 0.40277
# [1, 2, 'From', False]  0.39205 | 0.4156 0.25536 0.50518
# [1, 2, 'To', False]  0.28665 | 0.3006 0.18195 0.37741
# [1, 2, 'MeanColumns', False]  0.27514 | 0.28831 0.2401 0.297
# [1, 2, 'MaxColumns', False]  0.30917 | 0.33265 0.26295 0.33192
# [1, 3, 'From', False]  0.35145 | 0.37853 0.22579 0.45004
# [1, 3, 'To', False]  0.23145 | 0.21995 0.18317 0.29123
# [1, 3, 'MeanColumns', False]  0.24185 | 0.25136 0.20091 0.27329
# [1, 3, 'MaxColumns', False]  0.28866 | 0.30752 0.24591 0.31254
# [1, 4, 'From', False]  0.34037 | 0.34082 0.31866 0.36164
# [1, 4, 'To', False]  0.27787 | 0.27999 0.16885 0.38477
# [1, 4, 'MeanColumns', False]  0.27997 | 0.27866 0.25158 0.30968
# [1, 4, 'MaxColumns', False]  0.31789 | 0.31552 0.2759 0.36225
# [1, 5, 'From', False]  0.42898 | 0.42326 0.44063 0.42306
# [1, 5, 'To', False]  0.18114 | 0.1873 0.11281 0.24331
# [1, 5, 'MeanColumns', False]  0.34427 | 0.36827 0.28052 0.38402
# [1, 5, 'MaxColumns', False]  0.35448 | 0.37503 0.28847 0.39995
# [1, 6, 'From', False]  0.36171 | 0.3902 0.28155 0.41337
# [1, 6, 'To', False]  0.38127 | 0.38678 0.26933 0.48772
# [1, 6, 'MeanColumns', False]  0.2944 | 0.32993 0.23639 0.3169
# [1, 6, 'MaxColumns', False]  0.27733 | 0.30444 0.21752 0.31003
# [1, 7, 'From', False]  0.18377 | 0.19164 0.15556 0.20411
# [1, 7, 'To', False]  0.16324 | 0.17233 0.09963 0.21776
# [1, 7, 'MeanColumns', False]  0.20197 | 0.20629 0.12993 0.26968
# [1, 7, 'MaxColumns', False]  0.20051 | 0.20342 0.1313 0.2668
# [1, 8, 'From', False]  0.43501 | 0.44816 0.34341 0.51346
# [1, 8, 'To', False]  0.28969 | 0.28708 0.20528 0.37671
# [1, 8, 'MeanColumns', False]  0.32642 | 0.32073 0.28824 0.37028
# [1, 8, 'MaxColumns', False]  0.28557 | 0.28119 0.21703 0.35849
# [1, 9, 'From', False]  0.31646 | 0.33322 0.26359 0.35256
# [1, 9, 'To', False]  0.24913 | 0.24362 0.17952 0.32425
# [1, 9, 'MeanColumns', False]  0.31285 | 0.35998 0.22597 0.35259
# [1, 9, 'MaxColumns', False]  0.28838 | 0.33387 0.20294 0.32832
# [1, 10, 'From', False]  0.24157 | 0.25828 0.21424 0.2522
# [1, 10, 'To', False]  0.17874 | 0.17918 0.12673 0.23033
# [1, 10, 'MeanColumns', False]  0.26381 | 0.27802 0.223 0.29041
# [1, 10, 'MaxColumns', False]  0.25201 | 0.26873 0.2039 0.28338
# [1, 11, 'From', False]  0.43345 | 0.4567 0.2933 0.55036
# [1, 11, 'To', False]  0.19461 | 0.20661 0.12823 0.24899
# [1, 11, 'MeanColumns', False]  0.24892 | 0.27803 0.2037 0.26502
# [1, 11, 'MaxColumns', False]  0.33656 | 0.38511 0.26551 0.35906
# [2, 'Mean', 'From', False]  0.34885 | 0.34473 0.33878 0.36304
# [2, 'Mean', 'To', False]  0.20148 | 0.19968 0.13132 0.27345
# [2, 'Mean', 'MeanColumns', False]  0.28638 | 0.29821 0.26273 0.29818
# [2, 'Mean', 'MaxColumns', False]  0.30925 | 0.33782 0.28245 0.30748
# [2, 0, 'From', False]  0.33521 | 0.34525 0.26826 0.39212
# [2, 0, 'To', False]  0.29653 | 0.27747 0.17783 0.4343
# [2, 0, 'MeanColumns', False]  0.27529 | 0.28734 0.2579 0.28062
# [2, 0, 'MaxColumns', False]  0.29652 | 0.31659 0.26819 0.30477
# [2, 1, 'From', False]  0.3008 | 0.28388 0.30084 0.3177
# [2, 1, 'To', False]  0.34278 | 0.34365 0.21244 0.47226
# [2, 1, 'MeanColumns', False]  0.29879 | 0.29779 0.25162 0.34695
# [2, 1, 'MaxColumns', False]  0.34617 | 0.34058 0.31193 0.38601
# [2, 2, 'From', False]  0.35537 | 0.34255 0.2862 0.43736
# [2, 2, 'To', False]  0.20697 | 0.20447 0.14467 0.27176
# [2, 2, 'MeanColumns', False]  0.33282 | 0.34878 0.3154 0.33427
# [2, 2, 'MaxColumns', False]  0.35529 | 0.37155 0.33201 0.36232
# [2, 3, 'From', False]  0.31098 | 0.35264 0.20666 0.37365
# [2, 3, 'To', False]  0.19325 | 0.1917 0.14584 0.2422
# [2, 3, 'MeanColumns', False]  0.23771 | 0.25802 0.16834 0.28677
# [2, 3, 'MaxColumns', False]  0.27108 | 0.28781 0.20374 0.32168
# [2, 4, 'From', False]  0.19688 | 0.1971 0.16835 0.22518
# [2, 4, 'To', False]  0.27133 | 0.26831 0.16474 0.38094
# [2, 4, 'MeanColumns', False]  0.21877 | 0.22914 0.15206 0.2751
# [2, 4, 'MaxColumns', False]  0.23258 | 0.24295 0.16255 0.29224
# [2, 5, 'From', False]  0.33937 | 0.31926 0.34042 0.35843
# [2, 5, 'To', False]  0.23398 | 0.22979 0.15457 0.31759
# [2, 5, 'MeanColumns', False]  0.28571 | 0.2798 0.26507 0.31226
# [2, 5, 'MaxColumns', False]  0.26888 | 0.28218 0.22641 0.29805
# [2, 6, 'From', False]  0.2537 | 0.27347 0.19394 0.29369
# [2, 6, 'To', False]  0.34755 | 0.32418 0.30209 0.41639
# [2, 6, 'MeanColumns', False]  0.27693 | 0.29416 0.22697 0.30966
# [2, 6, 'MaxColumns', False]  0.27461 | 0.28995 0.22497 0.30891
# [2, 7, 'From', False]  0.32736 | 0.32063 0.33379 0.32766
# [2, 7, 'To', False]  0.1906 | 0.19898 0.1197 0.25311
# [2, 7, 'MeanColumns', False]  0.25967 | 0.26169 0.22391 0.29339
# [2, 7, 'MaxColumns', False]  0.24916 | 0.2647 0.20218 0.28059
# [2, 8, 'From', False]  0.3237 | 0.31766 0.28226 0.37119
# [2, 8, 'To', False]  0.26934 | 0.26599 0.21765 0.32438
# [2, 8, 'MeanColumns', False]  0.26707 | 0.25768 0.23168 0.31186
# [2, 8, 'MaxColumns', False]  0.25142 | 0.24275 0.20593 0.30557
# [2, 9, 'From', False]  0.31946 | 0.31241 0.30002 0.34595
# [2, 9, 'To', False]  0.29981 | 0.28165 0.26588 0.35189
# [2, 9, 'MeanColumns', False]  0.2718 | 0.26615 0.26489 0.28437
# [2, 9, 'MaxColumns', False]  0.24841 | 0.26014 0.23142 0.25367
# [2, 10, 'From', False]  0.278 | 0.29831 0.27303 0.26265
# [2, 10, 'To', False]  0.21319 | 0.22555 0.13064 0.28338
# [2, 10, 'MeanColumns', False]  0.22444 | 0.23414 0.18308 0.25609
# [2, 10, 'MaxColumns', False]  0.22488 | 0.23365 0.17732 0.26368
# [2, 11, 'From', False]  0.39395 | 0.3862 0.33687 0.45878
# [2, 11, 'To', False]  0.19526 | 0.20136 0.14963 0.23478
# [2, 11, 'MeanColumns', False]  0.21312 | 0.22286 0.16683 0.24967
# [2, 11, 'MaxColumns', False]  0.28703 | 0.32124 0.20911 0.33076
# [3, 'Mean', 'From', False]  0.33834 | 0.35477 0.29641 0.36385
# [3, 'Mean', 'To', False]  0.22026 | 0.21849 0.15057 0.29172
# [3, 'Mean', 'MeanColumns', False]  0.28853 | 0.31066 0.2682 0.28673
# [3, 'Mean', 'MaxColumns', False]  0.28766 | 0.28957 0.28044 0.29297
# [3, 0, 'From', False]  0.35568 | 0.36079 0.28098 0.42528
# [3, 0, 'To', False]  0.34902 | 0.31185 0.22694 0.50827
# [3, 0, 'MeanColumns', False]  0.34176 | 0.37106 0.33443 0.31981
# [3, 0, 'MaxColumns', False]  0.34932 | 0.37645 0.32693 0.34457
# [3, 1, 'From', False]  0.30014 | 0.28876 0.2898 0.32188
# [3, 1, 'To', False]  0.32648 | 0.33954 0.19557 0.44432
# [3, 1, 'MeanColumns', False]  0.37477 | 0.3874 0.34306 0.39384
# [3, 1, 'MaxColumns', False]  0.4269 | 0.41592 0.42116 0.44362
# [3, 2, 'From', False]  0.35752 | 0.36599 0.24633 0.46024
# [3, 2, 'To', False]  0.19358 | 0.1993 0.13003 0.25142
# [3, 2, 'MeanColumns', False]  0.38868 | 0.39245 0.42161 0.35198
# [3, 2, 'MaxColumns', False]  0.38411 | 0.38358 0.40368 0.36506
# [3, 3, 'From', False]  0.3605 | 0.43537 0.26495 0.38118
# [3, 3, 'To', False]  0.19873 | 0.18873 0.15499 0.25246
# [3, 3, 'MeanColumns', False]  0.27683 | 0.26923 0.2505 0.31075
# [3, 3, 'MaxColumns', False]  0.27283 | 0.25349 0.24714 0.31786
# [3, 4, 'From', False]  0.21278 | 0.22032 0.18719 0.23084
# [3, 4, 'To', False]  0.26688 | 0.26544 0.1726 0.36259
# [3, 4, 'MeanColumns', False]  0.33088 | 0.30625 0.30403 0.38236
# [3, 4, 'MaxColumns', False]  0.31418 | 0.29402 0.25991 0.3886
# [3, 5, 'From', False]  0.3303 | 0.33545 0.29534 0.36009
# [3, 5, 'To', False]  0.28856 | 0.27728 0.23669 0.3517
# [3, 5, 'MeanColumns', False]  0.2169 | 0.23021 0.17459 0.2459
# [3, 5, 'MaxColumns', False]  0.21265 | 0.23131 0.15886 0.24777
# [3, 6, 'From', False]  0.26601 | 0.27876 0.22138 0.29788
# [3, 6, 'To', False]  0.28736 | 0.27899 0.23786 0.34524
# [3, 6, 'MeanColumns', False]  0.24713 | 0.25946 0.19649 0.28543
# [3, 6, 'MaxColumns', False]  0.245 | 0.25467 0.19596 0.28438
# [3, 7, 'From', False]  0.26916 | 0.2667 0.24818 0.2926
# [3, 7, 'To', False]  0.21069 | 0.21342 0.15239 0.26626
# [3, 7, 'MeanColumns', False]  0.16339 | 0.17 0.10502 0.21514
# [3, 7, 'MaxColumns', False]  0.16996 | 0.17985 0.11003 0.21998
# [3, 8, 'From', False]  0.32168 | 0.32346 0.2711 0.37049
# [3, 8, 'To', False]  0.2693 | 0.27834 0.21263 0.31694
# [3, 8, 'MeanColumns', False]  0.25343 | 0.24019 0.22196 0.29813
# [3, 8, 'MaxColumns', False]  0.28141 | 0.25394 0.25206 0.33823
# [3, 9, 'From', False]  0.32791 | 0.32652 0.30935 0.34785
# [3, 9, 'To', False]  0.31947 | 0.30925 0.29517 0.35398
# [3, 9, 'MeanColumns', False]  0.20969 | 0.2279 0.15391 0.24726
# [3, 9, 'MaxColumns', False]  0.20598 | 0.23407 0.14437 0.23949
# [3, 10, 'From', False]  0.29552 | 0.30855 0.32658 0.25142
# [3, 10, 'To', False]  0.24757 | 0.25281 0.16856 0.32135
# [3, 10, 'MeanColumns', False]  0.19965 | 0.21094 0.13428 0.25373
# [3, 10, 'MaxColumns', False]  0.19607 | 0.20461 0.12362 0.25997
# [3, 11, 'From', False]  0.42652 | 0.41042 0.39893 0.47022
# [3, 11, 'To', False]  0.25923 | 0.2767 0.22907 0.27191
# [3, 11, 'MeanColumns', False]  0.30734 | 0.30035 0.29735 0.32433
# [3, 11, 'MaxColumns', False]  0.35278 | 0.34552 0.33028 0.38255
# [4, 'Mean', 'From', False]  0.42221 | 0.47673 0.42045 0.36944
# [4, 'Mean', 'To', False]  0.27871 | 0.26479 0.23851 0.33282
# [4, 'Mean', 'MeanColumns', False]  0.30677 | 0.36609 0.25832 0.29591
# [4, 'Mean', 'MaxColumns', False]  0.30261 | 0.35529 0.26581 0.28674
# [4, 0, 'From', False]  0.50728 | 0.55957 0.51207 0.45021
# [4, 0, 'To', False]  0.32825 | 0.25278 0.26677 0.46521
# [4, 0, 'MeanColumns', False]  0.40223 | 0.45872 0.41858 0.32938
# [4, 0, 'MaxColumns', False]  0.40243 | 0.46477 0.39778 0.34475
# [4, 1, 'From', False]  0.38454 | 0.39901 0.38033 0.37427
# [4, 1, 'To', False]  0.32583 | 0.31802 0.2127 0.44678
# [4, 1, 'MeanColumns', False]  0.31311 | 0.33909 0.25568 0.34456
# [4, 1, 'MaxColumns', False]  0.35151 | 0.37426 0.31786 0.36242
# [4, 2, 'From', False]  0.34492 | 0.39176 0.22985 0.41314
# [4, 2, 'To', False]  0.27671 | 0.26643 0.2052 0.35852
# [4, 2, 'MeanColumns', False]  0.32767 | 0.37907 0.3172 0.28673
# [4, 2, 'MaxColumns', False]  0.33716 | 0.35465 0.34313 0.31371
# [4, 3, 'From', False]  0.37201 | 0.50519 0.30917 0.30168
# [4, 3, 'To', False]  0.21851 | 0.21472 0.16562 0.2752
# [4, 3, 'MeanColumns', False]  0.24996 | 0.26233 0.21097 0.27657
# [4, 3, 'MaxColumns', False]  0.25138 | 0.2551 0.20573 0.29332
# [4, 4, 'From', False]  0.26941 | 0.30196 0.23944 0.26682
# [4, 4, 'To', False]  0.28329 | 0.29059 0.18427 0.37501
# [4, 4, 'MeanColumns', False]  0.25215 | 0.25966 0.20652 0.29028
# [4, 4, 'MaxColumns', False]  0.2525 | 0.2586 0.19448 0.30443
# [4, 5, 'From', False]  0.39345 | 0.38294 0.41974 0.37768
# [4, 5, 'To', False]  0.30582 | 0.27576 0.28583 0.35586
# [4, 5, 'MeanColumns', False]  0.3008 | 0.34143 0.22996 0.331
# [4, 5, 'MaxColumns', False]  0.28286 | 0.32074 0.19621 0.33161
# [4, 6, 'From', False]  0.31985 | 0.38601 0.22417 0.34937
# [4, 6, 'To', False]  0.33783 | 0.33619 0.25818 0.41914
# [4, 6, 'MeanColumns', False]  0.21588 | 0.2301 0.14715 0.27039
# [4, 6, 'MaxColumns', False]  0.21174 | 0.22265 0.15065 0.26191
# [4, 7, 'From', False]  0.2524 | 0.24955 0.24868 0.25896
# [4, 7, 'To', False]  0.28568 | 0.27637 0.27004 0.31062
# [4, 7, 'MeanColumns', False]  0.18873 | 0.20595 0.11326 0.24698
# [4, 7, 'MaxColumns', False]  0.1846 | 0.20077 0.11072 0.24231
# [4, 8, 'From', False]  0.30469 | 0.31935 0.21529 0.37944
# [4, 8, 'To', False]  0.28584 | 0.32403 0.25664 0.27685
# [4, 8, 'MeanColumns', False]  0.1896 | 0.19126 0.12856 0.24898
# [4, 8, 'MaxColumns', False]  0.22594 | 0.21898 0.16271 0.29612
# [4, 9, 'From', False]  0.39263 | 0.42271 0.40766 0.34751
# [4, 9, 'To', False]  0.3208 | 0.27281 0.32718 0.3624
# [4, 9, 'MeanColumns', False]  0.2503 | 0.26848 0.19444 0.28796
# [4, 9, 'MaxColumns', False]  0.26363 | 0.302 0.1999 0.28899
# [4, 10, 'From', False]  0.32103 | 0.34457 0.37106 0.24746
# [4, 10, 'To', False]  0.21879 | 0.23724 0.14684 0.27228
# [4, 10, 'MeanColumns', False]  0.27097 | 0.27788 0.17901 0.35602
# [4, 10, 'MaxColumns', False]  0.258 | 0.2534 0.16025 0.36035
# [4, 11, 'From', False]  0.36359 | 0.37637 0.37039 0.344
# [4, 11, 'To', False]  0.26548 | 0.28082 0.24221 0.2734
# [4, 11, 'MeanColumns', False]  0.27258 | 0.30794 0.23004 0.27977
# [4, 11, 'MaxColumns', False]  0.34609 | 0.39896 0.28668 0.35263
# [5, 'Mean', 'From', False]  0.48168 | 0.52388 0.5209 0.40027
# [5, 'Mean', 'To', False]  0.32318 | 0.30765 0.27134 0.39054
# [5, 'Mean', 'MeanColumns', False]  0.36835 | 0.44415 0.32965 0.33125
# [5, 'Mean', 'MaxColumns', False]  0.3326 | 0.34234 0.34821 0.30723
# [5, 0, 'From', False]  0.55018 | 0.61942 0.59281 0.43831
# [5, 0, 'To', False]  0.3695 | 0.34217 0.28949 0.47682
# [5, 0, 'MeanColumns', False]  0.38504 | 0.43987 0.4305 0.28476
# [5, 0, 'MaxColumns', False]  0.39367 | 0.45417 0.42642 0.30043
# [5, 1, 'From', False]  0.39787 | 0.41186 0.38935 0.39241
# [5, 1, 'To', False]  0.3026 | 0.31353 0.16446 0.42982
# [5, 1, 'MeanColumns', False]  0.34971 | 0.36263 0.28641 0.4001
# [5, 1, 'MaxColumns', False]  0.42189 | 0.41751 0.40103 0.44712
# [5, 2, 'From', False]  0.35725 | 0.41283 0.23397 0.42494
# [5, 2, 'To', False]  0.22717 | 0.20535 0.17294 0.30321
# [5, 2, 'MeanColumns', False]  0.44234 | 0.49052 0.46764 0.36886
# [5, 2, 'MaxColumns', False]  0.45201 | 0.46663 0.48536 0.40404
# [5, 3, 'From', False]  0.38553 | 0.49704 0.35208 0.30747
# [5, 3, 'To', False]  0.29597 | 0.28012 0.26172 0.34607
# [5, 3, 'MeanColumns', False]  0.20254 | 0.20765 0.14962 0.25034
# [5, 3, 'MaxColumns', False]  0.23149 | 0.22299 0.17961 0.29188
# [5, 4, 'From', False]  0.29274 | 0.34116 0.2556 0.28146
# [5, 4, 'To', False]  0.31541 | 0.30467 0.22873 0.41283
# [5, 4, 'MeanColumns', False]  0.18199 | 0.19593 0.12063 0.22941
# [5, 4, 'MaxColumns', False]  0.19305 | 0.20332 0.12712 0.24871
# [5, 5, 'From', False]  0.4137 | 0.37355 0.49794 0.36962
# [5, 5, 'To', False]  0.30306 | 0.26665 0.25367 0.38888
# [5, 5, 'MeanColumns', False]  0.34191 | 0.39695 0.27711 0.35167
# [5, 5, 'MaxColumns', False]  0.31766 | 0.3598 0.2388 0.35436
# [5, 6, 'From', False]  0.35457 | 0.40577 0.25538 0.40255
# [5, 6, 'To', False]  0.24509 | 0.24603 0.16161 0.32762
# [5, 6, 'MeanColumns', False]  0.29777 | 0.3114 0.22231 0.3596
# [5, 6, 'MaxColumns', False]  0.29391 | 0.29875 0.231 0.35199
# [5, 7, 'From', False]  0.23 | 0.24291 0.22408 0.223
# [5, 7, 'To', False]  0.27209 | 0.28782 0.21413 0.31433
# [5, 7, 'MeanColumns', False]  0.23883 | 0.25129 0.16745 0.29776
# [5, 7, 'MaxColumns', False]  0.2083 | 0.20776 0.14294 0.27419
# [5, 8, 'From', False]  0.32054 | 0.32547 0.23496 0.40119
# [5, 8, 'To', False]  0.21525 | 0.23405 0.16059 0.2511
# [5, 8, 'MeanColumns', False]  0.22407 | 0.22021 0.1576 0.2944
# [5, 8, 'MaxColumns', False]  0.27726 | 0.24557 0.2122 0.37402
# [5, 9, 'From', False]  0.43569 | 0.48444 0.49513 0.32751
# [5, 9, 'To', False]  0.26748 | 0.21222 0.22635 0.36386
# [5, 9, 'MeanColumns', False]  0.32816 | 0.35981 0.2955 0.32919
# [5, 9, 'MaxColumns', False]  0.33713 | 0.3641 0.32669 0.32059
# [5, 10, 'From', False]  0.29507 | 0.3083 0.3535 0.22341
# [5, 10, 'To', False]  0.24225 | 0.25313 0.18867 0.28496
# [5, 10, 'MeanColumns', False]  0.22426 | 0.24066 0.15578 0.27634
# [5, 10, 'MaxColumns', False]  0.21378 | 0.2201 0.1426 0.27865
# [5, 11, 'From', False]  0.35339 | 0.34945 0.36415 0.34657
# [5, 11, 'To', False]  0.23062 | 0.22527 0.23309 0.23348
# [5, 11, 'MeanColumns', False]  0.30096 | 0.32213 0.27367 0.30708
# [5, 11, 'MaxColumns', False]  0.35872 | 0.38076 0.31888 0.37653

# %% [markdown]
# We calculate the best attention setup using Optimus variations (we do not use the Optimus implementation at this step)

# %%
print_results_ap(metrics, label_names, conf)
# Out:
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Baseline: -7.374841293206202e-10  and NZW: 1.0 and AUPRC: 0.6020347240644445
# Max Across: -2.528158978461666e-10  and NZW: 0.9998916666666666 and AUPRC: 0.5092589421414682
# Per Label Per Instance: 0.2646716823268673  and NZW:  0.9988386072449177 and AUPRC: 0.31096573110917985
# Per Instance: 4.874575742127204e-08  and NZW:  0.998990825035562 and AUPRC: 0.2596425935642796

# %%
print_results_ap(metricsP, label_names, conf)
# Out:
# Baseline: 0.6118434526199982  and NZW: 1.0 and AUPRC: 0.6020347240644445
# Max Across: 0.6635175797975238  and NZW: 1.0 and AUPRC: 0.6037004655488016
# Per Label Per Instance: 0.8633359336237785  and NZW:  0.997529437930103 and AUPRC: 0.563042594072341
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# Per Instance: 0.8633359336237785  and NZW:  0.997529437930103 and AUPRC: 0.4381637140602424

# %% [markdown]
# We repeat the process with Attention Scores with negative values (A*), thus by skipping the Softmax function. In the attention setups, we exclude the multiplication option in heads and layers, as a few combinations reach +/-inf

# %%
conf = []
for ci in ['Mean'] + list(range(12)):
    for ce in ['Mean'] + list(range(12)):
        for cp in ['From', 'To', 'MeanColumns', 'MaxColumns']: # Matrix: From, To, MeanColumns, MeanRows, MaxColumns, MaxRows
            for cl in [False]: # Selection: True: select layers per head, False: do not
                conf.append([ci, ce, cp, cl])
len(conf)
# Out:
# 676

# %%
import time 
import math
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    
    now = datetime.datetime.now()
    
    file_name = save_path + 'ESNLI_ALBERT_A_ATTENTION_NO_SOFTMAX_'+str(now.day) + '_' + str(now.month) + '_' + str(now.year)
    metrics = {'FTP':[], 'F':[], 'NZW':[], 'AUPRC' : []}
    metricsP = {'FTP':[], 'F':[], 'NZW':[], 'AUPRC' : []}
    time_r = []
    time_b = []
    time_b2 = []
    for con in conf:
        time_r.append([])
    for ind in tqdm(range(len(test_texts))):
        torch.cuda.empty_cache() 
        test_rational = new_rationale[ind]
        instance = test_texts[ind]
        my_evaluators.clear_states()
        my_evaluatorsP.clear_states()
        my_explainers.save_states = {}
        prediction, _, hidden_states = model.my_predict(instance)
        enc = model.tokenizer([instance,instance], truncation=True, padding=True)[0]
        mask = enc.attention_mask
        tokens = enc.tokens
        
        attention = []
        for la in range(12):
            our_new_layer = []
            bob =  model.trainer.model.base_model.encoder.albert_layer_groups[0].albert_layers[0].attention
            has = hidden_states[la]
            aaa = bob.key(torch.tensor(has).to('cuda'))
            bbb = bob.query(torch.tensor(has).to('cuda'))
            for he in range(12):
                attention_scores = torch.matmul(bbb[:,he*64:(he+1)*64], aaa[:,he*64:(he+1)*64].transpose(-1, -2))
                attention_scores = attention_scores / math.sqrt(64)
                our_new_layer.append(attention_scores.cpu().detach().numpy())
            attention.append(our_new_layer)
        attention = np.array(attention)
        
        interpretations = []
        kk = 0
        for con in conf:
            ts = time.time()
            my_explainers.config = con
            temp = my_explainers.my_attention(instance, prediction, tokens, mask, attention, _)
            interpretations.append([maxabs_scale(i) for i in temp])
            time_r.append(time.time()-ts)
            kk = kk + 1
        for metric in metrics.keys():
            evaluated = []
            k = 0
            for interpretation in interpretations:
                tt = time.time()
                evaluated.append(evaluation[metric](interpretation, _, instance, prediction, tokens, _, _, test_rational))
                k = k + (time.time()-tt)
            if metric == 'FTP':
                time_b.append(k)
            metrics[metric].append(evaluated)
        my_evaluatorsP.saved_state = my_evaluators.saved_state.copy()
        for metric in metrics.keys():
            evaluated = []
            k = 0
            for interpretation in interpretations:
                tt = time.time()
                evaluated.append(evaluationP[metric](interpretation, _, instance, prediction, tokens, _, _, test_rational))
                k = k + (time.time()-tt)
            if metric == 'FTP':
                time_b2.append(k)
            metricsP[metric].append(evaluated)        
with open(file_name+' (A).pickle', 'wb') as handle:
    pickle.dump(metrics, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(file_name+' (P).pickle', 'wb') as handle:
    pickle.dump(metricsP, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(file_name+'_TIME.pickle', 'wb') as handle:
    pickle.dump(time_r, handle, protocol=pickle.HIGHEST_PROTOCOL)
time_r = np.array(time_r)
time_r.mean(axis=1).min(),time_r.mean(axis=1).max(), time_r.mean(axis=1).mean(), time_r.sum(axis=1).mean(), np.mean(time_b), np.mean(time_b2)
# Out:
# 100%|██████████| 2000/2000 [3:08:48<00:00,  5.66s/it]
# C:\Users\chris\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:79: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# We present the results for the different attention setups

# %%
print_results(file_name+' (A)', conf, metrics, label_names)
# Out:
# FTP
# ['Mean', 'Mean', 'From', False]  -0.0 | -0.05917 0.27948 -0.22032
# ['Mean', 'Mean', 'To', False]  -0.0 | -0.09121 0.44959 -0.35838
# ['Mean', 'Mean', 'MeanColumns', False]  -0.0 | -0.06727 0.24761 -0.18034
# ['Mean', 'Mean', 'MaxColumns', False]  -0.0 | -0.06686 0.25434 -0.18748
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ['Mean', 0, 'From', False]  0.0 | 0.0638 -0.27731 0.21351
# ['Mean', 0, 'To', False]  -0.0 | -0.07447 0.45224 -0.37777
# ['Mean', 0, 'MeanColumns', False]  -0.0 | -0.0705 0.27981 -0.2093
# ['Mean', 0, 'MaxColumns', False]  -0.0 | -0.06695 0.31228 -0.24533
# ['Mean', 1, 'From', False]  -0.0 | -0.06799 0.31561 -0.24762
# ['Mean', 1, 'To', False]  -0.0 | -0.0762 0.47127 -0.39507
# ['Mean', 1, 'MeanColumns', False]  -0.0 | -0.07058 0.28918 -0.2186
# ['Mean', 1, 'MaxColumns', False]  -0.0 | -0.06369 0.23973 -0.17604
# ['Mean', 2, 'From', False]  -0.0 | -0.07921 0.43442 -0.35521
# ['Mean', 2, 'To', False]  -0.0 | -0.07856 0.36256 -0.284
# ['Mean', 2, 'MeanColumns', False]  -0.0 | -0.07681 0.23676 -0.15996
# ['Mean', 2, 'MaxColumns', False]  -0.0 | -0.09018 0.26926 -0.17908
# ['Mean', 3, 'From', False]  0.0 | 0.02072 -0.08275 0.06203
# ['Mean', 3, 'To', False]  -0.0 | -0.06593 0.24501 -0.17908
# ['Mean', 3, 'MeanColumns', False]  -0.0 | -0.05362 0.16102 -0.1074
# ['Mean', 3, 'MaxColumns', False]  -0.0 | -0.06013 0.22153 -0.1614
# ['Mean', 4, 'From', False]  -0.0 | -0.04934 0.12759 -0.07825
# ['Mean', 4, 'To', False]  -0.0 | -0.08843 0.41089 -0.32246
# ['Mean', 4, 'MeanColumns', False]  -0.0 | -0.08212 0.28162 -0.1995
# ['Mean', 4, 'MaxColumns', False]  -0.0 | -0.06438 0.2803 -0.21593
# ['Mean', 5, 'From', False]  0.0 | 0.07305 -0.35548 0.28243
# ['Mean', 5, 'To', False]  -0.0 | -0.05592 0.29325 -0.23734
# ['Mean', 5, 'MeanColumns', False]  0.0 | 0.08108 -0.28566 0.20457
# ['Mean', 5, 'MaxColumns', False]  -0.0 | -0.02392 0.2025 -0.17858
# ['Mean', 6, 'From', False]  -0.0 | -0.05513 0.28603 -0.23091
# ['Mean', 6, 'To', False]  -0.0 | -0.07855 0.40076 -0.32221
# ['Mean', 6, 'MeanColumns', False]  -0.0 | -0.06792 0.29518 -0.22725
# ['Mean', 6, 'MaxColumns', False]  -0.0 | -0.05372 0.27516 -0.22145
# ['Mean', 7, 'From', False]  0.0 | 0.07027 -0.31246 0.24219
# ['Mean', 7, 'To', False]  -0.0 | -0.06848 0.2686 -0.20012
# ['Mean', 7, 'MeanColumns', False]  -0.0 | -0.06053 0.24292 -0.18239
# ['Mean', 7, 'MaxColumns', False]  -0.0 | -0.07631 0.29603 -0.21971
# ['Mean', 8, 'From', False]  -0.0 | -0.06055 0.28921 -0.22866
# ['Mean', 8, 'To', False]  -0.0 | -0.08033 0.45357 -0.37324
# ['Mean', 8, 'MeanColumns', False]  -0.0 | -0.07102 0.2742 -0.20318
# ['Mean', 8, 'MaxColumns', False]  -0.0 | -0.0677 0.33822 -0.27052
# ['Mean', 9, 'From', False]  0.0 | 0.05988 -0.2916 0.23172
# ['Mean', 9, 'To', False]  -0.0 | -0.07784 0.37659 -0.29875
# ['Mean', 9, 'MeanColumns', False]  0.0 | 0.0267 -0.09651 0.06981
# ['Mean', 9, 'MaxColumns', False]  -0.0 | -0.06601 0.32325 -0.25724
# ['Mean', 10, 'From', False]  -0.0 | -0.02171 0.12814 -0.10643
# ['Mean', 10, 'To', False]  -0.0 | -0.06306 0.27805 -0.21499
# ['Mean', 10, 'MeanColumns', False]  -0.0 | -0.05707 0.25539 -0.19833
# ['Mean', 10, 'MaxColumns', False]  -0.0 | -0.05796 0.28566 -0.22771
# ['Mean', 11, 'From', False]  -0.0 | -0.078 0.41585 -0.33785
# ['Mean', 11, 'To', False]  -0.0 | -0.08276 0.36335 -0.2806
# ['Mean', 11, 'MeanColumns', False]  -0.0 | -0.0562 0.17535 -0.11915
# ['Mean', 11, 'MaxColumns', False]  -0.0 | -0.05938 0.19222 -0.13283
# [0, 'Mean', 'From', False]  -0.0 | -0.05917 0.27948 -0.22032
# [0, 'Mean', 'To', False]  -0.0 | -0.09121 0.44959 -0.35838
# [0, 'Mean', 'MeanColumns', False]  -0.0 | -0.06727 0.24761 -0.18034
# [0, 'Mean', 'MaxColumns', False]  -0.0 | -0.06686 0.25434 -0.18748
# [0, 0, 'From', False]  0.0 | 0.0638 -0.27731 0.21351
# [0, 0, 'To', False]  -0.0 | -0.07447 0.45224 -0.37777
# [0, 0, 'MeanColumns', False]  -0.0 | -0.0705 0.27981 -0.2093
# [0, 0, 'MaxColumns', False]  -0.0 | -0.06695 0.31228 -0.24533
# [0, 1, 'From', False]  -0.0 | -0.06799 0.31561 -0.24762
# [0, 1, 'To', False]  -0.0 | -0.0762 0.47127 -0.39507
# [0, 1, 'MeanColumns', False]  -0.0 | -0.07058 0.28918 -0.2186
# [0, 1, 'MaxColumns', False]  -0.0 | -0.06369 0.23973 -0.17604
# [0, 2, 'From', False]  -0.0 | -0.07921 0.43442 -0.35521
# [0, 2, 'To', False]  -0.0 | -0.07856 0.36256 -0.284
# [0, 2, 'MeanColumns', False]  -0.0 | -0.07681 0.23676 -0.15996
# [0, 2, 'MaxColumns', False]  -0.0 | -0.09018 0.26926 -0.17908
# [0, 3, 'From', False]  0.0 | 0.02072 -0.08275 0.06203
# [0, 3, 'To', False]  -0.0 | -0.06593 0.24501 -0.17908
# [0, 3, 'MeanColumns', False]  -0.0 | -0.05362 0.16102 -0.1074
# [0, 3, 'MaxColumns', False]  -0.0 | -0.06013 0.22153 -0.1614
# [0, 4, 'From', False]  -0.0 | -0.04934 0.12759 -0.07825
# [0, 4, 'To', False]  -0.0 | -0.08843 0.41089 -0.32246
# [0, 4, 'MeanColumns', False]  -0.0 | -0.08212 0.28162 -0.1995
# [0, 4, 'MaxColumns', False]  -0.0 | -0.06438 0.2803 -0.21593
# [0, 5, 'From', False]  0.0 | 0.07305 -0.35548 0.28243
# [0, 5, 'To', False]  -0.0 | -0.05592 0.29325 -0.23734
# [0, 5, 'MeanColumns', False]  0.0 | 0.08108 -0.28566 0.20457
# [0, 5, 'MaxColumns', False]  -0.0 | -0.02392 0.2025 -0.17858
# [0, 6, 'From', False]  -0.0 | -0.05513 0.28603 -0.23091
# [0, 6, 'To', False]  -0.0 | -0.07855 0.40076 -0.32221
# [0, 6, 'MeanColumns', False]  -0.0 | -0.06792 0.29518 -0.22725
# [0, 6, 'MaxColumns', False]  -0.0 | -0.05372 0.27516 -0.22145
# [0, 7, 'From', False]  0.0 | 0.07027 -0.31246 0.24219
# [0, 7, 'To', False]  -0.0 | -0.06848 0.2686 -0.20012
# [0, 7, 'MeanColumns', False]  -0.0 | -0.06053 0.24292 -0.18239
# [0, 7, 'MaxColumns', False]  -0.0 | -0.07631 0.29603 -0.21971
# [0, 8, 'From', False]  -0.0 | -0.06055 0.28921 -0.22866
# [0, 8, 'To', False]  -0.0 | -0.08033 0.45357 -0.37324
# [0, 8, 'MeanColumns', False]  -0.0 | -0.07102 0.2742 -0.20318
# [0, 8, 'MaxColumns', False]  -0.0 | -0.0677 0.33822 -0.27052
# [0, 9, 'From', False]  0.0 | 0.05988 -0.2916 0.23172
# [0, 9, 'To', False]  -0.0 | -0.07784 0.37659 -0.29875
# [0, 9, 'MeanColumns', False]  0.0 | 0.0267 -0.09651 0.06981
# [0, 9, 'MaxColumns', False]  -0.0 | -0.06601 0.32325 -0.25724
# [0, 10, 'From', False]  -0.0 | -0.02171 0.12814 -0.10643
# [0, 10, 'To', False]  -0.0 | -0.06306 0.27805 -0.21499
# [0, 10, 'MeanColumns', False]  -0.0 | -0.05707 0.25539 -0.19833
# [0, 10, 'MaxColumns', False]  -0.0 | -0.05796 0.28566 -0.22771
# [0, 11, 'From', False]  -0.0 | -0.078 0.41585 -0.33785
# [0, 11, 'To', False]  -0.0 | -0.08276 0.36335 -0.2806
# [0, 11, 'MeanColumns', False]  -0.0 | -0.0562 0.17535 -0.11915
# [0, 11, 'MaxColumns', False]  -0.0 | -0.05938 0.19222 -0.13283
# F
# ['Mean', 'Mean', 'From', False]  0.0 | -0.03004 0.14577 -0.11574
# ['Mean', 'Mean', 'To', False]  0.0 | -0.03998 0.17893 -0.13895
# ['Mean', 'Mean', 'MeanColumns', False]  0.0 | -0.0206 0.07577 -0.05517
# ['Mean', 'Mean', 'MaxColumns', False]  0.0 | -0.01826 0.05685 -0.03858
# ['Mean', 0, 'From', False]  -0.0 | -0.01559 0.05219 -0.0366
# ['Mean', 0, 'To', False]  0.0 | -0.02403 0.16557 -0.14154
# ['Mean', 0, 'MeanColumns', False]  0.0 | -0.02149 0.07283 -0.05133
# ['Mean', 0, 'MaxColumns', False]  -0.0 | -0.01822 0.07757 -0.05935
# ['Mean', 1, 'From', False]  -0.0 | -0.02551 0.10477 -0.07925
# ['Mean', 1, 'To', False]  0.0 | -0.02804 0.1811 -0.15306
# ['Mean', 1, 'MeanColumns', False]  0.0 | -0.02967 0.11645 -0.08678
# ['Mean', 1, 'MaxColumns', False]  0.0 | -0.0191 0.07497 -0.05587
# ['Mean', 2, 'From', False]  0.0 | -0.03126 0.17472 -0.14346
# ['Mean', 2, 'To', False]  -0.0 | -0.02817 0.12633 -0.09816
# ['Mean', 2, 'MeanColumns', False]  -0.0 | -0.02225 0.05094 -0.02869
# ['Mean', 2, 'MaxColumns', False]  -0.0 | -0.03227 0.07236 -0.04009
# ['Mean', 3, 'From', False]  -0.0 | -0.03784 0.17763 -0.13979
# ['Mean', 3, 'To', False]  -0.0 | -0.01773 0.06159 -0.04386
# ['Mean', 3, 'MeanColumns', False]  -0.0 | -0.01789 0.04285 -0.02496
# ['Mean', 3, 'MaxColumns', False]  -0.0 | -0.01213 0.03589 -0.02376
# ['Mean', 4, 'From', False]  0.0 | -0.01426 0.04381 -0.02955
# ['Mean', 4, 'To', False]  0.0 | -0.04019 0.17859 -0.1384
# ['Mean', 4, 'MeanColumns', False]  0.0 | -0.03002 0.07903 -0.04901
# ['Mean', 4, 'MaxColumns', False]  -0.0 | -0.01996 0.07681 -0.05685
# ['Mean', 5, 'From', False]  0.0 | 0.01593 -0.10682 0.09089
# ['Mean', 5, 'To', False]  -0.0 | -0.0175 0.12592 -0.10842
# ['Mean', 5, 'MeanColumns', False]  0.0 | 0.02532 -0.06978 0.04447
# ['Mean', 5, 'MaxColumns', False]  -0.0 | -0.0074 0.10454 -0.09713
# ['Mean', 6, 'From', False]  0.0 | -0.02664 0.11343 -0.08679
# ['Mean', 6, 'To', False]  0.0 | -0.02893 0.13754 -0.10861
# ['Mean', 6, 'MeanColumns', False]  -0.0 | -0.02812 0.11592 -0.08781
# ['Mean', 6, 'MaxColumns', False]  0.0 | -0.00936 0.072 -0.06264
# ['Mean', 7, 'From', False]  -0.0 | -0.007 0.03791 -0.03091
# ['Mean', 7, 'To', False]  0.0 | -0.01608 0.05749 -0.04141
# ['Mean', 7, 'MeanColumns', False]  -0.0 | -0.01369 0.04032 -0.02663
# ['Mean', 7, 'MaxColumns', False]  -0.0 | -0.01801 0.07116 -0.05315
# ['Mean', 8, 'From', False]  0.0 | -0.02307 0.09547 -0.0724
# ['Mean', 8, 'To', False]  -0.0 | -0.02922 0.17953 -0.15031
# ['Mean', 8, 'MeanColumns', False]  0.0 | -0.0275 0.10671 -0.07921
# ['Mean', 8, 'MaxColumns', False]  0.0 | -0.01891 0.12043 -0.10151
# ['Mean', 9, 'From', False]  0.0 | 0.00801 -0.05004 0.04203
# ['Mean', 9, 'To', False]  -0.0 | -0.02278 0.15172 -0.12894
# ['Mean', 9, 'MeanColumns', False]  0.0 | -0.01295 0.05094 -0.038
# ['Mean', 9, 'MaxColumns', False]  0.0 | -0.01669 0.12255 -0.10586
# ['Mean', 10, 'From', False]  -0.0 | -0.00963 0.04583 -0.03619
# ['Mean', 10, 'To', False]  -0.0 | -0.00876 0.06292 -0.05416
# ['Mean', 10, 'MeanColumns', False]  0.0 | -0.01408 0.05402 -0.03994
# ['Mean', 10, 'MaxColumns', False]  -0.0 | -0.01029 0.07389 -0.06359
# ['Mean', 11, 'From', False]  0.0 | -0.0288 0.15554 -0.12673
# ['Mean', 11, 'To', False]  0.0 | -0.02649 0.11651 -0.09003
# ['Mean', 11, 'MeanColumns', False]  -0.0 | -0.01067 0.02255 -0.01188
# ['Mean', 11, 'MaxColumns', False]  0.0 | -0.01224 0.02383 -0.01159
# [0, 'Mean', 'From', False]  0.0 | -0.03004 0.14577 -0.11574
# [0, 'Mean', 'To', False]  0.0 | -0.03998 0.17893 -0.13895
# [0, 'Mean', 'MeanColumns', False]  0.0 | -0.0206 0.07577 -0.05517
# [0, 'Mean', 'MaxColumns', False]  0.0 | -0.01826 0.05685 -0.03858
# [0, 0, 'From', False]  -0.0 | -0.01559 0.05219 -0.0366
# [0, 0, 'To', False]  0.0 | -0.02403 0.16557 -0.14154
# [0, 0, 'MeanColumns', False]  0.0 | -0.02149 0.07283 -0.05133
# [0, 0, 'MaxColumns', False]  -0.0 | -0.01822 0.07757 -0.05935
# [0, 1, 'From', False]  -0.0 | -0.02551 0.10477 -0.07925
# [0, 1, 'To', False]  0.0 | -0.02804 0.1811 -0.15306
# [0, 1, 'MeanColumns', False]  0.0 | -0.02967 0.11645 -0.08678
# [0, 1, 'MaxColumns', False]  0.0 | -0.0191 0.07497 -0.05587
# [0, 2, 'From', False]  0.0 | -0.03126 0.17472 -0.14346
# [0, 2, 'To', False]  -0.0 | -0.02817 0.12633 -0.09816
# [0, 2, 'MeanColumns', False]  -0.0 | -0.02225 0.05094 -0.02869
# [0, 2, 'MaxColumns', False]  -0.0 | -0.03227 0.07236 -0.04009
# [0, 3, 'From', False]  -0.0 | -0.03784 0.17763 -0.13979
# [0, 3, 'To', False]  -0.0 | -0.01773 0.06159 -0.04386
# [0, 3, 'MeanColumns', False]  -0.0 | -0.01789 0.04285 -0.02496
# [0, 3, 'MaxColumns', False]  -0.0 | -0.01213 0.03589 -0.02376
# [0, 4, 'From', False]  0.0 | -0.01426 0.04381 -0.02955
# [0, 4, 'To', False]  0.0 | -0.04019 0.17859 -0.1384
# [0, 4, 'MeanColumns', False]  0.0 | -0.03002 0.07903 -0.04901
# [0, 4, 'MaxColumns', False]  -0.0 | -0.01996 0.07681 -0.05685
# [0, 5, 'From', False]  0.0 | 0.01593 -0.10682 0.09089
# [0, 5, 'To', False]  -0.0 | -0.0175 0.12592 -0.10842
# [0, 5, 'MeanColumns', False]  0.0 | 0.02532 -0.06978 0.04447
# [0, 5, 'MaxColumns', False]  -0.0 | -0.0074 0.10454 -0.09713
# [0, 6, 'From', False]  0.0 | -0.02664 0.11343 -0.08679
# [0, 6, 'To', False]  0.0 | -0.02893 0.13754 -0.10861
# [0, 6, 'MeanColumns', False]  -0.0 | -0.02812 0.11592 -0.08781
# [0, 6, 'MaxColumns', False]  0.0 | -0.00936 0.072 -0.06264
# [0, 7, 'From', False]  -0.0 | -0.007 0.03791 -0.03091
# [0, 7, 'To', False]  0.0 | -0.01608 0.05749 -0.04141
# [0, 7, 'MeanColumns', False]  -0.0 | -0.01369 0.04032 -0.02663
# [0, 7, 'MaxColumns', False]  -0.0 | -0.01801 0.07116 -0.05315
# [0, 8, 'From', False]  0.0 | -0.02307 0.09547 -0.0724
# [0, 8, 'To', False]  -0.0 | -0.02922 0.17953 -0.15031
# [0, 8, 'MeanColumns', False]  0.0 | -0.0275 0.10671 -0.07921
# [0, 8, 'MaxColumns', False]  0.0 | -0.01891 0.12043 -0.10151
# [0, 9, 'From', False]  0.0 | 0.00801 -0.05004 0.04203
# [0, 9, 'To', False]  -0.0 | -0.02278 0.15172 -0.12894
# [0, 9, 'MeanColumns', False]  0.0 | -0.01295 0.05094 -0.038
# [0, 9, 'MaxColumns', False]  0.0 | -0.01669 0.12255 -0.10586
# [0, 10, 'From', False]  -0.0 | -0.00963 0.04583 -0.03619
# [0, 10, 'To', False]  -0.0 | -0.00876 0.06292 -0.05416
# [0, 10, 'MeanColumns', False]  0.0 | -0.01408 0.05402 -0.03994
# [0, 10, 'MaxColumns', False]  -0.0 | -0.01029 0.07389 -0.06359
# [0, 11, 'From', False]  0.0 | -0.0288 0.15554 -0.12673
# [0, 11, 'To', False]  0.0 | -0.02649 0.11651 -0.09003
# [0, 11, 'MeanColumns', False]  -0.0 | -0.01067 0.02255 -0.01188
# [0, 11, 'MaxColumns', False]  0.0 | -0.01224 0.02383 -0.01159
# NZW
# ['Mean', 'Mean', 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 'Mean', 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 'Mean', 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 'Mean', 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# AUPRC
# ['Mean', 'Mean', 'From', False]  0.22181 | 0.22058 0.15788 0.28695
# ['Mean', 'Mean', 'To', False]  0.30532 | 0.30111 0.21001 0.40484
# ['Mean', 'Mean', 'MeanColumns', False]  0.25919 | 0.24069 0.23823 0.29864
# ['Mean', 'Mean', 'MaxColumns', False]  0.22124 | 0.20418 0.17443 0.28511
# ['Mean', 0, 'From', False]  0.22951 | 0.21597 0.18547 0.28709
# ['Mean', 0, 'To', False]  0.42342 | 0.42323 0.34615 0.50086
# ['Mean', 0, 'MeanColumns', False]  0.23518 | 0.21599 0.19444 0.29511
# ['Mean', 0, 'MaxColumns', False]  0.27966 | 0.25623 0.24316 0.3396
# ['Mean', 1, 'From', False]  0.31486 | 0.29869 0.29115 0.35473
# ['Mean', 1, 'To', False]  0.35333 | 0.36322 0.22428 0.47248
# ['Mean', 1, 'MeanColumns', False]  0.34606 | 0.32676 0.33089 0.38054
# ['Mean', 1, 'MaxColumns', False]  0.25019 | 0.2401 0.22544 0.28504
# ['Mean', 2, 'From', False]  0.30731 | 0.31239 0.19869 0.41086
# ['Mean', 2, 'To', False]  0.33292 | 0.29741 0.3008 0.40055
# ['Mean', 2, 'MeanColumns', False]  0.20192 | 0.19087 0.17886 0.23601
# ['Mean', 2, 'MaxColumns', False]  0.20372 | 0.19378 0.17374 0.24363
# ['Mean', 3, 'From', False]  0.21652 | 0.21709 0.13735 0.29511
# ['Mean', 3, 'To', False]  0.26616 | 0.25972 0.24797 0.29079
# ['Mean', 3, 'MeanColumns', False]  0.21326 | 0.20832 0.17878 0.25267
# ['Mean', 3, 'MaxColumns', False]  0.19849 | 0.19997 0.14245 0.25305
# ['Mean', 4, 'From', False]  0.23269 | 0.22977 0.20181 0.26651
# ['Mean', 4, 'To', False]  0.24352 | 0.24616 0.14936 0.33504
# ['Mean', 4, 'MeanColumns', False]  0.26985 | 0.26618 0.25041 0.29298
# ['Mean', 4, 'MaxColumns', False]  0.25374 | 0.26049 0.18881 0.3119
# ['Mean', 5, 'From', False]  0.17504 | 0.17759 0.12203 0.22549
# ['Mean', 5, 'To', False]  0.21992 | 0.21747 0.14126 0.30104
# ['Mean', 5, 'MeanColumns', False]  0.25207 | 0.2456 0.20476 0.30587
# ['Mean', 5, 'MaxColumns', False]  0.28414 | 0.29735 0.19984 0.35522
# ['Mean', 6, 'From', False]  0.31496 | 0.29405 0.28644 0.36441
# ['Mean', 6, 'To', False]  0.36984 | 0.35242 0.31267 0.44443
# ['Mean', 6, 'MeanColumns', False]  0.33608 | 0.31664 0.31562 0.37597
# ['Mean', 6, 'MaxColumns', False]  0.29565 | 0.30885 0.25619 0.3219
# ['Mean', 7, 'From', False]  0.1756 | 0.17981 0.11337 0.23362
# ['Mean', 7, 'To', False]  0.22277 | 0.23779 0.18879 0.24173
# ['Mean', 7, 'MeanColumns', False]  0.20864 | 0.19382 0.16447 0.26764
# ['Mean', 7, 'MaxColumns', False]  0.23322 | 0.21515 0.20658 0.27792
# ['Mean', 8, 'From', False]  0.308 | 0.27999 0.27418 0.36982
# ['Mean', 8, 'To', False]  0.35026 | 0.35894 0.22876 0.46307
# ['Mean', 8, 'MeanColumns', False]  0.29369 | 0.2753 0.27316 0.3326
# ['Mean', 8, 'MaxColumns', False]  0.26189 | 0.25 0.18515 0.35051
# ['Mean', 9, 'From', False]  0.21292 | 0.22153 0.14626 0.27096
# ['Mean', 9, 'To', False]  0.25424 | 0.26582 0.16209 0.33482
# ['Mean', 9, 'MeanColumns', False]  0.21857 | 0.21126 0.15948 0.28495
# ['Mean', 9, 'MaxColumns', False]  0.24227 | 0.241 0.16214 0.32367
# ['Mean', 10, 'From', False]  0.19067 | 0.19313 0.12919 0.24968
# ['Mean', 10, 'To', False]  0.21694 | 0.23113 0.16227 0.25741
# ['Mean', 10, 'MeanColumns', False]  0.19231 | 0.18248 0.1333 0.26114
# ['Mean', 10, 'MaxColumns', False]  0.21986 | 0.20499 0.15323 0.30138
# ['Mean', 11, 'From', False]  0.30051 | 0.30377 0.19739 0.40038
# ['Mean', 11, 'To', False]  0.38692 | 0.36305 0.35973 0.43797
# ['Mean', 11, 'MeanColumns', False]  0.14872 | 0.14544 0.11196 0.18876
# ['Mean', 11, 'MaxColumns', False]  0.17503 | 0.17021 0.13998 0.2149
# [0, 'Mean', 'From', False]  0.22181 | 0.22058 0.15788 0.28695
# [0, 'Mean', 'To', False]  0.30532 | 0.30111 0.21001 0.40484
# [0, 'Mean', 'MeanColumns', False]  0.25919 | 0.24069 0.23823 0.29864
# [0, 'Mean', 'MaxColumns', False]  0.22124 | 0.20418 0.17443 0.28511
# [0, 0, 'From', False]  0.22951 | 0.21597 0.18547 0.28709
# [0, 0, 'To', False]  0.42342 | 0.42323 0.34615 0.50086
# [0, 0, 'MeanColumns', False]  0.23518 | 0.21599 0.19444 0.29511
# [0, 0, 'MaxColumns', False]  0.27966 | 0.25623 0.24316 0.3396
# [0, 1, 'From', False]  0.31486 | 0.29869 0.29115 0.35473
# [0, 1, 'To', False]  0.35333 | 0.36322 0.22428 0.47248
# [0, 1, 'MeanColumns', False]  0.34606 | 0.32676 0.33089 0.38054
# [0, 1, 'MaxColumns', False]  0.25019 | 0.2401 0.22544 0.28504
# [0, 2, 'From', False]  0.30731 | 0.31239 0.19869 0.41086
# [0, 2, 'To', False]  0.33292 | 0.29741 0.3008 0.40055
# [0, 2, 'MeanColumns', False]  0.20192 | 0.19087 0.17886 0.23601
# [0, 2, 'MaxColumns', False]  0.20372 | 0.19378 0.17374 0.24363
# [0, 3, 'From', False]  0.21652 | 0.21709 0.13735 0.29511
# [0, 3, 'To', False]  0.26616 | 0.25972 0.24797 0.29079
# [0, 3, 'MeanColumns', False]  0.21326 | 0.20832 0.17878 0.25267
# [0, 3, 'MaxColumns', False]  0.19849 | 0.19997 0.14245 0.25305
# [0, 4, 'From', False]  0.23269 | 0.22977 0.20181 0.26651
# [0, 4, 'To', False]  0.24352 | 0.24616 0.14936 0.33504
# [0, 4, 'MeanColumns', False]  0.26985 | 0.26618 0.25041 0.29298
# [0, 4, 'MaxColumns', False]  0.25374 | 0.26049 0.18881 0.3119
# [0, 5, 'From', False]  0.17504 | 0.17759 0.12203 0.22549
# [0, 5, 'To', False]  0.21992 | 0.21747 0.14126 0.30104
# [0, 5, 'MeanColumns', False]  0.25207 | 0.2456 0.20476 0.30587
# [0, 5, 'MaxColumns', False]  0.28414 | 0.29735 0.19984 0.35522
# [0, 6, 'From', False]  0.31496 | 0.29405 0.28644 0.36441
# [0, 6, 'To', False]  0.36984 | 0.35242 0.31267 0.44443
# [0, 6, 'MeanColumns', False]  0.33608 | 0.31664 0.31562 0.37597
# [0, 6, 'MaxColumns', False]  0.29565 | 0.30885 0.25619 0.3219
# [0, 7, 'From', False]  0.1756 | 0.17981 0.11337 0.23362
# [0, 7, 'To', False]  0.22277 | 0.23779 0.18879 0.24173
# [0, 7, 'MeanColumns', False]  0.20864 | 0.19382 0.16447 0.26764
# [0, 7, 'MaxColumns', False]  0.23322 | 0.21515 0.20658 0.27792
# [0, 8, 'From', False]  0.308 | 0.27999 0.27418 0.36982
# [0, 8, 'To', False]  0.35026 | 0.35894 0.22876 0.46307
# [0, 8, 'MeanColumns', False]  0.29369 | 0.2753 0.27316 0.3326
# [0, 8, 'MaxColumns', False]  0.26189 | 0.25 0.18515 0.35051
# [0, 9, 'From', False]  0.21292 | 0.22153 0.14626 0.27096
# [0, 9, 'To', False]  0.25424 | 0.26582 0.16209 0.33482
# [0, 9, 'MeanColumns', False]  0.21857 | 0.21126 0.15948 0.28495
# [0, 9, 'MaxColumns', False]  0.24227 | 0.241 0.16214 0.32367
# [0, 10, 'From', False]  0.19067 | 0.19313 0.12919 0.24968
# [0, 10, 'To', False]  0.21694 | 0.23113 0.16227 0.25741
# [0, 10, 'MeanColumns', False]  0.19231 | 0.18248 0.1333 0.26114
# [0, 10, 'MaxColumns', False]  0.21986 | 0.20499 0.15323 0.30138
# [0, 11, 'From', False]  0.30051 | 0.30377 0.19739 0.40038
# [0, 11, 'To', False]  0.38692 | 0.36305 0.35973 0.43797
# [0, 11, 'MeanColumns', False]  0.14872 | 0.14544 0.11196 0.18876
# [0, 11, 'MaxColumns', False]  0.17503 | 0.17021 0.13998 0.2149

# %%
print_results(file_name+' (P)', conf, metricsP, label_names)
# Out:
# FTP
# ['Mean', 'Mean', 'From', False]  0.32483 | 0.0968 0.8258 0.05188
# ['Mean', 'Mean', 'To', False]  0.55051 | 0.21268 1.33886 0.1
# ['Mean', 'Mean', 'MeanColumns', False]  0.30008 | 0.08951 0.72948 0.08125
# ['Mean', 'Mean', 'MaxColumns', False]  0.32143 | 0.1127 0.75724 0.09434
# ['Mean', 0, 'From', False]  -0.38242 | -0.19614 -0.84183 -0.10929
# ['Mean', 0, 'To', False]  0.58499 | 0.27866 1.36593 0.11037
# ['Mean', 0, 'MeanColumns', False]  0.36409 | 0.1511 0.84048 0.10068
# ['Mean', 0, 'MaxColumns', False]  0.39923 | 0.17056 0.93089 0.09624
# ['Mean', 1, 'From', False]  0.3728 | 0.12118 0.92427 0.07294
# ['Mean', 1, 'To', False]  0.57879 | 0.24426 1.40602 0.0861
# ['Mean', 1, 'MeanColumns', False]  0.34082 | 0.0979 0.84795 0.07662
# ['Mean', 1, 'MaxColumns', False]  0.28942 | 0.08622 0.70497 0.07706
# ['Mean', 2, 'From', False]  0.51546 | 0.18724 1.28281 0.07633
# ['Mean', 2, 'To', False]  0.44596 | 0.16121 1.08019 0.09646
# ['Mean', 2, 'MeanColumns', False]  0.29761 | 0.09937 0.6941 0.09936
# ['Mean', 2, 'MaxColumns', False]  0.34425 | 0.12835 0.78997 0.11443
# ['Mean', 3, 'From', False]  -0.12092 | -0.05848 -0.25343 -0.05087
# ['Mean', 3, 'To', False]  0.29687 | 0.09427 0.71764 0.07869
# ['Mean', 3, 'MeanColumns', False]  0.20594 | 0.06882 0.47497 0.07404
# ['Mean', 3, 'MaxColumns', False]  0.28636 | 0.10934 0.66051 0.08922
# ['Mean', 4, 'From', False]  0.15123 | 0.02816 0.36758 0.05794
# ['Mean', 4, 'To', False]  0.51339 | 0.20436 1.22998 0.10581
# ['Mean', 4, 'MeanColumns', False]  0.37255 | 0.16012 0.84103 0.11648
# ['Mean', 4, 'MaxColumns', False]  0.37478 | 0.17771 0.84245 0.10419
# ['Mean', 5, 'From', False]  -0.47127 | -0.22998 -1.0719 -0.11193
# ['Mean', 5, 'To', False]  0.33925 | 0.10092 0.86076 0.05606
# ['Mean', 5, 'MeanColumns', False]  -0.35541 | -0.1194 -0.84587 -0.10097
# ['Mean', 5, 'MaxColumns', False]  0.27395 | 0.15607 0.6138 0.05199
# ['Mean', 6, 'From', False]  0.32675 | 0.09484 0.83779 0.04762
# ['Mean', 6, 'To', False]  0.46493 | 0.15107 1.17328 0.07044
# ['Mean', 6, 'MeanColumns', False]  0.34895 | 0.10569 0.86746 0.07371
# ['Mean', 6, 'MaxColumns', False]  0.35143 | 0.15091 0.82142 0.08196
# ['Mean', 7, 'From', False]  -0.42264 | -0.21492 -0.94368 -0.10931
# ['Mean', 7, 'To', False]  0.36461 | 0.17296 0.81011 0.11077
# ['Mean', 7, 'MeanColumns', False]  0.28654 | 0.07991 0.71145 0.06827
# ['Mean', 7, 'MaxColumns', False]  0.37871 | 0.14201 0.88707 0.10704
# ['Mean', 8, 'From', False]  0.33905 | 0.10506 0.84893 0.06316
# ['Mean', 8, 'To', False]  0.55386 | 0.22615 1.34672 0.0887
# ['Mean', 8, 'MeanColumns', False]  0.32416 | 0.09242 0.8033 0.07675
# ['Mean', 8, 'MaxColumns', False]  0.41616 | 0.15997 1.00376 0.08473
# ['Mean', 9, 'From', False]  -0.38333 | -0.17414 -0.88358 -0.09225
# ['Mean', 9, 'To', False]  0.47054 | 0.19307 1.12113 0.09741
# ['Mean', 9, 'MeanColumns', False]  -0.14677 | -0.09194 -0.29543 -0.05293
# ['Mean', 9, 'MaxColumns', False]  0.39203 | 0.14441 0.95506 0.07662
# ['Mean', 10, 'From', False]  0.16347 | 0.05974 0.3885 0.04217
# ['Mean', 10, 'To', False]  0.38282 | 0.19781 0.83988 0.11077
# ['Mean', 10, 'MeanColumns', False]  0.31888 | 0.11516 0.76159 0.0799
# ['Mean', 10, 'MaxColumns', False]  0.36014 | 0.14842 0.85251 0.0795
# ['Mean', 11, 'From', False]  0.49803 | 0.18528 1.22868 0.08014
# ['Mean', 11, 'To', False]  0.44097 | 0.15388 1.07272 0.09631
# ['Mean', 11, 'MeanColumns', False]  0.23219 | 0.08277 0.52672 0.08708
# ['Mean', 11, 'MaxColumns', False]  0.25229 | 0.08878 0.57741 0.09069
# [0, 'Mean', 'From', False]  0.32483 | 0.0968 0.8258 0.05188
# [0, 'Mean', 'To', False]  0.55051 | 0.21268 1.33886 0.1
# [0, 'Mean', 'MeanColumns', False]  0.30008 | 0.08951 0.72948 0.08125
# [0, 'Mean', 'MaxColumns', False]  0.32143 | 0.1127 0.75724 0.09434
# [0, 0, 'From', False]  -0.38242 | -0.19614 -0.84183 -0.10929
# [0, 0, 'To', False]  0.58499 | 0.27866 1.36593 0.11037
# [0, 0, 'MeanColumns', False]  0.36409 | 0.1511 0.84048 0.10068
# [0, 0, 'MaxColumns', False]  0.39923 | 0.17056 0.93089 0.09624
# [0, 1, 'From', False]  0.3728 | 0.12118 0.92427 0.07294
# [0, 1, 'To', False]  0.57879 | 0.24426 1.40602 0.0861
# [0, 1, 'MeanColumns', False]  0.34082 | 0.0979 0.84795 0.07662
# [0, 1, 'MaxColumns', False]  0.28942 | 0.08622 0.70497 0.07706
# [0, 2, 'From', False]  0.51546 | 0.18724 1.28281 0.07633
# [0, 2, 'To', False]  0.44596 | 0.16121 1.08019 0.09646
# [0, 2, 'MeanColumns', False]  0.29761 | 0.09937 0.6941 0.09936
# [0, 2, 'MaxColumns', False]  0.34425 | 0.12835 0.78997 0.11443
# [0, 3, 'From', False]  -0.12092 | -0.05848 -0.25343 -0.05087
# [0, 3, 'To', False]  0.29687 | 0.09427 0.71764 0.07869
# [0, 3, 'MeanColumns', False]  0.20594 | 0.06882 0.47497 0.07404
# [0, 3, 'MaxColumns', False]  0.28636 | 0.10934 0.66051 0.08922
# [0, 4, 'From', False]  0.15123 | 0.02816 0.36758 0.05794
# [0, 4, 'To', False]  0.51339 | 0.20436 1.22998 0.10581
# [0, 4, 'MeanColumns', False]  0.37255 | 0.16012 0.84103 0.11648
# [0, 4, 'MaxColumns', False]  0.37478 | 0.17771 0.84245 0.10419
# [0, 5, 'From', False]  -0.47127 | -0.22998 -1.0719 -0.11193
# [0, 5, 'To', False]  0.33925 | 0.10092 0.86076 0.05606
# [0, 5, 'MeanColumns', False]  -0.35541 | -0.1194 -0.84587 -0.10097
# [0, 5, 'MaxColumns', False]  0.27395 | 0.15607 0.6138 0.05199
# [0, 6, 'From', False]  0.32675 | 0.09484 0.83779 0.04762
# [0, 6, 'To', False]  0.46493 | 0.15107 1.17328 0.07044
# [0, 6, 'MeanColumns', False]  0.34895 | 0.10569 0.86746 0.07371
# [0, 6, 'MaxColumns', False]  0.35143 | 0.15091 0.82142 0.08196
# [0, 7, 'From', False]  -0.42264 | -0.21492 -0.94368 -0.10931
# [0, 7, 'To', False]  0.36461 | 0.17296 0.81011 0.11077
# [0, 7, 'MeanColumns', False]  0.28654 | 0.07991 0.71145 0.06827
# [0, 7, 'MaxColumns', False]  0.37871 | 0.14201 0.88707 0.10704
# [0, 8, 'From', False]  0.33905 | 0.10506 0.84893 0.06316
# [0, 8, 'To', False]  0.55386 | 0.22615 1.34672 0.0887
# [0, 8, 'MeanColumns', False]  0.32416 | 0.09242 0.8033 0.07675
# [0, 8, 'MaxColumns', False]  0.41616 | 0.15997 1.00376 0.08473
# [0, 9, 'From', False]  -0.38333 | -0.17414 -0.88358 -0.09225
# [0, 9, 'To', False]  0.47054 | 0.19307 1.12113 0.09741
# [0, 9, 'MeanColumns', False]  -0.14677 | -0.09194 -0.29543 -0.05293
# [0, 9, 'MaxColumns', False]  0.39203 | 0.14441 0.95506 0.07662
# [0, 10, 'From', False]  0.16347 | 0.05974 0.3885 0.04217
# [0, 10, 'To', False]  0.38282 | 0.19781 0.83988 0.11077
# [0, 10, 'MeanColumns', False]  0.31888 | 0.11516 0.76159 0.0799
# [0, 10, 'MaxColumns', False]  0.36014 | 0.14842 0.85251 0.0795
# [0, 11, 'From', False]  0.49803 | 0.18528 1.22868 0.08014
# [0, 11, 'To', False]  0.44097 | 0.15388 1.07272 0.09631
# [0, 11, 'MeanColumns', False]  0.23219 | 0.08277 0.52672 0.08708
# [0, 11, 'MaxColumns', False]  0.25229 | 0.08878 0.57741 0.09069
# F
# ['Mean', 'Mean', 'From', False]  0.17137 | 0.05382 0.43588 0.02442
# ['Mean', 'Mean', 'To', False]  0.21069 | 0.06917 0.53227 0.03064
# ['Mean', 'Mean', 'MeanColumns', False]  0.08124 | 0.00947 0.21854 0.01572
# ['Mean', 'Mean', 'MaxColumns', False]  0.07192 | 0.01898 0.16947 0.02733
# ['Mean', 0, 'From', False]  0.05628 | 0.00627 0.14848 0.01408
# ['Mean', 0, 'To', False]  0.21692 | 0.11061 0.50506 0.0351
# ['Mean', 0, 'MeanColumns', False]  0.09197 | 0.02853 0.22147 0.02589
# ['Mean', 0, 'MaxColumns', False]  0.09311 | 0.03235 0.22588 0.02111
# ['Mean', 1, 'From', False]  0.10584 | 0.00849 0.29704 0.01199
# ['Mean', 1, 'To', False]  0.20515 | 0.06983 0.53207 0.01356
# ['Mean', 1, 'MeanColumns', False]  0.11762 | 0.0059 0.33272 0.01424
# ['Mean', 1, 'MaxColumns', False]  0.07759 | 0.00846 0.21197 0.01233
# ['Mean', 2, 'From', False]  0.19321 | 0.05529 0.5095 0.01485
# ['Mean', 2, 'To', False]  0.14945 | 0.04288 0.37675 0.02871
# ['Mean', 2, 'MeanColumns', False]  0.06409 | 0.01801 0.14475 0.02951
# ['Mean', 2, 'MaxColumns', False]  0.09108 | 0.03246 0.20613 0.03465
# ['Mean', 3, 'From', False]  0.21311 | 0.07743 0.52997 0.03193
# ['Mean', 3, 'To', False]  0.07046 | 0.01292 0.17811 0.02034
# ['Mean', 3, 'MeanColumns', False]  0.05305 | 0.01254 0.12266 0.02396
# ['Mean', 3, 'MaxColumns', False]  0.04967 | 0.01507 0.11074 0.02319
# ['Mean', 4, 'From', False]  0.05671 | 0.01598 0.13133 0.0228
# ['Mean', 4, 'To', False]  0.21044 | 0.06905 0.5308 0.03146
# ['Mean', 4, 'MeanColumns', False]  0.1079 | 0.04733 0.23548 0.04087
# ['Mean', 4, 'MaxColumns', False]  0.10623 | 0.05454 0.2318 0.03234
# ['Mean', 5, 'From', False]  -0.15685 | -0.1034 -0.33068 -0.03646
# ['Mean', 5, 'To', False]  0.14052 | 0.04612 0.36629 0.00916
# ['Mean', 5, 'MeanColumns', False]  -0.0856 | -0.02076 -0.20499 -0.03105
# ['Mean', 5, 'MaxColumns', False]  0.14609 | 0.09408 0.32094 0.02325
# ['Mean', 6, 'From', False]  0.1127 | 0.00673 0.32164 0.00974
# ['Mean', 6, 'To', False]  0.13885 | 0.01732 0.39081 0.00842
# ['Mean', 6, 'MeanColumns', False]  0.11754 | 0.00888 0.33132 0.01241
# ['Mean', 6, 'MaxColumns', False]  0.09563 | 0.05097 0.21632 0.01959
# ['Mean', 7, 'From', False]  0.05561 | 0.0273 0.11964 0.01989
# ['Mean', 7, 'To', False]  0.09112 | 0.05864 0.17877 0.03595
# ['Mean', 7, 'MeanColumns', False]  0.0439 | 0.00419 0.11374 0.01378
# ['Mean', 7, 'MaxColumns', False]  0.09467 | 0.03649 0.21747 0.03004
# ['Mean', 8, 'From', False]  0.09552 | 0.00591 0.27119 0.00945
# ['Mean', 8, 'To', False]  0.20343 | 0.07005 0.5253 0.01496
# ['Mean', 8, 'MeanColumns', False]  0.10613 | 0.00475 0.30246 0.01117
# ['Mean', 8, 'MaxColumns', False]  0.13781 | 0.04795 0.35071 0.01479
# ['Mean', 9, 'From', False]  -0.06905 | -0.03174 -0.16001 -0.01541
# ['Mean', 9, 'To', False]  0.1779 | 0.06883 0.44773 0.01714
# ['Mean', 9, 'MeanColumns', False]  0.05907 | 0.0149 0.14813 0.01417
# ['Mean', 9, 'MaxColumns', False]  0.13978 | 0.04995 0.35941 0.00997
# ['Mean', 10, 'From', False]  0.06328 | 0.02762 0.13882 0.02338
# ['Mean', 10, 'To', False]  0.10324 | 0.08143 0.19503 0.03325
# ['Mean', 10, 'MeanColumns', False]  0.07066 | 0.02559 0.16165 0.02472
# ['Mean', 10, 'MaxColumns', False]  0.09375 | 0.04713 0.21987 0.01426
# ['Mean', 11, 'From', False]  0.17189 | 0.04976 0.45174 0.01416
# ['Mean', 11, 'To', False]  0.13174 | 0.03239 0.33974 0.02308
# ['Mean', 11, 'MeanColumns', False]  0.03367 | 0.00912 0.07063 0.02127
# ['Mean', 11, 'MaxColumns', False]  0.03663 | 0.00933 0.07581 0.02475
# [0, 'Mean', 'From', False]  0.17137 | 0.05382 0.43588 0.02442
# [0, 'Mean', 'To', False]  0.21069 | 0.06917 0.53227 0.03064
# [0, 'Mean', 'MeanColumns', False]  0.08124 | 0.00947 0.21854 0.01572
# [0, 'Mean', 'MaxColumns', False]  0.07192 | 0.01898 0.16947 0.02733
# [0, 0, 'From', False]  0.05628 | 0.00627 0.14848 0.01408
# [0, 0, 'To', False]  0.21692 | 0.11061 0.50506 0.0351
# [0, 0, 'MeanColumns', False]  0.09197 | 0.02853 0.22147 0.02589
# [0, 0, 'MaxColumns', False]  0.09311 | 0.03235 0.22588 0.02111
# [0, 1, 'From', False]  0.10584 | 0.00849 0.29704 0.01199
# [0, 1, 'To', False]  0.20515 | 0.06983 0.53207 0.01356
# [0, 1, 'MeanColumns', False]  0.11762 | 0.0059 0.33272 0.01424
# [0, 1, 'MaxColumns', False]  0.07759 | 0.00846 0.21197 0.01233
# [0, 2, 'From', False]  0.19321 | 0.05529 0.5095 0.01485
# [0, 2, 'To', False]  0.14945 | 0.04288 0.37675 0.02871
# [0, 2, 'MeanColumns', False]  0.06409 | 0.01801 0.14475 0.02951
# [0, 2, 'MaxColumns', False]  0.09108 | 0.03246 0.20613 0.03465
# [0, 3, 'From', False]  0.21311 | 0.07743 0.52997 0.03193
# [0, 3, 'To', False]  0.07046 | 0.01292 0.17811 0.02034
# [0, 3, 'MeanColumns', False]  0.05305 | 0.01254 0.12266 0.02396
# [0, 3, 'MaxColumns', False]  0.04967 | 0.01507 0.11074 0.02319
# [0, 4, 'From', False]  0.05671 | 0.01598 0.13133 0.0228
# [0, 4, 'To', False]  0.21044 | 0.06905 0.5308 0.03146
# [0, 4, 'MeanColumns', False]  0.1079 | 0.04733 0.23548 0.04087
# [0, 4, 'MaxColumns', False]  0.10623 | 0.05454 0.2318 0.03234
# [0, 5, 'From', False]  -0.15685 | -0.1034 -0.33068 -0.03646
# [0, 5, 'To', False]  0.14052 | 0.04612 0.36629 0.00916
# [0, 5, 'MeanColumns', False]  -0.0856 | -0.02076 -0.20499 -0.03105
# [0, 5, 'MaxColumns', False]  0.14609 | 0.09408 0.32094 0.02325
# [0, 6, 'From', False]  0.1127 | 0.00673 0.32164 0.00974
# [0, 6, 'To', False]  0.13885 | 0.01732 0.39081 0.00842
# [0, 6, 'MeanColumns', False]  0.11754 | 0.00888 0.33132 0.01241
# [0, 6, 'MaxColumns', False]  0.09563 | 0.05097 0.21632 0.01959
# [0, 7, 'From', False]  0.05561 | 0.0273 0.11964 0.01989
# [0, 7, 'To', False]  0.09112 | 0.05864 0.17877 0.03595
# [0, 7, 'MeanColumns', False]  0.0439 | 0.00419 0.11374 0.01378
# [0, 7, 'MaxColumns', False]  0.09467 | 0.03649 0.21747 0.03004
# [0, 8, 'From', False]  0.09552 | 0.00591 0.27119 0.00945
# [0, 8, 'To', False]  0.20343 | 0.07005 0.5253 0.01496
# [0, 8, 'MeanColumns', False]  0.10613 | 0.00475 0.30246 0.01117
# [0, 8, 'MaxColumns', False]  0.13781 | 0.04795 0.35071 0.01479
# [0, 9, 'From', False]  -0.06905 | -0.03174 -0.16001 -0.01541
# [0, 9, 'To', False]  0.1779 | 0.06883 0.44773 0.01714
# [0, 9, 'MeanColumns', False]  0.05907 | 0.0149 0.14813 0.01417
# [0, 9, 'MaxColumns', False]  0.13978 | 0.04995 0.35941 0.00997
# [0, 10, 'From', False]  0.06328 | 0.02762 0.13882 0.02338
# [0, 10, 'To', False]  0.10324 | 0.08143 0.19503 0.03325
# [0, 10, 'MeanColumns', False]  0.07066 | 0.02559 0.16165 0.02472
# [0, 10, 'MaxColumns', False]  0.09375 | 0.04713 0.21987 0.01426
# [0, 11, 'From', False]  0.17189 | 0.04976 0.45174 0.01416
# [0, 11, 'To', False]  0.13174 | 0.03239 0.33974 0.02308
# [0, 11, 'MeanColumns', False]  0.03367 | 0.00912 0.07063 0.02127
# [0, 11, 'MaxColumns', False]  0.03663 | 0.00933 0.07581 0.02475
# NZW
# ['Mean', 'Mean', 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 'Mean', 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 'Mean', 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 'Mean', 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 0, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 1, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 2, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 3, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 4, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 5, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 6, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 7, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 8, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 9, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 10, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'From', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'To', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# ['Mean', 11, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 'Mean', 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 0, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 1, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 2, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 3, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 4, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 5, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 6, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 7, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 8, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 9, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 10, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'From', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'To', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'MeanColumns', False]  1.0 | 1.0 1.0 1.0
# [0, 11, 'MaxColumns', False]  1.0 | 1.0 1.0 1.0
# AUPRC
# ['Mean', 'Mean', 'From', False]  0.22181 | 0.22058 0.15788 0.28695
# ['Mean', 'Mean', 'To', False]  0.30532 | 0.30111 0.21001 0.40484
# ['Mean', 'Mean', 'MeanColumns', False]  0.25919 | 0.24069 0.23823 0.29864
# ['Mean', 'Mean', 'MaxColumns', False]  0.22124 | 0.20418 0.17443 0.28511
# ['Mean', 0, 'From', False]  0.22951 | 0.21597 0.18547 0.28709
# ['Mean', 0, 'To', False]  0.42342 | 0.42323 0.34615 0.50086
# ['Mean', 0, 'MeanColumns', False]  0.23518 | 0.21599 0.19444 0.29511
# ['Mean', 0, 'MaxColumns', False]  0.27966 | 0.25623 0.24316 0.3396
# ['Mean', 1, 'From', False]  0.31486 | 0.29869 0.29115 0.35473
# ['Mean', 1, 'To', False]  0.35333 | 0.36322 0.22428 0.47248
# ['Mean', 1, 'MeanColumns', False]  0.34606 | 0.32676 0.33089 0.38054
# ['Mean', 1, 'MaxColumns', False]  0.25019 | 0.2401 0.22544 0.28504
# ['Mean', 2, 'From', False]  0.30731 | 0.31239 0.19869 0.41086
# ['Mean', 2, 'To', False]  0.33292 | 0.29741 0.3008 0.40055
# ['Mean', 2, 'MeanColumns', False]  0.20192 | 0.19087 0.17886 0.23601
# ['Mean', 2, 'MaxColumns', False]  0.20372 | 0.19378 0.17374 0.24363
# ['Mean', 3, 'From', False]  0.21652 | 0.21709 0.13735 0.29511
# ['Mean', 3, 'To', False]  0.26616 | 0.25972 0.24797 0.29079
# ['Mean', 3, 'MeanColumns', False]  0.21326 | 0.20832 0.17878 0.25267
# ['Mean', 3, 'MaxColumns', False]  0.19849 | 0.19997 0.14245 0.25305
# ['Mean', 4, 'From', False]  0.23269 | 0.22977 0.20181 0.26651
# ['Mean', 4, 'To', False]  0.24352 | 0.24616 0.14936 0.33504
# ['Mean', 4, 'MeanColumns', False]  0.26985 | 0.26618 0.25041 0.29298
# ['Mean', 4, 'MaxColumns', False]  0.25374 | 0.26049 0.18881 0.3119
# ['Mean', 5, 'From', False]  0.17504 | 0.17759 0.12203 0.22549
# ['Mean', 5, 'To', False]  0.21992 | 0.21747 0.14126 0.30104
# ['Mean', 5, 'MeanColumns', False]  0.25207 | 0.2456 0.20476 0.30587
# ['Mean', 5, 'MaxColumns', False]  0.28414 | 0.29735 0.19984 0.35522
# ['Mean', 6, 'From', False]  0.31496 | 0.29405 0.28644 0.36441
# ['Mean', 6, 'To', False]  0.36984 | 0.35242 0.31267 0.44443
# ['Mean', 6, 'MeanColumns', False]  0.33608 | 0.31664 0.31562 0.37597
# ['Mean', 6, 'MaxColumns', False]  0.29565 | 0.30885 0.25619 0.3219
# ['Mean', 7, 'From', False]  0.1756 | 0.17981 0.11337 0.23362
# ['Mean', 7, 'To', False]  0.22277 | 0.23779 0.18879 0.24173
# ['Mean', 7, 'MeanColumns', False]  0.20864 | 0.19382 0.16447 0.26764
# ['Mean', 7, 'MaxColumns', False]  0.23322 | 0.21515 0.20658 0.27792
# ['Mean', 8, 'From', False]  0.308 | 0.27999 0.27418 0.36982
# ['Mean', 8, 'To', False]  0.35026 | 0.35894 0.22876 0.46307
# ['Mean', 8, 'MeanColumns', False]  0.29369 | 0.2753 0.27316 0.3326
# ['Mean', 8, 'MaxColumns', False]  0.26189 | 0.25 0.18515 0.35051
# ['Mean', 9, 'From', False]  0.21292 | 0.22153 0.14626 0.27096
# ['Mean', 9, 'To', False]  0.25424 | 0.26582 0.16209 0.33482
# ['Mean', 9, 'MeanColumns', False]  0.21857 | 0.21126 0.15948 0.28495
# ['Mean', 9, 'MaxColumns', False]  0.24227 | 0.241 0.16214 0.32367
# ['Mean', 10, 'From', False]  0.19067 | 0.19313 0.12919 0.24968
# ['Mean', 10, 'To', False]  0.21694 | 0.23113 0.16227 0.25741
# ['Mean', 10, 'MeanColumns', False]  0.19231 | 0.18248 0.1333 0.26114
# ['Mean', 10, 'MaxColumns', False]  0.21986 | 0.20499 0.15323 0.30138
# ['Mean', 11, 'From', False]  0.30051 | 0.30377 0.19739 0.40038
# ['Mean', 11, 'To', False]  0.38692 | 0.36305 0.35973 0.43797
# ['Mean', 11, 'MeanColumns', False]  0.14872 | 0.14544 0.11196 0.18876
# ['Mean', 11, 'MaxColumns', False]  0.17503 | 0.17021 0.13998 0.2149
# [0, 'Mean', 'From', False]  0.22181 | 0.22058 0.15788 0.28695
# [0, 'Mean', 'To', False]  0.30532 | 0.30111 0.21001 0.40484
# [0, 'Mean', 'MeanColumns', False]  0.25919 | 0.24069 0.23823 0.29864
# [0, 'Mean', 'MaxColumns', False]  0.22124 | 0.20418 0.17443 0.28511
# [0, 0, 'From', False]  0.22951 | 0.21597 0.18547 0.28709
# [0, 0, 'To', False]  0.42342 | 0.42323 0.34615 0.50086
# [0, 0, 'MeanColumns', False]  0.23518 | 0.21599 0.19444 0.29511
# [0, 0, 'MaxColumns', False]  0.27966 | 0.25623 0.24316 0.3396
# [0, 1, 'From', False]  0.31486 | 0.29869 0.29115 0.35473
# [0, 1, 'To', False]  0.35333 | 0.36322 0.22428 0.47248
# [0, 1, 'MeanColumns', False]  0.34606 | 0.32676 0.33089 0.38054
# [0, 1, 'MaxColumns', False]  0.25019 | 0.2401 0.22544 0.28504
# [0, 2, 'From', False]  0.30731 | 0.31239 0.19869 0.41086
# [0, 2, 'To', False]  0.33292 | 0.29741 0.3008 0.40055
# [0, 2, 'MeanColumns', False]  0.20192 | 0.19087 0.17886 0.23601
# [0, 2, 'MaxColumns', False]  0.20372 | 0.19378 0.17374 0.24363
# [0, 3, 'From', False]  0.21652 | 0.21709 0.13735 0.29511
# [0, 3, 'To', False]  0.26616 | 0.25972 0.24797 0.29079
# [0, 3, 'MeanColumns', False]  0.21326 | 0.20832 0.17878 0.25267
# [0, 3, 'MaxColumns', False]  0.19849 | 0.19997 0.14245 0.25305
# [0, 4, 'From', False]  0.23269 | 0.22977 0.20181 0.26651
# [0, 4, 'To', False]  0.24352 | 0.24616 0.14936 0.33504
# [0, 4, 'MeanColumns', False]  0.26985 | 0.26618 0.25041 0.29298
# [0, 4, 'MaxColumns', False]  0.25374 | 0.26049 0.18881 0.3119
# [0, 5, 'From', False]  0.17504 | 0.17759 0.12203 0.22549
# [0, 5, 'To', False]  0.21992 | 0.21747 0.14126 0.30104
# [0, 5, 'MeanColumns', False]  0.25207 | 0.2456 0.20476 0.30587
# [0, 5, 'MaxColumns', False]  0.28414 | 0.29735 0.19984 0.35522
# [0, 6, 'From', False]  0.31496 | 0.29405 0.28644 0.36441
# [0, 6, 'To', False]  0.36984 | 0.35242 0.31267 0.44443
# [0, 6, 'MeanColumns', False]  0.33608 | 0.31664 0.31562 0.37597
# [0, 6, 'MaxColumns', False]  0.29565 | 0.30885 0.25619 0.3219
# [0, 7, 'From', False]  0.1756 | 0.17981 0.11337 0.23362
# [0, 7, 'To', False]  0.22277 | 0.23779 0.18879 0.24173
# [0, 7, 'MeanColumns', False]  0.20864 | 0.19382 0.16447 0.26764
# [0, 7, 'MaxColumns', False]  0.23322 | 0.21515 0.20658 0.27792
# [0, 8, 'From', False]  0.308 | 0.27999 0.27418 0.36982
# [0, 8, 'To', False]  0.35026 | 0.35894 0.22876 0.46307
# [0, 8, 'MeanColumns', False]  0.29369 | 0.2753 0.27316 0.3326
# [0, 8, 'MaxColumns', False]  0.26189 | 0.25 0.18515 0.35051
# [0, 9, 'From', False]  0.21292 | 0.22153 0.14626 0.27096
# [0, 9, 'To', False]  0.25424 | 0.26582 0.16209 0.33482
# [0, 9, 'MeanColumns', False]  0.21857 | 0.21126 0.15948 0.28495
# [0, 9, 'MaxColumns', False]  0.24227 | 0.241 0.16214 0.32367
# [0, 10, 'From', False]  0.19067 | 0.19313 0.12919 0.24968
# [0, 10, 'To', False]  0.21694 | 0.23113 0.16227 0.25741
# [0, 10, 'MeanColumns', False]  0.19231 | 0.18248 0.1333 0.26114
# [0, 10, 'MaxColumns', False]  0.21986 | 0.20499 0.15323 0.30138
# [0, 11, 'From', False]  0.30051 | 0.30377 0.19739 0.40038
# [0, 11, 'To', False]  0.38692 | 0.36305 0.35973 0.43797
# [0, 11, 'MeanColumns', False]  0.14872 | 0.14544 0.11196 0.18876
# [0, 11, 'MaxColumns', False]  0.17503 | 0.17021 0.13998 0.2149

# %% [markdown]
# We calculate the best attention setup using Optimus variations (we do not use the Optimus implementation script at this step)

# %%
print_results_ap(metrics, label_names, conf)
# Out:
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\lib\function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Baseline: 2.269624895430885e-09  and NZW: 1.0 and AUPRC: 0.530555284711656
# Max Across: 3.784789111745586e-09  and NZW: 1.0 and AUPRC: 0.2379534509245289
# Per Label Per Instance: 0.6161406672643608  and NZW:  1.0 and AUPRC: 0.3132952088979517
# Per Instance: 1.1065884920544167e-07  and NZW:  1.0 and AUPRC: 0.282757079369867

# %%
print_results_ap(metricsP, label_names, conf)
# Out:
# Baseline: -0.22705476316599915  and NZW: 1.0 and AUPRC: 0.530555284711656
# Max Across: 0.5849874408966941  and NZW: 1.0 and AUPRC: 0.4234155651651186
# Per Label Per Instance: 0.8908513292088815  and NZW:  1.0 and AUPRC: 0.5077940669674452
# c:\Users\chris\Anaconda3\envs\optimus_transformers\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# Per Instance: 0.8908513292088815  and NZW:  1.0 and AUPRC: 0.43849421662844446
